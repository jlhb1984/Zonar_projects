# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Template exported from CRM.

# %%
units_provision_crm=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\UnitsProvision.xlsx')
units_provision_crm.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UnitID        200 non-null    str
#  1   SerialNumber  0 non-null      float64
#  2   IMEI          0 non-null      float64
#  3   SimNo         0 non-null      float64
#  4   Carrier       0 non-null      float64
#  5   AreaCode      0 non-null      float64
#  6   PhoneNumber   0 non-null      float64
#  7   StaticIP      0 non-null      float64
#  8   ModemName     0 non-null      float64
#  9   Paired        200 non-null    bool
# dtypes: bool(1), float64(8), str(1)
# memory usage: 14.4 KB
# c:\Users\Jose.Hurtado\Documents\Zonar_projects\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# Template uploaded to google drive and downloaded to data folder.

# %%
units_provision_crm_google_drive=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\UnitsProvision.xlsx - UnitsProvision.csv',sep=',')
units_provision_crm_google_drive.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UnitID        200 non-null    str
#  1   SerialNumber  0 non-null      float64
#  2   IMEI          0 non-null      float64
#  3   SimNo         0 non-null      float64
#  4   Carrier       0 non-null      float64
#  5   AreaCode      0 non-null      float64
#  6   PhoneNumber   0 non-null      float64
#  7   StaticIP      0 non-null      float64
#  8   ModemName     0 non-null      float64
#  9   Paired        200 non-null    bool
# dtypes: bool(1), float64(8), str(1)
# memory usage: 14.4 KB

# %% [markdown]
# File used by Daniel G. (Python could not read xls file.)

# %%
#units_provision_dg=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\daniel_g_template.xls')
#units_provision_dg.info()

# %% [markdown]
# File used by Daniel G uploaded to google drive and downloaded to data folder.

# %%
units_provision_dg=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\daniel_g_template.xls - daniel_g_template.xls.csv')
units_provision_dg.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UnitID        92 non-null     str
#  1   SerialNumber  92 non-null     int64
#  2   IMEI          92 non-null     int64
#  3   SimNo         92 non-null     int64
#  4   Carrier       92 non-null     str
#  5   AreaCode      0 non-null      float64
#  6   PhoneNumber   92 non-null     int64
#  7   StaticIP      92 non-null     str
#  8   ModemName     0 non-null      float64
#  9   Paired        92 non-null     bool
# dtypes: bool(1), float64(2), int64(4), str(3)
# memory usage: 6.7 KB

# %%
#template_new_format.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\template_to_import.csv')

# %%
template_new_format=units_provision_dg
template_new_format['SerialNumber']=template_new_format['SerialNumber'].astype('str')
template_new_format['IMEI']=template_new_format['IMEI'].astype('str')
template_new_format['SimNo']=template_new_format['SimNo'].astype('str')
template_new_format['Carrier']=template_new_format['Carrier'].astype('str')
template_new_format['AreaCode']=template_new_format['AreaCode'].astype('str')
template_new_format['PhoneNumber']=template_new_format['PhoneNumber'].astype('str')
template_new_format['StaticIP']=template_new_format['StaticIP'].astype('str')
template_new_format['ModemName']=template_new_format['ModemName'].astype('str')
template_new_format['Paired']=template_new_format['Paired'].astype('str')
template_new_format.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UnitID        92 non-null     str
#  1   SerialNumber  92 non-null     str
#  2   IMEI          92 non-null     str
#  3   SimNo         92 non-null     str
#  4   Carrier       92 non-null     str
#  5   AreaCode      0 non-null      str
#  6   PhoneNumber   92 non-null     str
#  7   StaticIP      92 non-null     str
#  8   ModemName     0 non-null      str
#  9   Paired        92 non-null     str
# dtypes: str(10)
# memory usage: 7.3 KB

# %%
template_new_format.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\template_to_import.csv')

# %%
template_new_format.to_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\template_to_import_excel.xlsx')

# %% [markdown]
# Provisioning verification

# %%
df_book_table01=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\daniel_g_template.xls - daniel_g_template.xls.csv',sep=',',encoding='latin1')
df_book_table02=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\CustomerUnits.xlsx')
# Out:
# c:\Users\Jose.Hurtado\Documents\Zonar_projects\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_book_table01.info()
df_book_table02.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UnitID        92 non-null     str
#  1   SerialNumber  92 non-null     int64
#  2   IMEI          92 non-null     int64
#  3   SimNo         92 non-null     int64
#  4   Carrier       92 non-null     str
#  5   AreaCode      0 non-null      float64
#  6   PhoneNumber   92 non-null     int64
#  7   StaticIP      92 non-null     str
#  8   ModemName     0 non-null      float64
#  9   Paired        92 non-null     bool
# dtypes: bool(1), float64(2), int64(4), str(3)
# memory usage: 6.7 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 1206 entries, 0 to 1205
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1206 non-null   int64
# ...

# %%
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]       
#print("df_book_table01[8,0]: ",df_book_table01.iloc[8,0]) #UnitsByDealer.csv_r.csv
#print("df_book_table02[8,5]: ",df_book_table02.iloc[8,5]) #6MB.        
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='UnitID'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='Unit ID'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]): 
        if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):                                                                             
            list_field01.append(df_book_table02.iloc[j,2])
            list_field02.append(df_book_table02.iloc[j,19])
            list_field03.append(df_book_table02.iloc[j,24])
            list_field04.append(df_book_table02.iloc[j,21])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['UnitID']=list_field01
df_aux['IMEI']=list_field02
df_aux['SIM #']=list_field03
df_aux['Phone Number']=list_field04
print("Cont= ",cont)
print(df_aux.info())
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    #df_aux.drop('Unnamed: 0',axis=1)
    df_aux.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\coincidences.csv')                  #Edit
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):
                df_book_table02.iloc[j,3]=np.nan
                print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    #print(df_book_table02)
    df_book_table02.dropna(axis=0,inplace=True)
    print(df_book_table02)
    df_book_table02.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\differences.csv')          #Edit

#lista_combinada=[lista_simcard,lista_linea]
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UnitID        92 non-null     str
#  1   SerialNumber  92 non-null     int64
#  2   IMEI          92 non-null     int64
#  3   SimNo         92 non-null     int64
#  4   Carrier       92 non-null     str
#  5   AreaCode      0 non-null      float64
#  6   PhoneNumber   92 non-null     int64
#  7   StaticIP      92 non-null     str
#  8   ModemName     0 non-null      float64
#  9   Paired        92 non-null     bool
# dtypes: bool(1), float64(2), int64(4), str(3)
# memory usage: 6.7 KB
# None
#
# Tabla 2:
# <class 'pandas.DataFrame'>
# RangeIndex: 1206 entries, 0 to 1205
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
# ...

# %% [markdown]
# Favor de Jahidine

# %%
ubd=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\CRMUnitsDealersReports_15724_20260616160105.csv',sep=',')
ubd.info()
ubd['Peripherals'].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1432 entries, 0 to 1431
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Dealer                1432 non-null   str
#  1   Company1              1432 non-null   str
#  2   VIP                   1432 non-null   str
#  3   FEIN                  1432 non-null   str
#  4   DNI                   106 non-null    str
#  5   Peripherals           1432 non-null   str
#  6   ServiceName           1382 non-null   str
#  7   IsRenting             0 non-null      float64
#  8   UnitID1               1432 non-null   str
#  9   ShortName             1432 non-null   str
#  10  UnitType              1432 non-null   str
#  11  Carrier               697 non-null    str
#  12  MonthlyFee            1432 non-null   float64
#  13  BillingGroup          10 non-null     str
#  14  BillingPeriod         1432 non-null   str
#  15  LastServicePaidUntil  1432 non-null   str
# ...
