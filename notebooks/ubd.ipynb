# %%
import pandas as pd
import numpy as np

# %%
ubd=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\CRMUnitsDealersReports.xlsx')
ubd.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3290 entries, 0 to 3289
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   3290 non-null   str
#  1   Company                  3290 non-null   str
#  2   VIP                      3290 non-null   str
#  3   FEIN                     3046 non-null   str
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      825 non-null    str
#  6   Peripherals              3290 non-null   str
#  7   Service                  3240 non-null   str
#  8   Owner                    3290 non-null   str
#  9   Unit ID                  3290 non-null   str
#  10  Unit                     3290 non-null   str
#  11  Unit Type                3290 non-null   str
#  12  Carrier                  1113 non-null   str
#  13  Unnamed: 13              0 non-null      float64
# ...

# %%
ubd['Peripherals'].value_counts()
# Out:
# Peripherals
# Panic Button,                                                               3254
# Temp. Sensor, Panic Button,                                                    7
# Passenger Counter, Panic Button,                                               3
# Fuel Sensor - 192629, Panic Button,                                            1
# Fuel Sensor - 237501, Panic Button,                                            1
# Fuel Sensor - 235915, Panic Button,                                            1
# Fuel Sensor - 235830, Fuel Sensor - 235841, Panic Button,                      1
# Temp. Sensor, Fuel Sensor - 214309, Fuel Sensor - 214297, Panic Button,        1
# MDVR - 009902BDC5, Panic Button,                                               1
# Fuel Sensor - 214499, Panic Button,                                            1
# Fuel Sensor - 214923, Panic Button,                                            1
# ...

# %%
ubd['Status'].value_counts()
# Out:
# Status
# Active    3290
# Name: count, dtype: int64
