# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data analysys since 01-11-2025 17-12-2025 1.

# %%
raw_data=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/prz050.csv',sep=';',encoding='latin1')
raw_datam=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/prz050m.csv',sep=';',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
#raw_datam.to_csv('/home/jlhb1984/py-projects/data/chilco/prz050decoded.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10161 entries, 0 to 10160
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           10161 non-null  object
#  1   Message Type      10161 non-null  object
#  2   Protocole         10161 non-null  object
#  3   IMEI              10161 non-null  object
#  4   Serial            10161 non-null  object
#  5   Mileage           10161 non-null  object
#  6   Date              10161 non-null  object
#  7   Ignition          10161 non-null  object
#  8   Latitude          10161 non-null  object
#  9   Longitude         10161 non-null  object
#  10  Altitude          10161 non-null  object
#  11  External Power    9986 non-null   object
#  12  RPM               9986 non-null   object
#  13  Speed             9784 non-null   object
#  14  Satellite Number  9784 non-null   object
#  15  Azimuth           9784 non-null   object
# ...

# %%
prz050d=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/prz050decoded.csv')
prz050d_f=prz050d[['Date','Mileage','Speed']]
prz050d_f
# Out:
#                               Date                   Mileage      Speed
# 0      Date:"2025-11-01T00:02:05Z"          Mileage:15494501  Speed:0.0
# 1      Date:"2025-11-01T01:02:06Z"          Mileage:15494501  Speed:0.0
# 2      Date:"2025-11-01T02:02:06Z"          Mileage:15494501  Speed:0.0
# 3                          Model:0       Firmware:"V1.0.1.5"        NaN
# 4                   Band:"CAT-1 5"  AccessTechnology:"CAT-1"        NaN
# ...                            ...                       ...        ...
# 10156  Date:"2025-12-17T15:57:15Z"          Mileage:18430109  Speed:0.0
# 10157  Date:"2025-12-17T16:57:15Z"          Mileage:18430109  Speed:0.0
# 10158  Date:"2025-12-17T17:57:15Z"          Mileage:18430109  Speed:0.0
# 10159  Date:"2025-12-17T18:57:14Z"          Mileage:18430109  Speed:0.0
# 10160  Date:"2025-12-17T19:57:15Z"          Mileage:18430109  Speed:0.0
#
# [10161 rows x 3 columns]

# %%
#Looking for event: 2025-11-01T10:4
value_to_look=input('Type the date to searh: ')
print("Working...")
prz050d_f_wanted=prz050d_f[prz050d_f['Date'].str.contains(value_to_look)]
delta_x=float(prz050d_f_wanted.iloc[1,1][8:16])-float(prz050d_f_wanted.iloc[0,1][8:16])
delta_s=float(prz050d_f_wanted.iloc[1,2][6:10])-float(prz050d_f_wanted.iloc[0,2][6:10])

acc_ms=((delta_s*10)/(36*60))
prz050d_f_wanted
#print("Distance between 5:41am and 5:40am: ",delta_x,'m','Speed between 5:41am and 5:40am',delta_s,'Km/h','Acceleration= ',acc_ms,'m/s^2')
# Out:
# Working...
#                             Date           Mileage       Speed
# 169  Date:"2025-11-01T10:40:11Z"  Mileage:15557145  Speed:63.0
# 170  Date:"2025-11-01T10:41:11Z"  Mileage:15558248  Speed:66.0
# 171  Date:"2025-11-01T10:42:11Z"  Mileage:15559321  Speed:63.0
# 172  Date:"2025-11-01T10:42:58Z"  Mileage:15560207  Speed:68.0
# 173  Date:"2025-11-01T10:43:15Z"  Mileage:15560508  Speed:62.0
# 174  Date:"2025-11-01T10:43:42Z"  Mileage:15561014  Speed:68.0
# 175  Date:"2025-11-01T10:43:58Z"  Mileage:15561316  Speed:64.0
# 176  Date:"2025-11-01T10:43:58Z"  Mileage:15561316  Speed:64.0
# 177  Date:"2025-11-01T10:44:04Z"  Mileage:15561424  Speed:64.0
# 178  Date:"2025-11-01T10:45:11Z"  Mileage:15562661  Speed:49.0
# 179  Date:"2025-11-01T10:45:22Z"  Mileage:15562830  Speed:61.0
# 180  Date:"2025-11-01T10:46:10Z"  Mileage:15563573  Speed:54.0
# 181  Date:"2025-11-01T10:46:37Z"  Mileage:15563970  Speed:48.0
# 182  Date:"2025-11-01T10:47:41Z"  Mileage:15564904  Speed:51.0
# ...

# %%
mileage_report_pm=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/mileageReport_0111_3011.csv',sep=',')
mileage_report_pm
# Out:
#         Unit     Time/Date (COT)  \
# 0     PRZ050  11/01/2025 3:46 AM
# 1     PRZ050  11/01/2025 3:51 AM
# 2     PRZ050  11/01/2025 3:52 AM
# 3     PRZ050  11/01/2025 3:55 AM
# 4     PRZ050  11/01/2025 3:56 AM
# ...      ...                 ...
# 3814  PRZ050  11/27/2025 9:54 AM
# 3815  PRZ050  11/27/2025 9:55 AM
# 3816  PRZ050  11/27/2025 9:56 AM
# 3817  PRZ050  11/27/2025 9:57 AM
# 3818  PRZ050  11/27/2025 9:59 AM
#
#                                                 Address  Distance (km)  \
# 0        122-12250 Cra. 2, Soacha, Cundinamarca, 250055           0.75
# 1       36-35 Cra. 9 Este, Soacha, Cundinamarca, 250054           0.27
# 2     7 Este259-7 Este409 Cl. 33, Soacha, Cundinamar...           0.41
# 3                  Cl. 31, Soacha, Cundinamarca, 250054           0.55
# 4                 Dg. 30L, Soacha, Cundinamarca, 250051           0.21
# ...                                                 ...            ...
# ...

# %%
#Looking for event: 11/01/2025 5:4
value_to_look=input('Type the value to searh: ')
print("Working...")
prz050d_f_wanted=mileage_report_pm[mileage_report_pm['Time/Date (COT)'].str.contains(value_to_look)]
prz050d_f_wanted
# Out:
# Working...
#       Unit     Time/Date (COT)  \
# 61  PRZ050  11/01/2025 5:40 AM
# 62  PRZ050  11/01/2025 5:41 AM
# 63  PRZ050  11/01/2025 5:42 AM
# 64  PRZ050  11/01/2025 5:43 AM
# 65  PRZ050  11/01/2025 5:43 AM
# 66  PRZ050  11/01/2025 5:44 AM
# 67  PRZ050  11/01/2025 5:45 AM
# 68  PRZ050  11/01/2025 5:45 AM
# 69  PRZ050  11/01/2025 5:46 AM
# 70  PRZ050  11/01/2025 5:46 AM
# 71  PRZ050  11/01/2025 5:47 AM
# 72  PRZ050  11/01/2025 5:48 AM
# 73  PRZ050  11/01/2025 5:48 AM
# 74  PRZ050  11/01/2025 5:49 AM
#
#                                               Address  Distance (km)  \
# 61                 50, El Rosal, Cundinamarca, 250217           0.02
# 62                 50, El Rosal, Cundinamarca, 250217           4.39
# 63               50, Facatativá, Cundinamarca, 253058           0.89
# 64               50, Facatativá, Cundinamarca, 253058           0.21
# 65               50, Facatativá, Cundinamarca, 253058           0.11
# ...

# %% [markdown]
# Data analysys since 13-11-2025 11-02-2026 2. Raw data only was stored since 13-11-2026, reason why I could not do the data analysis since 01-11-2025.

# %% [markdown]
# CRM raw data

# %%
raw_data_updated=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/prz050_011125_110226_crm.csv',sep=';',encoding='latin1')
raw_datam_updated=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/prz050_011125_110226_crm_m.csv',sep=';',encoding='latin1')
raw_datam_updated.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam_updated.info()
#raw_datam_updated.to_csv('/home/jlhb1984/py-projects/data/chilco/prz050decoded_11022026.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28539 entries, 0 to 28538
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           28539 non-null  object
#  1   Message Type      28539 non-null  object
#  2   Protocole         28539 non-null  object
#  3   IMEI              28539 non-null  object
#  4   Serial            28539 non-null  object
#  5   Mileage           28539 non-null  object
#  6   Date              28539 non-null  object
#  7   Ignition          28539 non-null  object
#  8   Latitude          28539 non-null  object
#  9   Longitude         28539 non-null  object
#  10  Altitude          28539 non-null  object
#  11  External Power    28333 non-null  object
#  12  RPM               28333 non-null  object
#  13  Speed             28103 non-null  object
#  14  Satellite Number  28103 non-null  object
#  15  Azimuth           28103 non-null  object
# ...

# %%
prz050d_updated_crm=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/prz050decoded_11022026.csv')
prz050d_f_updated_crm=prz050d_updated_crm[['Date','Mileage','Speed']]
prz050d_f_updated_crm
# Out:
#                               Date           Mileage       Speed
# 0      Date:"2025-11-13T15:55:23Z"  Mileage:17093829  Speed:50.0
# 1      Date:"2025-11-13T15:57:08Z"  Mileage:17095476  Speed:59.0
# 2      Date:"2025-11-13T15:58:07Z"  Mileage:17096153  Speed:25.0
# 3      Date:"2025-11-13T15:58:50Z"  Mileage:17096373  Speed:12.0
# 4      Date:"2025-11-13T15:59:57Z"  Mileage:17096381   Speed:0.0
# ...                            ...               ...         ...
# 28534  Date:"2026-02-11T16:02:37Z"  Mileage:24857997   Speed:0.0
# 28535  Date:"2026-02-11T16:03:37Z"  Mileage:24857997   Speed:0.0
# 28536  Date:"2026-02-11T16:04:37Z"  Mileage:24857997   Speed:0.0
# 28537  Date:"2026-02-11T16:05:37Z"  Mileage:24857997   Speed:0.0
# 28538  Date:"2026-02-11T16:06:37Z"  Mileage:24857997   Speed:0.0
#
# [28539 rows x 3 columns]

# %% [markdown]
# PM mileage report, only from 01-02-2026 to 11-02-2026 because of big data.

# %%
mileage_report_pm_updated=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/mileageReport_0102_1102_pm.csv',sep=',')
mileage_report_pm_updated
# Out:
#         Unit      Time/Date (COT)  \
# 0     PRZ050   02/02/2026 8:22 AM
# 1     PRZ050   02/02/2026 8:22 AM
# 2     PRZ050   02/02/2026 8:22 AM
# 3     PRZ050   02/02/2026 8:23 AM
# 4     PRZ050   02/02/2026 8:23 AM
# ...      ...                  ...
# 2659  PRZ050  02/11/2026 10:40 AM
# 2660  PRZ050  02/11/2026 10:40 AM
# 2661  PRZ050  02/11/2026 10:42 AM
# 2662  PRZ050  02/11/2026 10:43 AM
# 2663  PRZ050  02/11/2026 10:44 AM
#
#                                             Address  Distance (mi)  \
# 0     Vía Sin Nombre, Copacabana, Antioquia, 051048           0.01
# 1     Vía Sin Nombre, Copacabana, Antioquia, 051048           0.01
# 2     Vía Sin Nombre, Copacabana, Antioquia, 051048           0.04
# 3     Vía Sin Nombre, Copacabana, Antioquia, 051048           0.01
# 4     Vía Sin Nombre, Copacabana, Antioquia, 051048           0.06
# ...                                             ...            ...
# 2659              60, Copacabana, Antioquia, 051048           0.11
# ...

# %% [markdown]
# Activities report from TSO:

# %%
activities_report=pd.read_csv(r'/home/jlhb1984/py-projects/data/chilco/Activity Report_v3_es.csv',sep=';',encoding='latin1')
activities_report.fillna('Empty',inplace=True)
value_to_look=input('Type the date to searh: ')
print("Working...")
activities_report_tso=activities_report[activities_report['Hora de Inicio'].str.contains(value_to_look)]
activities_report_tso[['Hora de Inicio','Tiempo Viajado','Distancia Conducida','Dirección']]
# Out:
# /tmp/ipykernel_1511/1572739257.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Empty' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   activities_report.fillna('Empty',inplace=True)
# Working...
#             Hora de Inicio Tiempo Viajado Distancia Conducida  \
# 0   11/02/2026 12:00 a. m.    00h:00m:00s                0,00
# 1    11/02/2026 6:22 a. m.    00h:04m:17s                2,22
# 2    11/02/2026 6:27 a. m.    00h:01m:48s                0,10
# 3    11/02/2026 6:29 a. m.    00h:28m:07s               27,63
# 4    11/02/2026 6:58 a. m.    00h:01m:13s                0,05
# 5    11/02/2026 8:45 a. m.    00h:00m:00s                0,00
# 6    11/02/2026 8:47 a. m.    00h:06m:11s                4,96
# 7    11/02/2026 9:00 a. m.    00h:00m:00s                0,00
# 8    11/02/2026 9:01 a. m.    00h:26m:01s               23,43
# ...

# %% [markdown]
# Comparison:

# %%
#CRM:
#Looking for event: 2025-11-01T06:2
value_to_look=input('Type the date to searh: ')
print("Working...")
prz050d_f_wanted_crm=prz050d_f_updated_crm[prz050d_f_updated_crm['Date'].str.contains(value_to_look)]
#delta_x=float(prz050d_f_wanted.iloc[1,1][8:16])-float(prz050d_f_wanted.iloc[0,1][8:16])
#delta_s=float(prz050d_f_wanted.iloc[1,2][6:10])-float(prz050d_f_wanted.iloc[0,2][6:10])

acc_ms=((delta_s*10)/(36*60))
prz050d_f_wanted_crm
# Out:
# Working...
#                               Date           Mileage       Speed
# 28307  Date:"2026-02-11T11:23:28Z"  Mileage:24769242  Speed:17.0
# 28308  Date:"2026-02-11T11:23:32Z"  Mileage:24769258  Speed:12.0
# 28309  Date:"2026-02-11T11:23:51Z"  Mileage:24769332  Speed:11.0

# %%
#PM:
#Looking for event: 02/11/2026 6:23 AM
value_to_look=input('Type the value to searh: ')
print("Working...")
prz050d_f_wanted_pm=mileage_report_pm_updated[mileage_report_pm_updated['Time/Date (COT)'].str.contains(value_to_look)]
prz050d_f_wanted_pm
# Out:
# Working...
#         Unit     Time/Date (COT)  \
# 2542  PRZ050  02/11/2026 6:23 AM
# 2543  PRZ050  02/11/2026 6:23 AM
# 2544  PRZ050  02/11/2026 6:23 AM
#
#                                             Address  Distance (mi)  \
# 2542  Vía Sin Nombre, Copacabana, Antioquia, 051048           0.01
# 2543              60, Copacabana, Antioquia, 051048           0.05
# 2544  Vía Sin Nombre, Copacabana, Antioquia, 051048           0.07
#
#       Total Distance (mi)  Odometer  Driver
# 2542               877.64  15391.62     NaN
# 2543               877.69  15391.66     NaN
# 2544               877.75  15391.73     NaN
