# %%
import pandas as pd
import numpy as np

# %%
report=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\supercarnes\driverCoachingReport_2026-08-27_1787850141074_8oi4cag36.csv',sep=',')
report.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tag                  501 non-null    str
#  1   Event Id             501 non-null    str
#  2   Driver               501 non-null    str
#  3   Driver ID            209 non-null    str
#  4   Vehicle              501 non-null    str
#  5   Date                 501 non-null    str
#  6   Time (UTC-5)         501 non-null    str
#  7   Event                501 non-null    str
#  8   Status               501 non-null    str
#  9   Reviewer: Notes      501 non-null    str
#  10  Reviewed On (UTC-5)  0 non-null      float64
# dtypes: float64(1), str(10)
# memory usage: 43.2 KB

# %%
report['Event'].value_counts()
# Out:
# Event
# Lane Departure         237
# No Seatbelt             56
# Power Lost              35
# Tailgating              31
# Camera Obstructed       29
# Stop Sign Violation     27
# Using Phone             23
# Collision Warning       20
# Hard Turn               18
# Yawn                    17
# Drowsiness               5
# Hard Brake               2
# Manual                   1
# Name: count, dtype: int64

# %%
report=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\supercarnes\driverCoachingReport_2026-09-01_1788281896742_hfao8vejf.csv',sep=',')
report.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tag                  88 non-null     str
#  1   Event Id             88 non-null     str
#  2   Driver               88 non-null     str
#  3   Driver ID            55 non-null     str
#  4   Vehicle              88 non-null     str
#  5   Date                 88 non-null     str
#  6   Time (UTC-5)         88 non-null     str
#  7   Event                88 non-null     str
#  8   Status               88 non-null     str
#  9   Reviewer: Notes      88 non-null     str
#  10  Reviewed On (UTC-5)  0 non-null      float64
# dtypes: float64(1), str(10)
# memory usage: 7.7 KB

# %%
report['Event'].value_counts()
# Out:
# Event
# Yawn                   18
# Power Lost             17
# Using Phone            14
# Drowsiness             11
# Lane Departure          7
# No Seatbelt             6
# Collision Warning       5
# Stop Sign Violation     3
# Camera Obstructed       2
# Hard Brake              2
# Tailgating              2
# Distracted              1
# Name: count, dtype: int64

# %%
vehicles_drowsiness=report[report['Event']=='Drowsiness']
vehicles_drowsiness
# Out:
#                 Tag                Event Id                         Driver  \
# 0   BODEGA DE POLLO  200193281-178821060837           ANDREY CANO CARRILLO
# 23        PLANTA JH  200189062-178817893275              ALEXANDER BARRERA
# 24        PLANTA JH  200189062-178820286004              ALEXANDER BARRERA
# 25        PLANTA JH  200189062-178820316261              ALEXANDER BARRERA
# 26        PLANTA JH  200189062-178821498575              ALEXANDER BARRERA
# 29        PLANTA JH  200189062-178826318357              ALEXANDER BARRERA
# 38        PLANTA JH  200189628-178827402602  DIEGO ANDRES AVENDAÑO MENESES
# 49        PLANTA JH  200189061-178827010570               LUIDIN SEPULVEDA
# 62        PLANTA JH  200189065-178818122545                     Unassigned
# 80         untagged  200189629-178826579360           NILTON SANCHEZ LARES
# 84         untagged  200189060-178818808587                   YOLMAR LOPEZ
#
# ...
