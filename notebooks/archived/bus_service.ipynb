# %%
import pandas as pd 
import numpy as np
import datetime

# %% [markdown]
# Camera matrix: A1 LUM169 AIR2
# Firmware: 3.38.951
# Serial: 8B5141QT
#
# Camera1 test: 8B514244
# Camera2 test: 8B5142A5

# %% [markdown]
# A1 LUM169 AIR2

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\bus_service\8B5141QT.csv',sep=',')
vf.info()
print("vf since",vf.iloc[0,3],"to ",vf.iloc[vf.shape[0]-1,3])
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10900 entries, 0 to 10899
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     10900 non-null  int64
#  1   Sequence #                 0 non-null      float64
#  2   Server Time                10900 non-null  str
#  3   Unit Time                  10900 non-null  str
#  4   Last Message Time          10900 non-null  str
#  5   Latitude                   10900 non-null  float64
#  6   Longitude                  10900 non-null  float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 10900 non-null  str
#  9   Raw Event                  10900 non-null  str
#  10  Address                    10900 non-null  str
#  11  GPS Speed                  10509 non-null  float64
#  12  ECU Speed                  0 non-null      float64
# ...

# %%
vf['Raw Event'].value_counts()
# Out:
# Raw Event
# GpsData.Moving                              5928
# AutoSnapshot                                1575
# GpsData.Idling                              1326
# CameraEvent.LANE_DEPARTURE_WARNING           607
# TravelStop                                   312
# TravelStart                                  310
# IgnitionStatus.driving                       310
# IgnitionStatus.parking                       310
# CameraEvent.NO_SEATBELT                      116
# CameraEvent.STOP_SIGN_VIOLATION               50
# CameraEvent.YAWN                              20
# CameraEvent.POTENTIAL_INCIDENT_MEDIUM          8
# PowerEvent.Connect                             6
# CameraEvent.USING_PHONE                        6
# CameraEvent.FORWARD_COLLISION_WARNING          5
# CameraEvent.HEADWAY_MONITORING_EMERGENCY       5
# PowerEvent.Disconnect                          3
# CameraEvent.POWER_LOST                         3
# Name: count, dtype: int64

# %%
vf_dms=vf[vf['Raw Event'].str.contains('CameraEvent')]
vf_dms['Raw Event'].value_counts()
# Out:
# Raw Event
# CameraEvent.LANE_DEPARTURE_WARNING          607
# CameraEvent.NO_SEATBELT                     116
# CameraEvent.STOP_SIGN_VIOLATION              50
# CameraEvent.YAWN                             20
# CameraEvent.POTENTIAL_INCIDENT_MEDIUM         8
# CameraEvent.USING_PHONE                       6
# CameraEvent.FORWARD_COLLISION_WARNING         5
# CameraEvent.HEADWAY_MONITORING_EMERGENCY      5
# CameraEvent.POWER_LOST                        3
# Name: count, dtype: int64

# %% [markdown]
# 8B514244

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\bus_service\Export.xlsx - Sheet1.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Columns: 104 entries, Message to Unnamed: 103
# dtypes: float64(4), str(100)
# memory usage: 583.5 KB

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"USING_PHONE"                     12
# event:"NO_SEATBELT"                      7
# event:"POTENTIAL_INCIDENT_LOW"           1
# event:"YAWN"                             1
# event:"DROWSINESS"                       1
# event:"HEADWAY_MONITORING_EMERGENCY"     1
# event:"SHARP_TURN"                       1
# Name: count, dtype: int64

# %%
vf_camera_events['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"                   21
# eventCategory:"POTENTIAL_INCIDENT"     1
# eventCategory:"HEADWAY_MONITORING"     1
# eventCategory:"SHARP_TURN"             1
# Name: count, dtype: int64
