# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ipi=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\ipi16042026.csv',sep=',')
ipi.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unidad               139 non-null    str
#  1   Conductor            139 non-null    str
#  2   Evento               139 non-null    str
#  3   Dirección            139 non-null    str
#  4   Fecha                139 non-null    str
#  5   Tiempo (UTC-5)       139 non-null    str
#  6   Duración del Evento  139 non-null    str
#  7   Distancia (km)       139 non-null    float64
# dtypes: float64(1), str(7)
# memory usage: 8.8 KB

# %%
ipi['Unidad'].value_counts()
# Out:
# Unidad
# KYR910     56
# NOX568     47
# FSQ694     36
# Name: count, dtype: int64

# %%
fsq694=ipi[ipi['Unidad'].str.contains('FSQ694')]
fsq694_16042026=fsq694[fsq694['Tiempo (UTC-5)'].str.contains('1')]
#fsq694_16042026

# %%
raw_data=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694.csv',sep=',',encoding='latin1')
raw_datam=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694_columns.csv',sep=',',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
raw_datam.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694_m.csv')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           479 non-null    str
#  1   Message Type      479 non-null    str
#  2   Protocole         479 non-null    str
#  3   IMEI              479 non-null    str
#  4   Serial            479 non-null    str
#  5   Mileage           479 non-null    str
#  6   Date              479 non-null    str
#  7   Ignition          479 non-null    str
#  8   Latitude          479 non-null    str
#  9   Longitude         479 non-null    str
#  10  Altitude          479 non-null    str
#  11  External Power    475 non-null    str
#  12  RPM               475 non-null    str
#  13  Speed             471 non-null    str
#  14  Satellite Number  471 non-null    str
#  15  Azimuth           471 non-null    str
#  16  Bettery level     471 non-null    str
# dtypes: str(17)
# ...

# %%
fsq694_m=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694_m.csv',sep=',')
fsq694_m['Odometer in meters']=0.0
fsq694_m.info()
fsq694_m_mileage=fsq694_m[fsq694_m['Date'].str.contains('2026-04-16T15')]
#fsq694_m_mileage[['Mileage','Date','IMEI']]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          479 non-null    int64
#  1   Message             479 non-null    str
#  2   Message Type        479 non-null    str
#  3   Protocole           479 non-null    str
#  4   IMEI                479 non-null    str
#  5   Serial              479 non-null    str
#  6   Mileage             479 non-null    str
#  7   Date                479 non-null    str
#  8   Ignition            479 non-null    str
#  9   Latitude            479 non-null    str
#  10  Longitude           479 non-null    str
#  11  Altitude            479 non-null    str
#  12  External Power      475 non-null    str
#  13  RPM                 475 non-null    str
#  14  Speed               471 non-null    str
#  15  Satellite Number    471 non-null    str
#  16  Azimuth             471 non-null    str
# ...

# %%
fsq694_m=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694_m.csv',sep=',')
fsq694_m_mileage=fsq694_m[fsq694_m['Date'].str.contains('2026-04-16T16:')]
#fsq694_m_mileage[['Mileage','Date','IMEI']]

# %%
fsq694_m_odometer=fsq694_m[~fsq694_m['Protocole'].str.contains(':0')]
fsq694_m_odometer['Protocole'].value_counts()
# Out:
# Protocole
# ProtocolHeadType:19    455
# ProtocolHeadType:20     16
# Name: count, dtype: int64

# %%
y_axis=[]
x_axis=[]
date=[]

for i in range(0,fsq694_m_odometer.shape[0]):
    #print(float(fsq694_m_odometer.iloc[i,6][8:15]))
    y_axis.append(float(fsq694_m_odometer.iloc[i,6][8:15]))
    x_axis.append(i)
    date.append(fsq694_m_odometer.iloc[i,7])

print("Delta odometer: ",y_axis[170]-y_axis[133],'meters')

for i in range(133,171):
    print(date[i],' -> ',x_axis[i],y_axis[i])

plt.ylim(5230627,5240177)
plt.xlim(133,171)
plt.yticks(range(5230627,5240177,500))
plt.xticks(range(133,171,5),rotation=90)
plt.plot(x_axis,y_axis)
# Out:
# Delta odometer:  9550.0 meters
# Date:"2026-04-16T13:40:53Z"  ->  133 5230627.0
# Date:"2026-04-16T15:55:17Z"  ->  134 5230627.0
# Date:"2026-04-16T15:56:17Z"  ->  135 5230627.0
# Date:"2026-04-16T15:57:18Z"  ->  136 5230761.0
# Date:"2026-04-16T15:57:41Z"  ->  137 5230786.0
# Date:"2026-04-16T15:58:33Z"  ->  138 5231044.0
# Date:"2026-04-16T15:58:55Z"  ->  139 5231173.0
# Date:"2026-04-16T15:59:07Z"  ->  140 5231233.0
# Date:"2026-04-16T15:59:42Z"  ->  141 5231426.0
# Date:"2026-04-16T15:59:50Z"  ->  142 5231471.0
# Date:"2026-04-16T16:00:49Z"  ->  143 5231867.0
# Date:"2026-04-16T16:02:18Z"  ->  144 5232254.0
# Date:"2026-04-16T16:02:51Z"  ->  145 5232379.0
# Date:"2026-04-16T16:02:54Z"  ->  146 5232383.0
# Date:"2026-04-16T16:04:08Z"  ->  147 5232492.0
# Date:"2026-04-16T16:04:52Z"  ->  148 5233031.0
# Date:"2026-04-16T16:06:18Z"  ->  149 5233580.0
# Date:"2026-04-16T16:07:18Z"  ->  150 5233924.0
# Date:"2026-04-16T16:08:17Z"  ->  151 5234118.0
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Analysis on April the 21th.

# %%
ipi=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\ipi21042026.csv',sep=',')
ipi.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unidad               207 non-null    str
#  1   Conductor            207 non-null    str
#  2   Evento               207 non-null    str
#  3   Dirección            207 non-null    str
#  4   Fecha                207 non-null    str
#  5   Tiempo (UTC-5)       207 non-null    str
#  6   Duración del Evento  207 non-null    str
#  7   Distancia (km)       207 non-null    float64
# dtypes: float64(1), str(7)
# memory usage: 13.1 KB

# %%
ipi['Unidad'].value_counts()
# Out:
# Unidad
# KYR910     79
# FSQ694     76
# NOX568     52
# Name: count, dtype: int64

# %%
ipi_fsq694=ipi[ipi['Unidad'].str.contains('FSQ694')]
ipi_fsq694['Distancia (km)'].sum()
# Out:
# np.float64(3.6699999999999995)

# %%
ar=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\Activity Report_v3.csv',sep=',')
ar['MilesDriven_float']=0.0
aux='s'
ar.info()
cad_str_to_float=[]

for i in range(0,ar.shape[0]):
    try:
        aux=ar.iloc[i,4].replace('.','')
        ar.iloc[i,4]=aux
        aux=ar.iloc[i,4].replace(',','.')
        cad_str_to_float.append(float(aux))
    except AttributeError as e:
        print("Error found on: ",ar.iloc[i,2])
        cad_str_to_float.append(0.0)

ar['MilesDriven_float']=cad_str_to_float
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GroupName          0 non-null      float64
#  1   UnitName           206 non-null    str
#  2   StartTime          206 non-null    str
#  3   MovingTimeSecs     206 non-null    str
#  4   MilesDriven        205 non-null    str
#  5   MaxSpeed           206 non-null    int64
#  6   StopTime           206 non-null    str
#  7   textbox43          206 non-null    str
#  8   StopLengthSecs     206 non-null    str
#  9   ContactName        206 non-null    str
#  10  textbox45          206 non-null    str
#  11  textbox54          206 non-null    int64
#  12  textbox28          206 non-null    str
#  13  textbox29          206 non-null    str
#  14  textbox30          206 non-null    int64
#  15  textbox32          206 non-null    str
#  16  MovingTimeSecs_1   206 non-null    str
# ...

# %%
ar_filtered=ar[['UnitName','MilesDriven_float']]
ar_filtered.info()
ar_filtered.groupby('UnitName').sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UnitName           206 non-null    str
#  1   MilesDriven_float  206 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 3.3 KB
#                MilesDriven_float
# UnitName
# Unit: FSQ694              117.39
# Unit: KYR910               57.56
# Unit: NOX568              160.59

# %%
raw_data=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694_2021_042026.csv',sep=',',encoding='latin1')
raw_datam=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694_2021_042026_columns.csv',sep=',',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
raw_datam.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694_m_2021_04.csv')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           1111 non-null   str
#  1   Message Type      1111 non-null   str
#  2   Protocole         1111 non-null   str
#  3   IMEI              1111 non-null   str
#  4   Serial            1111 non-null   str
#  5   Mileage           1111 non-null   str
#  6   Date              1111 non-null   str
#  7   Ignition          1111 non-null   str
#  8   Latitude          1111 non-null   str
#  9   Longitude         1111 non-null   str
#  10  Altitude          1111 non-null   str
#  11  External Power    1108 non-null   str
#  12  RPM               1108 non-null   str
#  13  Speed             1105 non-null   str
#  14  Satellite Number  1105 non-null   str
#  15  Azimuth           1105 non-null   str
#  16  Bettery level     1105 non-null   str
# dtypes: str(17)
# ...

# %%
fsq694_m=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\ort\fsq694_m_2021_04.csv',sep=',')
fsq694_m['Odometer in meters']=0.0
fsq694_m.info()
fsq694_m_mileage=fsq694_m[fsq694_m['Date'].str.contains('2026-04-16T15')]
#fsq694_m_mileage[['Mileage','Date','IMEI']]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1111 non-null   int64
#  1   Message             1111 non-null   str
#  2   Message Type        1111 non-null   str
#  3   Protocole           1111 non-null   str
#  4   IMEI                1111 non-null   str
#  5   Serial              1111 non-null   str
#  6   Mileage             1111 non-null   str
#  7   Date                1111 non-null   str
#  8   Ignition            1111 non-null   str
#  9   Latitude            1111 non-null   str
#  10  Longitude           1111 non-null   str
#  11  Altitude            1111 non-null   str
#  12  External Power      1108 non-null   str
#  13  RPM                 1108 non-null   str
#  14  Speed               1105 non-null   str
#  15  Satellite Number    1105 non-null   str
# ...

# %%
fsq694_m_odometer=fsq694_m[~fsq694_m['Protocole'].str.contains(':0')]
fsq694_m_odometer['Protocole'].value_counts()
# Out:
# Protocole
# ProtocolHeadType:19    1071
# ProtocolHeadType:20      34
# Name: count, dtype: int64

# %%
y_axis=[]
x_axis=[]
date=[]

for i in range(0,fsq694_m_odometer.shape[0]):
    #print(float(fsq694_m_odometer.iloc[i,6][8:15]))
    y_axis.append(float(fsq694_m_odometer.iloc[i,6][8:15]))
    x_axis.append(i)
    date.append(fsq694_m_odometer.iloc[i,7])

print("Delta odometer: ",date[279],' -> ',y_axis[279],',','-',date[868],'-',y_axis[868])
print("Delta odometer: ",y_axis[868]-y_axis[279],'meters',"\n")

for i in range(0,fsq694_m_odometer.shape[0]):
    print(date[i],' -> ',x_axis[i],y_axis[i])

plt.plot(x_axis,y_axis)
# Out:
# Delta odometer:  Date:"2026-04-20T19:00:08Z"  ->  5516552.0 , - Date:"2026-04-21T19:00:13Z" - 5633708.0
# Delta odometer:  117156.0 meters
#
# Date:"2026-04-20T01:17:01Z"  ->  0 5464316.0
# Date:"2026-04-20T05:17:00Z"  ->  1 5464316.0
# Date:"2026-04-20T09:17:01Z"  ->  2 5464316.0
# Date:"2026-04-20T09:27:12Z"  ->  3 5464316.0
# Date:"2026-04-20T09:28:13Z"  ->  4 5464316.0
# Date:"2026-04-20T09:29:13Z"  ->  5 5464316.0
# Date:"2026-04-20T09:30:13Z"  ->  6 5464316.0
# Date:"2026-04-20T09:31:13Z"  ->  7 5464316.0
# Date:"2026-04-20T09:32:13Z"  ->  8 5464316.0
# Date:"2026-04-20T09:33:12Z"  ->  9 5464316.0
# Date:"2026-04-20T09:34:13Z"  ->  10 5464316.0
# Date:"2026-04-20T09:34:32Z"  ->  11 5464345.0
# Date:"2026-04-20T09:35:34Z"  ->  12 5464381.0
# Date:"2026-04-20T09:36:35Z"  ->  13 5464540.0
# Date:"2026-04-20T09:37:31Z"  ->  14 5464741.0
# Date:"2026-04-20T09:38:21Z"  ->  15 5464999.0
# Date:"2026-04-20T09:38:23Z"  ->  16 5465004.0
# Date:"2026-04-20T09:38:32Z"  ->  17 5465038.0
# ...
