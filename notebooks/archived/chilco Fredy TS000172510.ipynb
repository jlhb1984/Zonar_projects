# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
#from yellowbrick.cluster import SilhouetteVisualizer

# %%
cu=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\CustomerUnits.xlsx')
cu['Unit Type'].value_counts()
# Out:
# c:\Users\Jose.Hurtado\Documents\Zonar_projects\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Unit Type
# Queclink GV55W                                     212
# VidFleet 4K                                         40
# Topfly PioneerX                                     39
# VidFleet AIR2                                       15
# CalAmp 2630 - CINTERION GSM - LMU30H30BT3-G1000      1
# CalAmp 2630 - GEMALTO HSPA -LMU26H3001-JAM01         1
# Name: count, dtype: int64

# %%
cu.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               308 non-null    int64
#  1   Owner                    0 non-null      float64
#  2   Unit ID                  308 non-null    str
#  3   Unit                     308 non-null    str
#  4   Peripherals              0 non-null      float64
#  5   Billing Period           0 non-null      float64
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            5 non-null      str
#  9   Last Event Date          308 non-null    str
#  10  Monthly Fee              308 non-null    float64
#  11  Bill To                  14 non-null     str
#  12  Assigned To              308 non-null    str
#  13  Linked Mode              0 non-null      float64
# ...

# %%
cu_failure=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\units_reported.csv',sep=',')
cu_failure.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Short_name  16 non-null     str
# dtypes: str(1)
# memory usage: 260.0 bytes

# %%
df_book_table01=cu_failure
df_book_table02=cu

num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]       
#print("df_book_table01[8,0]: ",df_book_table01.iloc[8,0]) #UnitsByDealer.csv_r.csv
#print("df_book_table02[8,5]: ",df_book_table02.iloc[8,5]) #6MB.        
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='Short_name'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='Unit'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]): 
        if (df_book_table01.iloc[i,position_table01])==(df_book_table02.iloc[j,position_table02]):                                                                             
            list_field01.append(df_book_table01.iloc[i,0])
            list_field02.append(df_book_table02.iloc[j,19])
            list_field03.append(df_book_table02.iloc[j,18])
            list_field04.append(df_book_table02.iloc[j,29])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['Short_name']=list_field01
df_aux['IMEI']=list_field02
df_aux['Unit type']=list_field03
df_aux['Last Contact On']=list_field04
print("Cont= ",cont)
print(df_aux.info())
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    df_aux.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\units_failing.csv')                  #Edit
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):
                df_book_table02.iloc[j,3]=np.nan
                print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    #print(df_book_table02)
    df_book_table02.dropna(axis=0,inplace=True)
    print(df_book_table02)
    df_book_table02.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\dif_units_failing.csv')          #Edit
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Short_name  16 non-null     str
# dtypes: str(1)
# memory usage: 260.0 bytes
# None
#
# Tabla 2:
# <class 'pandas.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               308 non-null    int64
#  1   Owner                    0 non-null      float64
#  2   Unit ID                  308 non-null    str
#  3   Unit                     308 non-null    str
#  4   Peripherals              0 non-null      float64
#  5   Billing Period           0 non-null      float64
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
# ...

# %%
units_failing=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\units_failing.csv',sep=',')
units_failing.drop("Unnamed: 0",axis=1)
# Out:
#    Short_name             IMEI        Unit type          Last Contact On
# 0      CGQ270  869487061675582  Topfly PioneerX  2026-07-07 16:39:56.103
# 1      EQY796  868574042784996   Queclink GV55W  2026-07-07 16:05:05.263
# 2      EQZ327  868574042848049   Queclink GV55W  2026-07-07 16:15:36.420
# 3      EQZ329  868574042900006   Queclink GV55W  2026-07-07 16:39:55.220
# 4      EQZ330  868574042888151   Queclink GV55W  2026-07-07 15:43:00.090
# 5      EQZ355  868574042898549   Queclink GV55W  2026-07-06 13:11:56.157
# 6      ERK700  868574042918081   Queclink GV55W  2026-07-07 16:35:23.353
# 7      KOK936  868574042788351   Queclink GV55W  2026-07-07 16:39:54.673
# 8      EQY796  868574042784996   Queclink GV55W  2026-07-07 16:05:05.263
# 9      EQZ330  868574042888151   Queclink GV55W  2026-07-07 15:43:00.090
# 10     EQZ355  868574042898549   Queclink GV55W  2026-07-06 13:11:56.157
# 11     ERK700  868574042918081   Queclink GV55W  2026-07-07 16:35:23.353
# ...

# %%
units_failing_processed=units_failing.drop_duplicates('Short_name')
units_failing_processed
# Out:
#     Unnamed: 0 Short_name             IMEI        Unit type  \
# 0            0     CGQ270  869487061675582  Topfly PioneerX
# 1            1     EQY796  868574042784996   Queclink GV55W
# 2            2     EQZ327  868574042848049   Queclink GV55W
# 3            3     EQZ329  868574042900006   Queclink GV55W
# 4            4     EQZ330  868574042888151   Queclink GV55W
# 5            5     EQZ355  868574042898549   Queclink GV55W
# 6            6     ERK700  868574042918081   Queclink GV55W
# 7            7     KOK936  868574042788351   Queclink GV55W
# 12          12     PRZ609  869487064415689  Topfly PioneerX
# 13          13     PRZ982  868574042894688   Queclink GV55W
# 14          14     SOO657  868574042913991   Queclink GV55W
# 15          15     WNM396  868574042784426   Queclink GV55W
#
#             Last Contact On
# 0   2026-07-07 16:39:56.103
# 1   2026-07-07 16:05:05.263
# 2   2026-07-07 16:15:36.420
# 3   2026-07-07 16:39:55.220
# 4   2026-07-07 15:43:00.090
# ...

# %%
units_failing_processed['Unit type'].value_counts()
# Out:
# Unit type
# Queclink GV55W     10
# Topfly PioneerX     2
# Name: count, dtype: int64

# %%
print('Queclink: ', (10/12)*100,'%', 'TopFly: ',(2/12)*100,'%')
# Out:
# Queclink:  83.33333333333334 % TopFly:  16.666666666666664 %

# %%
ar0=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_cgq270.csv',sep=',')
ar1=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_eqy796.csv',sep=',')
ar2=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_eqz327.csv',sep=',')
ar3=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_eqz329.csv',sep=',')
ar4=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_eqz330.csv',sep=',')
ar5=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_eqz355.csv',sep=',')
ar6=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_erk700.csv',sep=',')
ar7=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_kok936.csv',sep=',')
ar8=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_prz609.csv',sep=',')
ar9=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_prz982.csv',sep=',')
ar10=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_soo657.csv',sep=',')
ar11=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\ar_wnm396.csv',sep=',')

ar_total=pd.concat([ar0,ar1,ar2,ar3,ar4,ar5,ar6,ar7,ar8,ar9,ar10,ar11])

ar_total.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 202727 entries, 0 to 14982
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   UnitID        202727 non-null  str
#  1   EventCode     202727 non-null  str
#  2   UTC_DateTime  202727 non-null  str
#  3   Address       202727 non-null  str
#  4   Latitude      202727 non-null  str
#  5   Longitude     202727 non-null  str
# dtypes: str(6)
# memory usage: 10.8 MB

# %%
ar_total['lat_float']=0.0
ar_total['lon_float']=0.0
ar_total['lat_float_t']=0.0
ar_total['lon_float_t']=0.0
aux_lat='NaN'
aux_lon='Nan'
ar_lat_t=[]
ar_lon_t=[]
lat_str_to_float=[]
lon_str_to_float=[]

for i in range(0,ar_total.shape[0]):    
    aux_lat=ar_total.iloc[i,4].replace(',','.')
    lat_str_to_float.append(float(aux_lat))
    #print(aux_lat, ar_total.iloc[i,4])   
    aux_lon=ar_total.iloc[i,5].replace(',','.')
    lon_str_to_float.append(float(aux_lon))
    #print(aux_lon, ar_total.iloc[i,5]) 

ar_total['lat_float']=lat_str_to_float
ar_total['lon_float']=lon_str_to_float

for i in range(0,ar_total.shape[0]):
    aux=float(ar_total.iloc[i,6])
    ar_lat_t.append(round(aux,5))

for i in range(0,ar_total.shape[0]):
    aux=(float(ar_total.iloc[i,7]))
    ar_lon_t.append(round(aux,5))

ar_total['lat_float_t']=ar_lat_t
ar_total['lon_float_t']=ar_lon_t
ar_total.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 202727 entries, 0 to 14982
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   UnitID        202727 non-null  str
#  1   EventCode     202727 non-null  str
#  2   UTC_DateTime  202727 non-null  str
#  3   Address       202727 non-null  str
#  4   Latitude      202727 non-null  str
#  5   Longitude     202727 non-null  str
#  6   lat_float     202727 non-null  float64
#  7   lon_float     202727 non-null  float64
#  8   lat_float_t   202727 non-null  float64
#  9   lon_float_t   202727 non-null  float64
# dtypes: float64(4), str(6)
# memory usage: 17.0 MB

# %% [markdown]
# Scatter plot total of units reported with troubles

# %%
x_axis=[]
y_axis=[]
unit=[]
df=pd.DataFrame()

for i in range(0,ar_total.shape[0]):
    #try:
    x_axis.append(ar_total.iloc[i,8])
    y_axis.append(ar_total.iloc[i,9])
    unit.append(ar_total.iloc[i,0])
    #except:
    #print(ar_total.iloc[i,6], ' -> ',ar_total.iloc[i,7])

df['Unit']=unit
df['Lat']=x_axis
df['Lon']=y_axis

sns.scatterplot(data=df, x='Lat', marker='+',y='Lon', hue='Unit')

plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left",markerscale=3)
plt.tight_layout()
plt.show()

# %%
print(' Max latitude: ',df['Lat'].max(),'Min latiude: ',df['Lat'].min(),'\n','Max longitude: ',df['Lon'].max(),'Min longitude: ',df['Lon'].min())
# Out:
#  Max latitude:  5.39937 Min latiude:  0.88114
#  Max longitude:  -73.50356 Min longitude:  -77.87443

# %%
chilco_dict={
    'EQY796':'Buffered messages.',
    'EQZ330':'Jump, no buffered messages.',
    'EQZ355':'Buffered messages',
    'ERK700':'Buffered messages',
    'KOK936':'Buffered messages',
    'PRZ609':'Buffered messages. High Mins Diff',
    'WNM396':'High speed detected, generated from the unit.',
    'CGQ270':'No error detectes on June',
    'EQZ327':'Buffered messages, high speed genrated from the unit.',
    'EQZ329':'Without any mistake in the period reported.',
    'PRZ982':'Trouble not found in the period reported.',
    'SOO657':'No data found to analize in te period reported.,'
}

chilco_dict
# Out:
# {'EQY796': 'Buffered messages.',
#  'EQZ330': 'Jump, no buffered messages.',
#  'EQZ355': 'Buffered messages',
#  'ERK700': 'Buffered messages',
#  'KOK936': 'Buffered messages',
#  'PRZ609': 'Buffered messages. High Mins Diff',
#  'WNM396': 'High speed detected, generated from the unit.',
#  'CGQ270': 'No error detectes on June',
#  'EQZ327': 'Buffered messages, high speed genrated from the unit.',
#  'EQZ329': 'Without any mistake in the period reported.',
#  'PRZ982': 'Trouble not found in the period reported.',
#  'SOO657': 'No data found to analize in te period reported.,'}

# %% [markdown]
# Freddy's questions:
# Hola @Jose Luis Hurtado Balcazar
#
# Respecto a las unidades que tienen problemas de conectividad (caso de buffer) que indicas en el correo adjunto, sugiero que hagamos el siguiente análisis:
# Qué alternativas de solución tenemos sugeridas por el equipo de hardware?
# Nos sucede con unidades nuevas en el mismo sector geográfico? Debemos hacer esto antes de sugerir el cambio de unidades al cliente.
# Quedamos atentos al resultado de tu análisis.
#
# Gracias.
#
# Unidades nuevas: CGQ270 y PRZ609.
# Unidad con falla EQY796.

# %%
ar_total_eqy796=ar_total[ar_total['UnitID'].str.contains('EQY')]
ar_total_cg1270=ar_total[ar_total['UnitID'].str.contains('CGQ')]
ar_total_prz609=ar_total[ar_total['UnitID'].str.contains('PRZ609')]

ar_total=pd.concat([ar_total_eqy796,ar_total_cg1270,ar_total_prz609])

# %%
ar_total['lat_float']=0.0
ar_total['lon_float']=0.0
ar_total['lat_float_t']=0.0
ar_total['lon_float_t']=0.0
aux_lat='NaN'
aux_lon='Nan'
ar_lat_t=[]
ar_lon_t=[]
lat_str_to_float=[]
lon_str_to_float=[]

for i in range(0,ar_total.shape[0]):    
    aux_lat=ar_total.iloc[i,4].replace(',','.')
    lat_str_to_float.append(float(aux_lat))
    #print(aux_lat, ar_total.iloc[i,4])   
    aux_lon=ar_total.iloc[i,5].replace(',','.')
    lon_str_to_float.append(float(aux_lon))
    #print(aux_lon, ar_total.iloc[i,5]) 

ar_total['lat_float']=lat_str_to_float
ar_total['lon_float']=lon_str_to_float

for i in range(0,ar_total.shape[0]):
    aux=float(ar_total.iloc[i,6])
    ar_lat_t.append(round(aux,5))

for i in range(0,ar_total.shape[0]):
    aux=(float(ar_total.iloc[i,7]))
    ar_lon_t.append(round(aux,5))

ar_total['lat_float_t']=ar_lat_t
ar_total['lon_float_t']=ar_lon_t
ar_total.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 38685 entries, 0 to 16884
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UnitID        38685 non-null  str
#  1   EventCode     38685 non-null  str
#  2   UTC_DateTime  38685 non-null  str
#  3   Address       38685 non-null  str
#  4   Latitude      38685 non-null  str
#  5   Longitude     38685 non-null  str
#  6   lat_float     38685 non-null  float64
#  7   lon_float     38685 non-null  float64
#  8   lat_float_t   38685 non-null  float64
#  9   lon_float_t   38685 non-null  float64
# dtypes: float64(4), str(6)
# memory usage: 3.2 MB

# %%
x_axis=[]
y_axis=[]
unit=[]
df=pd.DataFrame()

for i in range(0,ar_total.shape[0]):
    #try:
    x_axis.append(ar_total.iloc[i,8])
    y_axis.append(ar_total.iloc[i,9])
    unit.append(ar_total.iloc[i,0])
    #except:
    #print(ar_total.iloc[i,6], ' -> ',ar_total.iloc[i,7])

df['Unit']=unit
df['Lat']=x_axis
df['Lon']=y_axis

sns.scatterplot(data=df, x='Lat', marker='s',y='Lon', hue='Unit')

plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left",markerscale=3)
plt.tight_layout()
plt.show()
