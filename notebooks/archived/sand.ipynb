# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hl=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\sand\historicallocations.xlsx')
hl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     53 non-null     int64
#  1   Unit         53 non-null     str
#  2   Events       53 non-null     str
#  3   Date         53 non-null     str
#  4   Landmark     0 non-null      float64
#  5   Address      53 non-null     str
#  6   Speed        53 non-null     int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     53 non-null     float64
#  10  Longitude    53 non-null     float64
# dtypes: float64(5), int64(2), str(4)
# memory usage: 4.7 KB

# %%
hl['Events'].value_counts()
# Out:
# Events
# Ignition ON           22
# Ignition OFF          21
# Power Restored         4
# Power Cut              4
# Unk Harsh Behavior     2
# Name: count, dtype: int64
