# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Test April the 24th, 2026. Reports since 19-04-2026 to 23-04-2026.

# %%
#Activity Reports Summary
#ars in Kilometers
ars=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\brahman\Activity Report Summarized 1923_042026.csv',sep=',')
ars['MilesDriven_in_Miles']=0.0
cad_str_to_float=[]

for i in range(0,ars.shape[0]):
    aux=ars.iloc[i,4].replace('.','')
    ars.iloc[i,4]=aux
    aux=ars.iloc[i,4].replace(',','.')
    cad_str_to_float.append(aux)    
    
#print(cad_str_to_float)

ars['MilesDriven_dec']=cad_str_to_float

ars.info()
for i in range(0,ars.shape[0]):
    ars.iloc[i,18]=float(ars.iloc[i,19])*0.621371
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   GroupName             0 non-null      float64
#  1   UnitID                40 non-null     str
#  2   UnitName1             40 non-null     str
#  3   MaxSpeed              40 non-null     int64
#  4   MilesDriven           40 non-null     str
#  5   TravelTimeSecs        40 non-null     str
#  6   Textbox3              40 non-null     str
#  7   IdleTimeSecs          40 non-null     str
#  8   Textbox6              40 non-null     str
#  9   IdleTimeSecs2         40 non-null     str
#  10  Textbox11             40 non-null     str
#  11  Textbox15             40 non-null     str
#  12  Textbox16             40 non-null     str
#  13  Textbox17             40 non-null     str
#  14  Textbox18             40 non-null     str
#  15  Textbox19             40 non-null     str
# ...

# %%
ur=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\brahman\utilizationReport_1923_042026.csv',sep=',')
ur.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tag                23 non-null     str
#  1   Unit               23 non-null     str
#  2   Driver             0 non-null      float64
#  3   Distance (km)      23 non-null     float64
#  4   Duration           23 non-null     str
#  5   Idle Time          23 non-null     str
#  6   Stop Time          23 non-null     str
#  7   Moving Percentage  23 non-null     str
#  8   Days Worked        23 non-null     int64
#  9   Days Total         23 non-null     int64
#  10  Days Percentage    23 non-null     str
# dtypes: float64(2), int64(2), str(7)
# memory usage: 2.1 KB

# %%
df_book_table01=ur
df_book_table02=ars
df_book_table01.fillna(0,inplace=True)
df_book_table02.fillna(0,inplace=True)
df_book_table01.info()
df_book_table02.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tag                23 non-null     str
#  1   Unit               23 non-null     str
#  2   Driver             23 non-null     float64
#  3   Distance (km)      23 non-null     float64
#  4   Duration           23 non-null     str
#  5   Idle Time          23 non-null     str
#  6   Stop Time          23 non-null     str
#  7   Moving Percentage  23 non-null     str
#  8   Days Worked        23 non-null     int64
#  9   Days Total         23 non-null     int64
#  10  Days Percentage    23 non-null     str
# dtypes: float64(2), int64(2), str(7)
# memory usage: 2.1 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
# ...

# %%
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]
list_field05=[]       
#print("df_book_table01[8,0]: ",df_book_table01.iloc[8,0]) #UnitsByDealer.csv_r.csv
#print("df_book_table02[8,5]: ",df_book_table02.iloc[8,5]) #6MB.        
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='Unit'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='UnitName1'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]):
        #print(df_book_table01.iloc[i,position_table01],df_book_table02.iloc[j,position_table02]) 
        if df_book_table01.iloc[i,position_table01]==df_book_table02.iloc[j,position_table02]:                                                                             
            list_field01.append(df_book_table01.iloc[i,1])
            list_field02.append(df_book_table01.iloc[i,3])
            list_field03.append(df_book_table02.iloc[j,4])
            list_field04.append(df_book_table01.iloc[i,4])
            list_field05.append(df_book_table02.iloc[j,5])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['Unit']=list_field01
df_aux['PM Distance']=list_field02
df_aux['TSO Distance']=list_field03
df_aux['PM Duration']=list_field04
df_aux['TSO TravelTimeSecs']=list_field05
print("Cont= ",cont)
print(df_aux.info())
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    df_aux.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\brahman\coincidences_24042026.csv')                  #Edit
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if df_book_table01.iloc[i,position_table01]==df_book_table02.iloc[j,position_table02]:
                df_book_table02.iloc[j,3]=np.nan
                #print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                #print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    #print(df_book_table02)
    df_book_table02.dropna(axis=0,inplace=True)
    #print(df_book_table02)
    df_book_table02.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\brahman\differences_24042026.csv')          #Edit

print(df_aux)
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tag                23 non-null     str
#  1   Unit               23 non-null     str
#  2   Driver             23 non-null     float64
#  3   Distance (km)      23 non-null     float64
#  4   Duration           23 non-null     str
#  5   Idle Time          23 non-null     str
#  6   Stop Time          23 non-null     str
#  7   Moving Percentage  23 non-null     str
#  8   Days Worked        23 non-null     int64
#  9   Days Total         23 non-null     int64
#  10  Days Percentage    23 non-null     str
# dtypes: float64(2), int64(2), str(7)
# memory usage: 2.1 KB
# None
#
# Tabla 2:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %%
report=df_aux
report['%_Error (TSO as theorical value)']=0.0
report.info()
aux=[]

for i in range(0,report.shape[0]):
    aux.append(report.iloc[i,2].replace(',','.'))

report['TSO Distance']=aux
print(report['TSO Distance'])

for i in range(0,report.shape[0]):
    report.iloc[i,5]=(abs(report.iloc[i,1]-float(report.iloc[i,2]))/float(report.iloc[i,2]))*100

print(report)
report.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\brahman\report24042026.csv')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unit                              15 non-null     str
#  1   PM Distance                       15 non-null     float64
#  2   TSO Distance                      15 non-null     str
#  3   PM Duration                       15 non-null     str
#  4   TSO TravelTimeSecs                15 non-null     str
#  5   %_Error (TSO as theorical value)  15 non-null     float64
# dtypes: float64(2), str(4)
# memory usage: 852.0 bytes
# 0     1727.47
# 1     2173.11
# 2      518.53
# 3      293.91
# 4      576.58
# 5      158.33
# 6      404.27
# 7      358.40
# 8      373.14
# 9      167.34
# 10     407.89
# 11     676.54
# 12     764.13
# 13     440.86
# 14      20.12
# Name: TSO Distance, dtype: str
#       Unit  PM Distance TSO Distance                   PM Duration  \
# ...
