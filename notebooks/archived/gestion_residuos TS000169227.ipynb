# %%
import pandas as pd 
import numpy as np
import datetime as datetime

# %% [markdown]
# ett651 145W

# %%
ett651=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gestion_residuos\ett651_columns.csv',sep=',')
ett651.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7256 entries, 0 to 7255
# Columns: 152 entries, Message to Unnamed: 151
# dtypes: float64(8), str(144)
# memory usage: 8.4 MB
# C:\Users\Jose.Hurtado\AppData\Local\Temp\ipykernel_21524\2338592503.py:1: DtypeWarning: Columns (0: Unnamed: 140, 1: Unnamed: 141, 2: Unnamed: 143, 3: Unnamed: 144, 4: Unnamed: 145, 5: Unnamed: 146, 6: Unnamed: 147, 7: Unnamed: 148, 8: Unnamed: 149, 9: Unnamed: 150, 10: Unnamed: 151) have mixed types. Specify dtype option on import or set low_memory=False.
#   ett651=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gestion_residuos\ett651_columns.csv',sep=',')

# %%
ett651_3columns=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gestion_residuos\ett651.csv',sep=',')

# %%
print('Events since: ',ett651_3columns.iloc[0,0],' to ',ett651_3columns.iloc[(ett651.shape[0]-1),0])
# Out:
# Events since:  2026-02-01 03:53:57.251  to  2026-02-28 20:31:50.259

# %%
ett651['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              4038
# {"notificationType":"CameraRunningInfo"     1744
# {"notificationType":"AutoSnapshot"          1017
# {"notificationType":"IgnitionStatus"         295
# {"notificationType":"ParkingHeartbeat"        86
# {"notificationType":"DataUsage"               55
# {"notificationType":"CameraEvent"             15
# {"notificationType":"MaintenanceWarning"       6
# Name: count, dtype: int64

# %%
ett651_events=ett651[ett651['Message'].str.contains('CameraEvent')]
ett651_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    8
# event:"POTENTIAL_INCIDENT_LOW"       5
# event:"SHARP_TURN"                   1
# event:"POTENTIAL_INCIDENT_MEDIUM"    1
# Name: count, dtype: int64

# %%
ett651_events['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"FORWARD_COLLISION"     8
# eventCategory:"POTENTIAL_INCIDENT"    6
# eventCategory:"SHARP_TURN"            1
# Name: count, dtype: int64

# %% [markdown]
# lul650 147Y

# %%
lul650=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gestion_residuos\lul650_columns.csv',sep=',')
lul650.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6518 entries, 0 to 6517
# Columns: 116 entries, Message to Unnamed: 115
# dtypes: float64(5), str(111)
# memory usage: 5.8 MB

# %%
lul650['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              3684
# {"notificationType":"CameraRunningInfo"     1465
# {"notificationType":"AutoSnapshot"           919
# {"notificationType":"IgnitionStatus"         254
# {"notificationType":"ParkingHeartbeat"       104
# {"notificationType":"DataUsage"               72
# {"notificationType":"CameraEvent"             17
# {"notificationType":"MaintenanceWarning"       3
# Name: count, dtype: int64

# %%
lul650_events=lul650[lul650['Message'].str.contains('CameraEvent')]
lul650_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    9
# event:"POTENTIAL_INCIDENT_LOW"       4
# event:"HARD_BRAKE"                   3
# event:"SHARP_TURN"                   1
# Name: count, dtype: int64

# %%
lul650_events['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"FORWARD_COLLISION"     9
# eventCategory:"POTENTIAL_INCIDENT"    4
# eventCategory:"HARD_BRAKE"            3
# eventCategory:"SHARP_TURN"            1
# Name: count, dtype: int64

# %% [markdown]
# ett651 145W March 01 to March 26

# %%
ett651=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gestion_residuos\ett651_march_columns.csv',sep=',')
ett651.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8776 entries, 0 to 8775
# Columns: 104 entries, Message to Unnamed: 103
# dtypes: float64(4), str(100)
# memory usage: 7.0 MB
# C:\Users\Jose.Hurtado\AppData\Local\Temp\ipykernel_21524\613221358.py:1: DtypeWarning: Columns (0: Unnamed: 92, 1: Unnamed: 93, 2: Unnamed: 95, 3: Unnamed: 96, 4: Unnamed: 97, 5: Unnamed: 98, 6: Unnamed: 99, 7: Unnamed: 100, 8: Unnamed: 101, 9: Unnamed: 102, 10: Unnamed: 103) have mixed types. Specify dtype option on import or set low_memory=False.
#   ett651=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gestion_residuos\ett651_march_columns.csv',sep=',')

# %%
ett651['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              4882
# {"notificationType":"CameraRunningInfo"     2059
# {"notificationType":"AutoSnapshot"          1262
# {"notificationType":"IgnitionStatus"         376
# {"notificationType":"CameraEvent"             77
# {"notificationType":"ParkingHeartbeat"        56
# {"notificationType":"DataUsage"               55
# {"notificationType":"MaintenanceWarning"       9
# Name: count, dtype: int64

# %%
ett651_events=ett651[ett651['Message'].str.contains('CameraEvent')]
ett651_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"NO_SEATBELT"                  39
# event:"USING_PHONE"                  16
# event:"FORWARD_COLLISION_WARNING"    10
# event:"DROWSINESS"                    8
# event:"SHARP_TURN"                    2
# event:"POTENTIAL_INCIDENT_LOW"        1
# event:"POTENTIAL_INCIDENT_MEDIUM"     1
# Name: count, dtype: int64

# %%
ett651_events['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"                   63
# eventCategory:"FORWARD_COLLISION"     10
# eventCategory:"POTENTIAL_INCIDENT"     2
# eventCategory:"SHARP_TURN"             2
# Name: count, dtype: int64

# %% [markdown]
# lul650 145W March 01 to March 26

# %%
lul650=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gestion_residuos\lul650_march_columns.csv',sep=',')
lul650.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6952 entries, 0 to 6951
# Columns: 116 entries, Message to Unnamed: 115
# dtypes: float64(5), str(111)
# memory usage: 6.2 MB

# %%
lul650['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"              3938
# {"notificationType":"CameraRunningInfo"     1528
# {"notificationType":"AutoSnapshot"           962
# {"notificationType":"IgnitionStatus"         269
# {"notificationType":"CameraEvent"             95
# {"notificationType":"DataUsage"               94
# {"notificationType":"ParkingHeartbeat"        61
# {"notificationType":"MaintenanceWarning"       5
# Name: count, dtype: int64

# %%
lul650_events=lul650[lul650['Message'].str.contains('CameraEvent')]
lul650_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"DROWSINESS"                   34
# event:"USING_PHONE"                  31
# event:"NO_SEATBELT"                  15
# event:"POTENTIAL_INCIDENT_LOW"        7
# event:"FORWARD_COLLISION_WARNING"     5
# event:"SHARP_TURN"                    2
# event:"HARD_BRAKE"                    1
# Name: count, dtype: int64

# %%
lul650_events['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"                   80
# eventCategory:"POTENTIAL_INCIDENT"     7
# eventCategory:"FORWARD_COLLISION"      5
# eventCategory:"SHARP_TURN"             2
# eventCategory:"HARD_BRAKE"             1
# Name: count, dtype: int64
