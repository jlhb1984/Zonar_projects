# %%
import pandas as pd 
import numpy as np
import datetime

# %% [markdown]
# Camera matrix: 8B52211M
# Firmware: 3.38.951
# Serial: 8B52211M

# %% [markdown]
# 8B52211M

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\standby\8B52211M.csv',sep=',')
vf.info()
print("vf since",vf.iloc[0,3],"to ",vf.iloc[vf.shape[0]-1,3])
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     1253 non-null   int64
#  1   Sequence #                 0 non-null      float64
#  2   Server Time                1253 non-null   str
#  3   Unit Time                  1253 non-null   str
#  4   Last Message Time          1253 non-null   str
#  5   Latitude                   1253 non-null   float64
#  6   Longitude                  1253 non-null   float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 1253 non-null   str
#  9   Raw Event                  1253 non-null   str
#  10  Address                    1253 non-null   str
#  11  GPS Speed                  1232 non-null   float64
#  12  ECU Speed                  0 non-null      float64
#  13  Speed Limit                400 non-null    float64
#  14  Heading                    1250 non-null   float64
#  15  Ignition Status            1253 non-null   str
#  16  Notification Type          1253 non-null   str
#  17  Trip Id                    1253 non-null   str
#  18  Picture Id                 167 non-null    float64
#  19  Event Category             14 non-null     str
#  20  Event Level                14 non-null     str
#  21  Camera Clip Key            14 non-null     float64
#  22  Camera Clip Offset         14 non-null     float64
#  23  Clip Id                    14 non-null     float64
#  24  Duration                   0 non-null      float64
#  25  Rotate                     167 non-null    str
#  26  Camera Status              0 non-null      float64
#  27  Idle Status                1041 non-null   str
#  28  SDCard Status              0 non-null      float64
#  29  Data Usage In KB           0 non-null      float64
#  30  Transaction Id             0 non-null      float64
#  31  Status                     0 non-null      float64
#  32  Error Msg                  0 non-null      float64
#  33  Valid Time Range           0 non-null      float64
#  34  Warning                    0 non-null      float64
#  35  Distance                   1252 non-null   float64
#  36  Accumulated Distance       1008 non-null   float64
#  37  Engine Hours               1253 non-null   float64
#  38  Engine Hours + Off         1253 non-null   float64
#  39  ECU Engine Hours           1253 non-null   int64
#  40  ECU Engine Hours + Off     1253 non-null   int64
#  41  Engine Odometer            1253 non-null   float64
#  42  Engine Odometer + Off      1253 non-null   float64
#  43  ECU Engine Odometer        1253 non-null   int64
#  44  ECU Engine Odometer + Off  1253 non-null   int64
#  45  HDOP                       210 non-null    float64
#  46  VDOP                       0 non-null      float64
#  47  RSSI                       0 non-null      float64
#  48  Battery Level              0 non-null      float64
#  49  Raw Data                   1253 non-null   str
# dtypes: float64(31), int64(5), str(14)
# memory usage: 489.6 KB
# vf since 2026/05/06 15:15:02 to  2026/05/04 07:01:31

# %%
vf['Raw Event'].value_counts()
# Out:
# Raw Event
# GpsData.Idling                           618
# GpsData.Moving                           350
# AutoSnapshot                             158
# TravelStop                                46
# TravelStart                               46
# CameraEvent.NO_SEATBELT                   12
# IgnitionStatus.parking                    11
# IgnitionStatus.driving                    11
# CameraEvent.POTENTIAL_INCIDENT_MEDIUM      1
# Name: count, dtype: int64

# %%
vf_dms=vf[vf['Raw Event'].str.contains('CameraEvent')]
vf_dms['Raw Event'].value_counts()
# Out:
# Raw Event
# CameraEvent.NO_SEATBELT                  12
# CameraEvent.POTENTIAL_INCIDENT_MEDIUM     1
# Name: count, dtype: int64

# %%
vf['Engine Odometer']
# Out:
# 0       924.43
# 1       924.43
# 2       924.43
# 3       924.43
# 4       924.43
#          ...
# 1248    782.54
# 1249    782.54
# 1250    782.54
# 1251    782.54
# 1252    782.54
# Name: Engine Odometer, Length: 1253, dtype: float64
