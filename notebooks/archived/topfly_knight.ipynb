# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# 869487062724710 with motion 30s. Colombian unit.

# %%
raw_data_869487062724710=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062724710_2226_022026.csv',sep=',')
raw_data_869487062724710.info()
raw_data_869487062724710['Event Name'].value_counts()
print(raw_data_869487062724710.iloc[(raw_data_869487062724710.shape[0]-1),3],' -> ',raw_data_869487062724710.iloc[0,3])
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     1040 non-null   int64
#  1   Sequence #                 1040 non-null   int64
#  2   Account Id                 1040 non-null   int64
#  3   Server Time                1040 non-null   str
#  4   Unit Time                  1040 non-null   str
#  5   Latitude                   1040 non-null   float64
#  6   Longitude                  1040 non-null   float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 1040 non-null   str
#  9   Raw Event                  1040 non-null   str
#  10  GPS Speed                  1040 non-null   float64
#  11  ECU Speed                  0 non-null      float64
#  12  Address                    1040 non-null   str
#  13  Landmark ID                6 non-null      float64
# ...

# %%
motion=raw_data_869487062724710[raw_data_869487062724710['Event Name'].str.contains('Motion')]
only_motion=motion[~motion['Event Name'].str.contains('Motion S')]
#only_motion.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062724710_2226_022026_motion.csv')

# %%
raw_data_869487062724710['Event Name'].value_counts()
# Out:
# Event Name
# Motion          637
# Update          347
# Motion Stop      38
# Motion Start     18
# Name: count, dtype: int64

# %%
ts_events=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\troubleshootingevents_180b6743-112d-42d3-9203-4fd59fd20f62.csv',sep=',')
ts_events.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unit Time    211 non-null    str
#  1   Data Center  211 non-null    str
#  2   Voltage      0 non-null      float64
#  3   Latitude     71 non-null     float64
#  4   Longitude    71 non-null     float64
#  5   Raw Event    211 non-null    str
#  6   Event Name   211 non-null    str
#  7   Heading      71 non-null     float64
#  8   Sequence #   211 non-null    int64
#  9   GPS Speed    71 non-null     float64
#  10  Address      0 non-null      float64
#  11  Unit Type    211 non-null    str
#  12  Raw Data     211 non-null    str
# dtypes: float64(6), int64(1), str(6)
# memory usage: 21.6 KB

# %%
cont=0
for i in range(0,ts_events.shape[0]):
    if ts_events.iloc[i,6]=='User Update':
        cont=cont+1
        print('Event created on: ',ts_events.iloc[i,0])
print("Number of \'User Update\' events: ",cont)
# Out:
# Event created on:  2026/03/03 09:39:02 -05
# Event created on:  2026/03/03 09:17:56 -05
# Event created on:  2026/03/03 09:03:32 -05
# Event created on:  2026/03/03 08:58:06 -05
# Event created on:  2026/03/03 08:23:59 -05
# Number of 'User Update' events:  5

# %% [markdown]
# 869487062909196 wth motion 30s. Peruvian unit.

# %%
raw_data_869487062909196=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062909196_2226_022026.csv',sep=',')
raw_data_869487062909196.info()
print(raw_data_869487062909196.iloc[(raw_data_869487062909196.shape[0]-1),3],' -> ',raw_data_869487062909196.iloc[0,3])
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     124 non-null    int64
#  1   Sequence #                 124 non-null    int64
#  2   Account Id                 124 non-null    int64
#  3   Server Time                124 non-null    str
#  4   Unit Time                  124 non-null    str
#  5   Latitude                   124 non-null    float64
#  6   Longitude                  124 non-null    float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 124 non-null    str
#  9   Raw Event                  124 non-null    str
#  10  GPS Speed                  124 non-null    float64
#  11  ECU Speed                  0 non-null      float64
#  12  Address                    124 non-null    str
#  13  Landmark ID                0 non-null      float64
# ...

# %%
motion=raw_data_869487062909196[raw_data_869487062909196['Event Name'].str.contains('Motion')]
only_motion=motion[~motion['Event Name'].str.contains('Motion S')]
#only_motion
only_motion.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062909196_2226_022026_motion.csv')

# %%
raw_data_869487062909196['Event Name'].value_counts()
# Out:
# Event Name
# Motion          112
# Update            5
# Motion Stop       4
# Motion Start      3
# Name: count, dtype: int64

# %% [markdown]
# 869487062905251 with motion 1min. Peruvian unit.

# %%
raw_data_869487062905251=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062905251_2226_022026.csv',sep=',')
raw_data_869487062905251.info()
print(raw_data_869487062905251.iloc[0,3],' -> ',raw_data_869487062905251.iloc[(raw_data_869487062905251.shape[0]-1),3],)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     73 non-null     int64
#  1   Sequence #                 73 non-null     int64
#  2   Account Id                 73 non-null     int64
#  3   Server Time                73 non-null     str
#  4   Unit Time                  73 non-null     str
#  5   Latitude                   73 non-null     float64
#  6   Longitude                  73 non-null     float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 73 non-null     str
#  9   Raw Event                  73 non-null     str
#  10  GPS Speed                  73 non-null     float64
#  11  ECU Speed                  0 non-null      float64
#  12  Address                    73 non-null     str
#  13  Landmark ID                0 non-null      float64
# ...

# %%
motion=raw_data_869487062905251[raw_data_869487062905251['Event Name'].str.contains('Motion')]
only_motion=motion[~motion['Event Name'].str.contains('Motion S')]
#only_motion
only_motion.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062905251_2226_022026_motion.csv')

# %%
raw_data_869487062905251['Event Name'].value_counts()
# Out:
# Event Name
# Motion          58
# Update           8
# Motion Stop      4
# Motion Start     3
# Name: count, dtype: int64

# %% [markdown]
# GL300W comparison:

# %%
raw_data=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\Export_gl300w.csv',sep=',')
hl=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\historicallocationsgl300w.csv',sep=',')
aux_m=[]

for i in range(0,raw_data.shape[0]):
    aux_m.append(raw_data.iloc[i,1][6:11])
raw_data['Message_Type']=aux_m

raw_data['Message_Type'].value_counts()
hl['Events'].value_counts()
# Out:
# Events
# Parked              7147
# Idle - Stop         1515
# Drive               1418
# Speed alert          153
# Stopped Charging      24
# Power Cut             24
# Power Restored        24
# Start Charging        21
# Battery Warning       12
# Self Test/Reboot       1
# Name: count, dtype: int64

# %%
hl_drive=hl[hl['Events'].str.contains('Drive')]
hl_drive.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\drive_gl300.csv')

# %% [markdown]
# Because of Queclink GL300W does not have a similar event to "Update", for TopFly Knight, Update can be set to 6 hours. This was confirmed bY Gerardo Loaiza on Friday 27-02-2026.

# %% [markdown]
# # Script with the first edition.

# %% [markdown]
# 869487062724710 with motion 30s. Colombian unit.

# %%
raw_data_869487062724710=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062724710.csv',sep=',')
raw_data_869487062724710['Event Name'].value_counts()
# Out:
# Event Name
# Motion          193
# Update           94
# Motion Stop       9
# User Update       9
# Motion Start      7
# Name: count, dtype: int64

# %% [markdown]
# Date of panic button:
#
# 9:44, 9:44 -> 2026/03/06 9:44:43
#
# 9:45 -> 2026/03/06 9:45:17
#
# 9:46 -> 2026/03/06 9:46:17
#
# 9:48 -> 2026/03/06 9:48:38
#
# 9:50 -> 2026/03/06 9:50:17
#
# 9:51 -> 2026/03/06 9:51:56
#
# 9:53 -> 2026/03/06 9:53:17
#
# 9:58 -> 2026/03/06 9:58:35
#
# 10:09 -> 2026/03/06 10:08:54
#
# 10:10 (indoor) Without register.

# %%
raw_data_869487062724710_user_update=raw_data_869487062724710[raw_data_869487062724710['Event Name'].str.contains('User Update')]
raw_data_869487062724710_user_update[['Server Time','Unit Time','Latitude','Longitude','Event Name']]
# Out:
#             Server Time            Unit Time  Latitude  Longitude   Event Name
# 26  2026/03/06 10:08:54  2026/03/06 10:08:37  3.464569 -76.525940  User Update
# 35   2026/03/06 9:58:35   2026/03/06 9:58:34  3.464569 -76.525940  User Update
# 46   2026/03/06 9:53:17   2026/03/06 9:53:17  3.463692 -76.525360  User Update
# 49   2026/03/06 9:51:56   2026/03/06 9:51:56  3.463189 -76.525772  User Update
# 53   2026/03/06 9:50:17   2026/03/06 9:50:17  3.462468 -76.526176  User Update
# 57   2026/03/06 9:48:38   2026/03/06 9:48:38  3.463259 -76.526871  User Update
# 62   2026/03/06 9:46:17   2026/03/06 9:46:17  3.463941 -76.526634  User Update
# 64   2026/03/06 9:45:17   2026/03/06 9:45:17  3.464389 -76.526573  User Update
# 66   2026/03/06 9:44:43   2026/03/06 9:44:42  3.465162 -76.525902  User Update

# %%
raw_data_869487062724710_motion=raw_data_869487062724710[raw_data_869487062724710['Event Name'].str.contains('Motion')]
raw_data_869487062724710_motion_filtered=raw_data_869487062724710_motion[['Server Time','Unit Time','Latitude','Longitude','Sequence #','Event Name']]
#raw_data_869487062724710_motion.info()
raw_data_869487062724710_motion_filtered.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062724710_motion_30s.csv')

# %%
raw_data_869487062724710_motion_filtered['Server Time'].value_counts()
# Out:
# Server Time
# 2026/03/02 7:26:50     3
# 2026/03/06 10:22:44    2
# 2026/03/01 12:51:28    2
# 2026/03/06 10:25:17    1
# 2026/03/06 10:25:14    1
#                       ..
# 2026/03/01 10:56:50    1
# 2026/03/01 10:56:26    1
# 2026/03/01 10:55:56    1
# 2026/03/01 10:55:26    1
# 2026/03/01 10:54:55    1
# Name: count, Length: 205, dtype: int64

# %%
ts_events_869487062724710=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\troubleshootingevents_869487062724710.csv',sep=',')
ts_events_869487062724710['Event Name'].value_counts()
# Out:
# Event Name
# Comm Acquired    152
# Motion            58
# Update            29
# Device Info       19
# Motion Start      14
# Motion Stop       11
# User Update        8
# Name: count, dtype: int64

# %%
ts_events_869487062724710_user_update=ts_events_869487062724710[ts_events_869487062724710['Event Name'].str.contains('User Update')]
ts_events_869487062724710_user_update[['Unit Time','Latitude','Longitude','Event Name']]
# Out:
#                    Unit Time  Latitude  Longitude   Event Name
# 2    2026/03/06 09:44:21 -05       0.0        0.0  User Update
# 25   2026/03/06 08:50:12 -05       0.0        0.0  User Update
# 54   2026/03/05 14:31:06 -05       0.0        0.0  User Update
# 94   2026/03/03 09:39:02 -05       0.0        0.0  User Update
# 100  2026/03/03 09:17:56 -05       0.0        0.0  User Update
# 103  2026/03/03 09:03:32 -05       0.0        0.0  User Update
# 105  2026/03/03 08:58:06 -05       0.0        0.0  User Update
# 118  2026/03/03 08:23:59 -05       0.0        0.0  User Update

# %%
ts_events_869487062724710['Unit Time'].value_counts()
# Out:
# Unit Time
# 2026/03/06 09:42:02 -05    2
# 2026/03/06 08:45:31 -05    2
# 2026/03/05 21:51:55 -05    2
# 2026/03/05 10:17:29 -05    2
# 2026/03/03 22:37:53 -05    2
#                           ..
# 2026/02/28 20:49:48 -05    1
# 2026/02/28 20:29:47 -05    1
# 2026/02/28 20:09:45 -05    1
# 2026/02/28 19:35:45 -05    1
# 2026/02/28 19:25:46 -05    1
# Name: count, Length: 285, dtype: int64

# %% [markdown]
# 869487062724710 with motion 1min. Colombian unit.

# %%
raw_data_869487062724710=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_0610_0326.csv',sep=',')
raw_data_869487062724710['Event Name'].value_counts()
# Out:
# Event Name
# Motion          445
# Motion Stop      31
# User Update      16
# Motion Start     15
# Update            7
# Name: count, dtype: int64

# %%
raw_data_869487062724710_user_update=raw_data_869487062724710[raw_data_869487062724710['Event Name'].str.contains('User Update')]
raw_data_869487062724710_user_update[['Server Time','Unit Time','Latitude','Longitude','Event Name']]
# Out:
#              Server Time            Unit Time  Latitude  Longitude  \
# 3    2026/03/10 10:48:13  2026/03/10 10:48:13  3.464750 -76.525917
# 5    2026/03/10 10:46:11  2026/03/10 10:46:11  3.463747 -76.525299
# 6    2026/03/10 10:45:10  2026/03/10 10:45:10  3.463123 -76.525719
# 7    2026/03/10 10:44:05  2026/03/10 10:44:04  3.462577 -76.526245
# 8    2026/03/10 10:42:41  2026/03/10 10:42:41  3.463151 -76.526970
# 10   2026/03/10 10:41:18  2026/03/10 10:41:18  3.463962 -76.526649
# 11   2026/03/10 10:39:59  2026/03/10 10:39:59  3.464663 -76.526474
# 473  2026/03/06 10:08:54  2026/03/06 10:08:37  3.464569 -76.525940
# 482  2026/03/06 09:58:35  2026/03/06 09:58:34  3.464569 -76.525940
# 493  2026/03/06 09:53:17  2026/03/06 09:53:17  3.463692 -76.525360
# 496  2026/03/06 09:51:56  2026/03/06 09:51:56  3.463189 -76.525772
# 500  2026/03/06 09:50:17  2026/03/06 09:50:17  3.462468 -76.526176
# 504  2026/03/06 09:48:38  2026/03/06 09:48:38  3.463259 -76.526871
# ...

# %%
raw_data_869487062724710_motion=raw_data_869487062724710[raw_data_869487062724710['Event Name'].str.contains('Motion')]
raw_data_869487062724710_motion_filtered=raw_data_869487062724710_motion[['Server Time','Unit Time','Latitude','Longitude','Sequence #','Event Name']]
#raw_data_869487062724710_motion.info()
raw_data_869487062724710_motion_filtered.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062724710_motion_1min.csv')

# %%
raw_data_869487062724710_motion_filtered['Server Time'].value_counts()
# Out:
# Server Time
# 2026/03/07 22:04:45    2
# 2026/03/06 10:22:44    2
# 2026/03/10 10:52:02    1
# 2026/03/10 10:51:24    1
# 2026/03/10 10:49:23    1
#                       ..
# 2026/03/06 09:47:50    1
# 2026/03/06 09:47:19    1
# 2026/03/06 09:46:48    1
# 2026/03/06 09:45:48    1
# 2026/03/06 09:45:00    1
# Name: count, Length: 489, dtype: int64

# %% [markdown]
# Date of panic button:
#
# 10:39 -> 2026/03/10 10:39:59
#
# 10:40 -> 2026/03/10 10:41:18
#
# 10:41 -> 2026/03/10 10:42:41
#
# 10:42 -> 2026/03/10 10:42:41
#
# 10:44 -> 2026/03/10 10:44:04
#
# 10:45 -> 2026/03/10 10:45:10
#
# 10:46 -> 2026/03/10 10:46:11
#
# 10:48 -> 2026/03/10 10:48:13

# %% [markdown]
# 869487062909196 with motion 30s. Peruvian unit.

# %%
raw_data_869487062909196=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062909196_1011_032026.csv',sep=',')
raw_data_869487062909196.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     165 non-null    int64
#  1   Sequence #                 165 non-null    int64
#  2   Account Id                 165 non-null    int64
#  3   Server Time                165 non-null    str
#  4   Unit Time                  165 non-null    str
#  5   Latitude                   165 non-null    float64
#  6   Longitude                  165 non-null    float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 165 non-null    str
#  9   Raw Event                  165 non-null    str
#  10  GPS Speed                  165 non-null    float64
#  11  ECU Speed                  0 non-null      float64
#  12  Address                    165 non-null    str
#  13  Landmark ID                0 non-null      float64
# ...

# %%
raw_data_869487062909196_user_update=raw_data_869487062909196[raw_data_869487062909196['Event Name'].str.contains('User Update')]
raw_data_869487062909196_user_update[['Server Time','Unit Time','Latitude','Longitude','Event Name']]
# Out:
#             Server Time            Unit Time   Latitude  Longitude  \
# 22  2026/03/10 15:53:01  2026/03/10 15:53:00 -12.117382 -77.005997
# 77  2026/03/10 15:24:37  2026/03/10 15:24:37 -12.117382 -77.005997
# 79  2026/03/10 15:24:10  2026/03/10 15:24:00 -12.117479 -77.005997
#
#      Event Name
# 22  User Update
# 77  User Update
# 79  User Update

# %%
raw_data_869487062909196_motion=raw_data_869487062909196[raw_data_869487062909196['Event Name'].str.contains('Motion')]
raw_data_869487062909196_motion_filtered=raw_data_869487062909196_motion[['Server Time','Unit Time','Latitude','Longitude','Sequence #','Event Name']]
#raw_data_869487062724710_motion_filtered
raw_data_869487062909196_motion_filtered.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062909196_motion_30s.csv')

# %% [markdown]
# 869487062905251 with motion 1 min. Peruvian unit.

# %%
raw_data_869487062905251=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062905251_1011_032026.csv',sep=',')
raw_data_869487062905251.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     84 non-null     int64
#  1   Sequence #                 84 non-null     int64
#  2   Account Id                 84 non-null     int64
#  3   Server Time                84 non-null     str
#  4   Unit Time                  84 non-null     str
#  5   Latitude                   84 non-null     float64
#  6   Longitude                  84 non-null     float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 84 non-null     str
#  9   Raw Event                  84 non-null     str
#  10  GPS Speed                  84 non-null     float64
#  11  ECU Speed                  0 non-null      float64
#  12  Address                    84 non-null     str
#  13  Landmark ID                0 non-null      float64
# ...

# %%
raw_data_869487062905251_user_update=raw_data_869487062905251[raw_data_869487062905251['Event Name'].str.contains('User Update')]
raw_data_869487062905251_user_update[['Server Time','Unit Time','Latitude','Longitude','Event Name']]
# Out:
#             Server Time            Unit Time   Latitude  Longitude  \
# 9   2026/03/10 15:52:53  2026/03/10 15:52:51 -12.117308 -77.006012
# 36  2026/03/10 15:24:21  2026/03/10 15:24:19 -12.117610 -77.006172
# 37  2026/03/10 15:23:51  2026/03/10 15:23:49 -12.117610 -77.006172
#
#      Event Name
# 9   User Update
# 36  User Update
# 37  User Update

# %%
raw_data_869487062905251_motion=raw_data_869487062905251[raw_data_869487062905251['Event Name'].str.contains('Motion')]
raw_data_869487062905251_motion_filtered=raw_data_869487062905251_motion[['Server Time','Unit Time','Latitude','Longitude','Sequence #','Event Name']]
#raw_data_869487062724710_motion_filtered
raw_data_869487062905251_motion_filtered.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062905251_motion_1min.csv')

# %% [markdown]
# I found Stop events without Start events in Raw Data. 869487062724710 Colombian unit.

# %%
unit_869487062724710_1min=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062724710_motion_1min.csv',sep=',')
print("Data since: ",unit_869487062724710_1min.iloc[unit_869487062724710_1min.shape[0]-1,1]," until ", unit_869487062724710_1min.iloc[0,1])
unit_869487062724710_1min['Event Name'].value_counts()
# Out:
# Data since:  2026/03/06 09:45:00  until  2026/03/10 10:52:02
# Event Name
# Motion          445
# Motion Stop      31
# Motion Start     15
# Name: count, dtype: int64

# %%
ts_unit_869487062724710_1min=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\troubleshootingevents_869487062724710_0610_032026.csv',sep=',')
print("Data since: ",ts_unit_869487062724710_1min.iloc[ts_unit_869487062724710_1min.shape[0]-1,0]," until ", ts_unit_869487062724710_1min.iloc[0,0])
ts_unit_869487062724710_1min['Event Name'].value_counts()
# Out:
# Data since:  2026/03/05 21:51:55 -05  until  2026/03/10 18:44:18 -05
# Event Name
# Motion           57
# Comm Acquired    55
# Device Info      29
# Motion Start     22
# Motion Stop       9
# Update            9
# User Update       3
# Name: count, dtype: int64

# %%
motion=pd.concat([ts_unit_869487062724710_1min[['Event Name','Unit Time']],unit_869487062724710_1min[['Event Name','Unit Time']]])
motion_filtered=motion[motion['Event Name'].str.contains('Motion S')]
motion_filtered.sort_values('Unit Time').to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\motion_filtered1.csv')
motion['Event Name'].value_counts()
# Out:
# Event Name
# Motion           502
# Comm Acquired     55
# Motion Stop       40
# Motion Start      37
# Device Info       29
# Update             9
# User Update        3
# Name: count, dtype: int64

# %%
unit_869487062724710_30s=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062724710_motion_30s.csv',sep=',')
print("Data since: ",unit_869487062724710_30s.iloc[unit_869487062724710_30s.shape[0]-1,1]," until ", unit_869487062724710_30s.iloc[0,1])
unit_869487062724710_30s['Event Name'].value_counts()
# Out:
# Data since:  2026/03/01 10:54:55  until  2026/03/06 10:25:17
# Event Name
# Motion          193
# Motion Stop       9
# Motion Start      7
# Name: count, dtype: int64

# %%
unit_869487062905251_1min=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062905251_motion_1min.csv',sep=',')
print("Data since: ",unit_869487062905251_1min.iloc[unit_869487062905251_1min.shape[0]-1,1]," until ",unit_869487062905251_1min.iloc[0,1])
unit_869487062905251_1min['Event Name'].value_counts()
# Out:
# Data since:  2026/03/10 10:13:40  until  2026/03/10 16:02:17
# Event Name
# Motion          74
# Motion Stop      4
# Motion Start     3
# Name: count, dtype: int64

# %%
unit_869487062909196_30s=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_869487062909196_motion_30s.csv',sep=',')
print("Data since: ",unit_869487062909196_30s.iloc[unit_869487062909196_30s.shape[0]-1,1]," until ",unit_869487062909196_30s.iloc[0,1])
unit_869487062909196_30s['Event Name'].value_counts()
# Out:
# Data since:  2026/03/10 10:14:03  until  2026/03/10 20:56:08
# Event Name
# Motion          154
# Motion Stop       6
# Motion Start      1
# Name: count, dtype: int64

# %% [markdown]
# New analysis 16-03-2026 to 18-03-2026.
# Greg started the data acquisition with a listener on 13-03-2026 12:36 with 869487062724710.

# %%
unit_869487062724710_1min=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\rawdata_March16_2026_to_March18_2026_869487062724710.csv',sep=',')
print("Data since: ",unit_869487062724710_1min.iloc[unit_869487062724710_1min.shape[0]-1,4]," until ", unit_869487062724710_1min.iloc[0,4])
unit_869487062724710_1min['Event Name'].value_counts()
# Out:
# Data since:  2026/03/16 07:33:11  until  2026/03/18 15:17:29
# Event Name
# Motion          567
# Update           57
# Motion Stop      48
# Motion Start      6
# Name: count, dtype: int64

# %%
ts_unit_869487062724710_1min=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\troubleshootingevents_March16_2026_to_March18_2026_869487062724710.csv',sep=',')
print("Data since: ",ts_unit_869487062724710_1min.iloc[ts_unit_869487062724710_1min.shape[0]-1,0]," until ", ts_unit_869487062724710_1min.iloc[0,0])
ts_unit_869487062724710_1min['Event Name'].value_counts()
# Out:
# Data since:  2026/03/15 22:10:32 -05  until  2026/03/18 15:17:03 -05
# Event Name
# Motion           85
# Comm Acquired    49
# Motion Start     40
# Device Info      18
# Update           12
# Motion Stop      10
# Name: count, dtype: int64

# %%
motion=pd.concat([ts_unit_869487062724710_1min[['Event Name','Unit Time','Sequence #']],unit_869487062724710_1min[['Event Name','Unit Time','Sequence #']]])
motion_filtered=motion[motion['Event Name'].str.contains('Motion S')]
motion_filtered.sort_values('Unit Time').to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zonar\motion_filtered1_19032026.csv')
motion['Event Name'].value_counts()
# Out:
# Event Name
# Motion           652
# Update            69
# Motion Stop       58
# Comm Acquired     49
# Motion Start      46
# Device Info       18
# Name: count, dtype: int64
