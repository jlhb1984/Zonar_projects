# %%
import pandas as pd
import numpy as np

# %%
hlbpm788=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\lely\historicallocations.xlsx')
hlbpm788.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     307 non-null    int64
#  1   Unit         307 non-null    str
#  2   Events       307 non-null    str
#  3   Date         307 non-null    str
#  4   Landmark     0 non-null      float64
#  5   Address      307 non-null    str
#  6   Speed        307 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     307 non-null    float64
#  10  Longitude    307 non-null    float64
# dtypes: float64(5), int64(2), str(4)
# memory usage: 26.5 KB

# %%
hlbpm788['Events'].value_counts()
# Out:
# Events
# Drive             295
# Idle - Stop         8
# End Speeding        1
# Alta velocidad      1
# Ignition ON         1
# Parked              1
# Name: count, dtype: int64

# %%
hlbpm788_over_speed=hlbpm788[hlbpm788['Events'].str.contains('Alta velocidad')]
hlbpm788_over_speed
# Out:
#      Sequence     Unit          Events                  Date  Landmark  \
# 269        38  BPM-788  Alta velocidad  May 26 2026 06:28 AM       NaN
#
#                                    Address  Speed  Temperature  Driver  \
# 269  Pe-3n-56, Catac, Recuay, Ancash, Perú     80          NaN     NaN
#
#      Latitude  Longitude
# 269 -9.689641 -77.466393
