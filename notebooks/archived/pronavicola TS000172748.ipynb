# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ars=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\Activity Report Summarized_es.csv',sep=',')
ars.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GroupName       0 non-null      float64
#  1   UnitID          48 non-null     str
#  2   UnitName1       48 non-null     str
#  3   MaxSpeed        48 non-null     int64
#  4   MilesDriven     48 non-null     str
#  5   TravelTimeSecs  48 non-null     str
#  6   Textbox3        48 non-null     str
#  7   IdleTimeSecs    48 non-null     str
#  8   Textbox6        48 non-null     str
#  9   IdleTimeSecs2   48 non-null     str
#  10  Textbox11       48 non-null     str
#  11  Textbox20       48 non-null     str
#  12  Textbox21       48 non-null     str
#  13  Textbox24       48 non-null     str
#  14  Textbox25       48 non-null     str
#  15  Textbox26       48 non-null     str
#  16  Textbox27       48 non-null     str
#  17  Textbox28       48 non-null     str
# dtypes: float64(1), int64(1), str(16)
# memory usage: 6.9 KB

# %%
for i in range(0, ars.shape[0]):
    if ars.iloc[i,4]=='0,00':
        print(ars.iloc[i,1],ars.iloc[i,2],ars.iloc[i,3],ars.iloc[i,4])
# Out:
# 1EJQ SSL004 93 0,00
# 05VC SSL051 84 0,00
# 05UO SSL054 0 0,00
# 12MO SSL289 89 0,00
# 1BFY SSL352 111 0,00
# 0SMN SSL362 100 0,00
# 0VLQ SSL375 103 0,00
# 14CL SSL466 111 0,00
# 17G1 SSL480 134 0,00
# 0UJ7 VMB721 80 0,00

# %% [markdown]
# SSL004 - 352556102294845

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\ssl004.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10699 entries, 0 to 10698
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  10699 non-null  str
#  1   Message  10699 non-null  str
#  2   Status   10699 non-null  str
# dtypes: str(3)
# memory usage: 250.9 KB

# %% [markdown]
# Odometer

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#        Odometer in  Odometer en miles
# 0                0                0.0
# 1                0                0.0
# 2                0                0.0
# 3                0                0.0
# 4                0                0.0
# ...            ...                ...
# 10694            0                0.0
# 10695            0                0.0
# 10696            0                0.0
# 10697            0                0.0
# 10698            0                0.0
#
# [10699 rows x 2 columns]

# %% [markdown]
# SSL051 - 352556102036758

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\ssl051.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1956 entries, 0 to 1955
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  1956 non-null   str
#  1   Message  1956 non-null   str
#  2   Status   1956 non-null   str
# dtypes: str(3)
# memory usage: 46.0 KB

# %% [markdown]
# Odometer

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#       Odometer in  Odometer en miles
# 0               0           0.000000
# 1               0           0.000000
# 2             718           0.446144
# 3             718           0.446144
# 4             718           0.446144
# ...           ...                ...
# 1951        36795          22.863346
# 1952        36795          22.863346
# 1953            0           0.000000
# 1954            0           0.000000
# 1955            0           0.000000
#
# [1956 rows x 2 columns]

# %% [markdown]
# SSL054 no data available on April, more than 90days without report

# %% [markdown]
# SSL289 - 354514102533223

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\ssl289.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  10689 non-null  str
#  1   Message  10689 non-null  str
#  2   Status   10689 non-null  str
# dtypes: str(3)
# memory usage: 250.7 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#        Odometer in  Odometer en miles
# 0         85993056         53433.5912
# 1         85993056         53433.5912
# 2                0             0.0000
# 3         85993056         53433.5912
# 4                0             0.0000
# ...            ...                ...
# 10684            0             0.0000
# 10685            0             0.0000
# 10686            0             0.0000
# 10687            0             0.0000
# 10688            0             0.0000
#
# [10689 rows x 2 columns]

# %% [markdown]
# SSL352 - 359369091319901

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\ssl352.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21882 entries, 0 to 21881
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  21882 non-null  str
#  1   Message  21882 non-null  str
#  2   Status   21882 non-null  str
# dtypes: str(3)
# memory usage: 513.0 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#        Odometer in  Odometer en miles
# 0                0                0.0
# 1                0                0.0
# 2                0                0.0
# 3                0                0.0
# 4                0                0.0
# ...            ...                ...
# 21877            0                0.0
# 21878            0                0.0
# 21879            0                0.0
# 21880            0                0.0
# 21881            0                0.0
#
# [21882 rows x 2 columns]

# %% [markdown]
# SSL362 - 358077092508403

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\ssl362.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26058 entries, 0 to 26057
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  26058 non-null  str
#  1   Message  26058 non-null  str
#  2   Status   26058 non-null  str
# dtypes: str(3)
# memory usage: 610.9 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#        Odometer in  Odometer en miles
# 0                0                0.0
# 1                0                0.0
# 2                0                0.0
# 3                0                0.0
# 4                0                0.0
# ...            ...                ...
# 26053            0                0.0
# 26054            0                0.0
# 26055            0                0.0
# 26056            0                0.0
# 26057            0                0.0
#
# [26058 rows x 2 columns]

# %% [markdown]
# SSL375 - 354514101228312

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\ssl375.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15993 entries, 0 to 15992
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  15993 non-null  str
#  1   Message  15993 non-null  str
#  2   Status   15993 non-null  str
# dtypes: str(3)
# memory usage: 375.0 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#        Odometer in  Odometer en miles
# 0                0                0.0
# 1                0                0.0
# 2                0                0.0
# 3                0                0.0
# 4                0                0.0
# ...            ...                ...
# 15988            0                0.0
# 15989            0                0.0
# 15990            0                0.0
# 15991            0                0.0
# 15992            0                0.0
#
# [15993 rows x 2 columns]

# %% [markdown]
# SSL466 - 354514101234492

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\ssl476.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21274 entries, 0 to 21273
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  21274 non-null  str
#  1   Message  21274 non-null  str
#  2   Status   21274 non-null  str
# dtypes: str(3)
# memory usage: 498.7 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#        Odometer in  Odometer en miles
# 0                0                0.0
# 1                0                0.0
# 2                0                0.0
# 3                0                0.0
# 4                0                0.0
# ...            ...                ...
# 21269            0                0.0
# 21270            0                0.0
# 21271            0                0.0
# 21272            0                0.0
# 21273            0                0.0
#
# [21274 rows x 2 columns]

# %% [markdown]
# SSL480 - 354514102532076

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\ssl480.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19026 entries, 0 to 19025
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  19026 non-null  str
#  1   Message  19026 non-null  str
#  2   Status   19026 non-null  str
# dtypes: str(3)
# memory usage: 446.1 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#        Odometer in  Odometer en miles
# 0                0                0.0
# 1                0                0.0
# 2                0                0.0
# 3                0                0.0
# 4                0                0.0
# ...            ...                ...
# 19021            0                0.0
# 19022            0                0.0
# 19023            0                0.0
# 19024            0                0.0
# 19025            0                0.0
#
# [19026 rows x 2 columns]

# %% [markdown]
# VMB721 - 358077090719135

# %%
#unit=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',') #for csv files.
unit=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\pronaviicola\vmb721.xlsx') #For xls files.
unit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4926 entries, 0 to 4925
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  4926 non-null   str
#  1   Message  4926 non-null   str
#  2   Status   4926 non-null   str
# dtypes: str(3)
# memory usage: 115.6 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
unit_odometer=pd.DataFrame()
cont=0

for i in range (0,unit.shape[0]):
    l=len(unit.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(unit.iloc[i,2][68:76],16))
        aux_miles.append((int(unit.iloc[i,2][68:76],16))*0.000621371)
        cont=cont+1     

unit_odometer['Odometer in']=aux
unit_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

print(unit_odometer)
unit_odometer
plt.plot(x_axis,aux)
# Out:
#       Odometer in  Odometer en miles
# 0              70           0.043496
# 1              70           0.043496
# 2              70           0.043496
# 3              70           0.043496
# 4              70           0.043496
# ...           ...                ...
# 4921     51314690       31885.460240
# 4922     51314690       31885.460240
# 4923     51314690       31885.460240
# 4924     51314690       31885.460240
# 4925     51314690       31885.460240
#
# [4926 rows x 2 columns]
