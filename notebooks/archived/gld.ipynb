# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
raw_data=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gld\Export.csv',sep=',',encoding='latin1')
raw_datam=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gld\Exportm.csv',sep=',',encoding='latin1')
raw_datam.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam.info()
raw_datam.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\gld\Export_renamed.csv')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           2127 non-null   str
#  1   Message Type      2127 non-null   str
#  2   Protocole         2127 non-null   str
#  3   IMEI              2127 non-null   str
#  4   Serial            2127 non-null   str
#  5   Mileage           2127 non-null   str
#  6   Date              2127 non-null   str
#  7   Ignition          2127 non-null   str
#  8   Latitude          2127 non-null   str
#  9   Longitude         2127 non-null   str
#  10  Altitude          2127 non-null   str
#  11  External Power    2127 non-null   str
#  12  RPM               2127 non-null   str
#  13  Speed             2118 non-null   str
#  14  Satellite Number  2118 non-null   str
#  15  Azimuth           2118 non-null   str
#  16  Bettery level     2118 non-null   str
# dtypes: str(17)
# ...

# %%
raw_datam['Protocole'].value_counts()
# Out:
# Protocole
# ProtocolHeadType:19    2065
# ProtocolHeadType:20      53
# ProtocolHeadType:0        9
# Name: count, dtype: int64

# %%
raw_datam_filtered=raw_datam[~raw_datam['Protocole'].str.contains('ProtocolHeadType:0')]
raw_datam_filtered.info()

for i in range(0,raw_datam_filtered.shape[0]):
    if raw_datam_filtered.iloc[i,14]=="SatelliteNumber:0":
        print("Date: ",raw_datam_filtered.iloc[i,6],"Satellite Number: ",raw_datam_filtered.iloc[i,14])
# Out:
# <class 'pandas.DataFrame'>
# Index: 2118 entries, 0 to 2126
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           2118 non-null   str
#  1   Message Type      2118 non-null   str
#  2   Protocole         2118 non-null   str
#  3   IMEI              2118 non-null   str
#  4   Serial            2118 non-null   str
#  5   Mileage           2118 non-null   str
#  6   Date              2118 non-null   str
#  7   Ignition          2118 non-null   str
#  8   Latitude          2118 non-null   str
#  9   Longitude         2118 non-null   str
#  10  Altitude          2118 non-null   str
#  11  External Power    2118 non-null   str
#  12  RPM               2118 non-null   str
#  13  Speed             2118 non-null   str
#  14  Satellite Number  2118 non-null   str
#  15  Azimuth           2118 non-null   str
#  16  Bettery level     2118 non-null   str
# dtypes: str(17)
# memory usage: 297.8 KB
# ...
