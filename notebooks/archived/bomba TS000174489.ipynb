# %%
import pandas as pd
import numpy as np

# %%
br=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\bomba_foods\Basic Report.csv',sep=',')
br.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42194 entries, 0 to 42193
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Textbox13       42194 non-null  str
#  1   textbox4        42194 non-null  str
#  2   textbox5        42194 non-null  str
#  3   textbox6        42193 non-null  str
#  4   DistanceDriven  42194 non-null  str
#  5   textbox11       42193 non-null  str
#  6   textbox2        42194 non-null  int64
#  7   textbox7        42181 non-null  str
#  8   textbox14       42194 non-null  int64
# dtypes: int64(2), str(7)
# memory usage: 2.9 MB

# %%
parked=br[br['textbox5'].str.contains('Estacionado')]
parked[['textbox4','textbox5','textbox11']].to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\bomba_foods\parked.csv')

# %%
vcx925=parked[parked['textbox4'].str.contains('VCX925')]
vcx925
# Out:
#             Textbox13 textbox4     textbox5  \
# 35291  Distance (kms)   VCX925  Estacionado
# 35292  Distance (kms)   VCX925  Estacionado
# 35293  Distance (kms)   VCX925  Estacionado
# 35294  Distance (kms)   VCX925  Estacionado
# 35295  Distance (kms)   VCX925  Estacionado
# ...               ...      ...          ...
# 42131  Distance (kms)   VCX925  Estacionado
# 42189  Distance (kms)   VCX925  Estacionado
# 42190  Distance (kms)   VCX925  Estacionado
# 42191  Distance (kms)   VCX925  Estacionado
# 42192  Distance (kms)   VCX925  Estacionado
#
#                                   textbox6 DistanceDriven  \
# 35291  Carrera 36B Yumbo Valle del  760502           0,00
# 35292  Carrera 36B Yumbo Valle del  760502           0,00
# 35293  Carrera 36B Yumbo Valle del  760502           0,00
# 35294  Carrera 36B Yumbo Valle del  760502           0,00
# 35295  Carrera 36B Yumbo Valle del  760502           0,00
# ...                                    ...            ...
# ...

# %%
QOR044=parked[parked['textbox4'].str.contains('QOR044')]
QOR044
# Out:
#             Textbox13 textbox4     textbox5  \
# 34939  Distance (kms)   QOR044  Estacionado
# 34976  Distance (kms)   QOR044  Estacionado
# 34994  Distance (kms)   QOR044  Estacionado
# 35039  Distance (kms)   QOR044  Estacionado
# 35102  Distance (kms)   QOR044  Estacionado
# 35113  Distance (kms)   QOR044  Estacionado
# 35123  Distance (kms)   QOR044  Estacionado
# 35128  Distance (kms)   QOR044  Estacionado
# 35136  Distance (kms)   QOR044  Estacionado
# 35138  Distance (kms)   QOR044  Estacionado
# 35141  Distance (kms)   QOR044  Estacionado
# 35148  Distance (kms)   QOR044  Estacionado
# 35172  Distance (kms)   QOR044  Estacionado
# 35173  Distance (kms)   QOR044  Estacionado
# 35178  Distance (kms)   QOR044  Estacionado
# 35179  Distance (kms)   QOR044  Estacionado
# 35180  Distance (kms)   QOR044  Estacionado
# 35181  Distance (kms)   QOR044  Estacionado
# 35182  Distance (kms)   QOR044  Estacionado
# 35183  Distance (kms)   QOR044  Estacionado
# ...

# %%
QJK432=parked[parked['textbox4'].str.contains('QJK432')]
QJK432
# Out:
#             Textbox13 textbox4     textbox5  \
# 28169  Distance (kms)   QJK432  Estacionado
# 28170  Distance (kms)   QJK432  Estacionado
# 28171  Distance (kms)   QJK432  Estacionado
# 28172  Distance (kms)   QJK432  Estacionado
# 28173  Distance (kms)   QJK432  Estacionado
# ...               ...      ...          ...
# 34825  Distance (kms)   QJK432  Estacionado
# 34826  Distance (kms)   QJK432  Estacionado
# 34827  Distance (kms)   QJK432  Estacionado
# 34828  Distance (kms)   QJK432  Estacionado
# 34829  Distance (kms)   QJK432  Estacionado
#
#                                   textbox6 DistanceDriven  \
# 28169  Carrera 36B Yumbo Valle del  760502           0,00
# 28170  Carrera 36B Yumbo Valle del  760502           0,00
# 28171  Carrera 36B Yumbo Valle del  760502           0,00
# 28172  Carrera 36B Yumbo Valle del  760502           0,00
# 28173  Carrera 36B Yumbo Valle del  760502           0,00
# ...                                    ...            ...
# ...

# %%
LLQ951=parked[parked['textbox4'].str.contains('LLQ951')]
LLQ951
# Out:
#             Textbox13 textbox4     textbox5  \
# 16622  Distance (kms)   LLQ951  Estacionado
# 16623  Distance (kms)   LLQ951  Estacionado
# 16624  Distance (kms)   LLQ951  Estacionado
# 16625  Distance (kms)   LLQ951  Estacionado
# 16626  Distance (kms)   LLQ951  Estacionado
# ...               ...      ...          ...
# 28044  Distance (kms)   LLQ951  Estacionado
# 28045  Distance (kms)   LLQ951  Estacionado
# 28046  Distance (kms)   LLQ951  Estacionado
# 28047  Distance (kms)   LLQ951  Estacionado
# 28048  Distance (kms)   LLQ951  Estacionado
#
#                                       textbox6 DistanceDriven  \
# 16622  Via Principal, Cartagena, Bolivar  Bol            0,00
# 16623  Via Principal, Cartagena, Bolivar  Bol            0,00
# 16624  Via Principal, Cartagena, Bolivar  Bol            0,00
# 16625  Via Principal, Cartagena, Bolivar  Bol            0,00
# 16626  Via Principal, Cartagena, Bolivar  Bol            0,00
# ...

# %%
LLQ455=parked[parked['textbox4'].str.contains('LLQ455')]
LLQ455
# Out:
#             Textbox13 textbox4     textbox5  \
# 7688   Distance (kms)   LLQ455  Estacionado
# 7689   Distance (kms)   LLQ455  Estacionado
# 7690   Distance (kms)   LLQ455  Estacionado
# 7691   Distance (kms)   LLQ455  Estacionado
# 7692   Distance (kms)   LLQ455  Estacionado
# ...               ...      ...          ...
# 16174  Distance (kms)   LLQ455  Estacionado
# 16175  Distance (kms)   LLQ455  Estacionado
# 16176  Distance (kms)   LLQ455  Estacionado
# 16177  Distance (kms)   LLQ455  Estacionado
# 16178  Distance (kms)   LLQ455  Estacionado
#
#                                                 textbox6 DistanceDriven  \
# 7688          Cl9d 46-66, Cali, Valle Cauca, Colombia              0,00
# 7689          Cl9d 46-60, Cali, Valle Cauca, Colombia              0,00
# 7690   Cl. 9d #46-27 a 46-219, Cali, Cali, Valle del ...           0,00
# 7691   Cl. 10 #48-7, Cali, Cali, Valle del Cauca, Col...           0,00
# ...

# %%
LLQ454=parked[parked['textbox4'].str.contains('LLQ454')]
LLQ454
# Out:
#            Textbox13 textbox4     textbox5  \
# 2     Distance (kms)   LLQ454  Estacionado
# 3     Distance (kms)   LLQ454  Estacionado
# 4     Distance (kms)   LLQ454  Estacionado
# 5     Distance (kms)   LLQ454  Estacionado
# 6     Distance (kms)   LLQ454  Estacionado
# ...              ...      ...          ...
# 7427  Distance (kms)   LLQ454  Estacionado
# 7428  Distance (kms)   LLQ454  Estacionado
# 7429  Distance (kms)   LLQ454  Estacionado
# 7430  Distance (kms)   LLQ454  Estacionado
# 7431  Distance (kms)   LLQ454  Estacionado
#
#                                  textbox6 DistanceDriven  \
# 2     Carrera 36B Yumbo Valle del  760502           0,00
# 3     Carrera 36B Yumbo Valle del  760502           0,00
# 4     Carrera 36B Yumbo Valle del  760502           0,00
# 5     Carrera 36B Yumbo Valle del  760502           0,00
# 6     Carrera 36B Yumbo Valle del  760502           0,00
# ...                                   ...            ...
# ...

# %%
# It does not report since June the 5th
FSV105=parked[parked['textbox4'].str.contains('FSV105')]
FSV105
# Out:
# Empty DataFrame
# Columns: [Textbox13, textbox4, textbox5, textbox6, DistanceDriven, textbox11, textbox2, textbox7, textbox14]
# Index: []
