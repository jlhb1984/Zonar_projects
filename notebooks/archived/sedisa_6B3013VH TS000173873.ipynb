# %%
import pandas as pd 
import numpy as np
import datetime         #Shows in my time zone COL.

# %%
#vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\sedisa\vck379.csv',sep=',')
#vf.info()

# %%
vf=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\sedisa\Export (1).xlsx')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      215 non-null    str
#  1   Unnamed: 1   215 non-null    str
#  2   Unnamed: 2   215 non-null    str
#  3   Unnamed: 3   215 non-null    str
#  4   Unnamed: 4   215 non-null    str
#  5   Unnamed: 5   215 non-null    str
#  6   Unnamed: 6   215 non-null    str
#  7   Unnamed: 7   215 non-null    str
#  8   Unnamed: 8   215 non-null    str
#  9   Unnamed: 9   215 non-null    object
#  10  Unnamed: 10  215 non-null    object
#  11  Unnamed: 11  215 non-null    object
#  12  Unnamed: 12  215 non-null    object
#  13  Unnamed: 13  215 non-null    object
#  14  Unnamed: 14  215 non-null    str
#  15  Unnamed: 15  215 non-null    str
#  16  Unnamed: 16  194 non-null    str
#  17  Unnamed: 17  186 non-null    str
#  18  Unnamed: 18  178 non-null    str
#  19  Unnamed: 19  174 non-null    str
# ...

# %%
vf['Message'].value_counts()
# Out:
# Message
# {"notificationType":"CameraRunningInfo"     121
# {"notificationType":"IgnitionStatus"         48
# {"notificationType":"ParkingHeartbeat"       21
# {"notificationType":"MaintenanceWarning"      9
# {"notificationType":"DataUsage"               8
# {"notificationType":"PowerEvent"              4
# {"notificationType":"SDCardStatus"            4
# Name: count, dtype: int64

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
vf_camera_events['Unnamed: 5'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
vf_autosnapshot=vf[vf['Unnamed: 5'].str.contains('http')]
vf_autosnapshot['Unnamed: 5']#.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\sedisa\snapshot.csv')
# Out:
# Series([], Name: Unnamed: 5, dtype: str)

# %%
vf_date_time=vf[vf['Unnamed: 4'].str.contains('time')]
vf_date_time['Unnamed: 4']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
print(vf_date_time.iloc[0,4])

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,4][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))
    #vf_date_time.iloc[i,103]=str(epoch_date[i])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i])
# Out:
# time:1780877082027
# 2026-06-07 19:04:42.027000  ->  1780877082.027
# 2026-06-07 19:21:38.023000  ->  1780878098.023
# 2026-06-07 19:27:32.985000  ->  1780878452.985
# 2026-06-07 19:50:08.987000  ->  1780879808.987
# 2026-06-07 19:56:06.012000  ->  1780880166.012
# 2026-06-07 20:01:57.012000  ->  1780880517.012
# 2026-06-07 20:07:55.982000  ->  1780880875.982
# 2026-06-07 20:13:50.984000  ->  1780881230.984
# 2026-06-07 20:19:48.980000  ->  1780881588.98
# 2026-06-07 20:25:47.004000  ->  1780881947.004
# 2026-06-07 20:31:42.979000  ->  1780882302.979
# 2026-06-08 05:29:59.385000  ->  1780914599.385
# 2026-06-08 05:36:00.403000  ->  1780914960.403
# 2026-06-08 05:41:58.358000  ->  1780915318.358
# 2026-06-08 05:47:56.364000  ->  1780915676.364
# 2026-06-08 05:53:53.352000  ->  1780916033.352
# 2026-06-08 05:59:48.359000  ->  1780916388.359
# 2026-06-08 06:05:44.383000  ->  1780916744.383
# 2026-06-08 06:11:42.412000  ->  1780917102.412
# 2026-06-08 06:17:37.357000  ->  1780917457.357
# ...

# %%
vf_autosnapshot=vf[vf['Unnamed: 5'].str.contains('http')]
vf_autosnapshot_date=[]
aux_date_time_as=[]
epoch_date_as=[]
vf_autosnapshot['Date']='NaN'

for i in range(0,vf_autosnapshot.shape[0]):
    aux_date_time_as.append(float(vf_date_time.iloc[i,3][5:18])/1000)
    epoch_date_as.append(datetime.datetime.fromtimestamp(aux_date_time[i]))
    vf_autosnapshot.iloc[i,104]=str(epoch_date_as[i])

#vf_autosnapshot[['Unnamed: 5','Unnamed: 3','Date']].to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\sedisa\autosnap_vck379.csv')       #Edit.

# %% [markdown]
# NO_SEATBELT

# %%
vf_no_seatbelt=vf[vf['Unnamed: 4'].str.contains('NO_SEATBELT')]
#vf_no_seatbelt

vf_date_time=vf_no_seatbelt[vf_no_seatbelt['Unnamed: 9'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,9][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,103]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,19])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])

# %% [markdown]
# ## MaintenanceWarning

# %%
vf_camera_events=vf[vf['Message'].str.contains('MaintenanceWarning')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# ...
# Name: count, dtype: int64

# %% [markdown]
# NoTripDataUploaded_CheckRecordingFailure

# %%
warning_1=vf[vf['Unnamed: 4'].str.contains('NoTripDataUploaded_CheckRecordingFailure')]
#vf_no_seatbelt

vf_date_time=warning_1[warning_1['Unnamed: 5'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]
warning_m=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,5][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,42]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,8])
    warning_m.append(vf_date_time.iloc[i,4])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i], ' -> ',warning_m[i])
# Out:
# 2026-06-08 07:01:23.155000  ->  1780920083.155  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-08 19:56:39.175000  ->  1780966599.175  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-17 14:47:16.200000  ->  1781725636.2  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-17 17:50:10.181000  ->  1781736610.181  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-18 12:43:04.208000  ->  1781804584.208  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-18 16:39:09.237000  ->  1781818749.237  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"

# %% [markdown]
# StorageTypeChanged

# %%
warning_2=vf[vf['Unnamed: 4'].str.contains('StorageTypeChanged')]
#vf_no_seatbelt

vf_date_time=warning_2[warning_2['Unnamed: 7'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,7][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,42]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,10])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])
# Out:
# 2026-06-10 15:34:07.050000  ->  1781123647.05  ->  speed:0

# %% [markdown]
# {"notificationType":"MaintenanceWarning"	sn:"6B3013VH"	vehicleID:""	tripID:""	warning:"StorageTypeChanged"	detail:{"storageTypeChanged":{"previousStorage":"TFCard"	currentStorage:"NoStorage"}}	time:1781123647050	gpsData:{"source":"lastValid"	time:1781123222000	speed:0	heading:288.799987	coordinate:[-71.51834	-16.395.737	2396.2]	hDop:90	vDop:90}	accessKeyID:"Tsomobile_03ZhM6I4uRjzW"	sign:"nBI/6hRFWOGJBQFLcAU+ny5Bkgbvi27K4V7v1PAlusY="	useCache:true}

# %% [markdown]
# MainboardReboot_Check5PinConnection

# %%
warning_3=vf[vf['Unnamed: 4'].str.contains('MainboardReboot_Check5PinConnection')]
#vf_no_seatbelt

vf_date_time=warning_3[warning_3['Unnamed: 5'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,5][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,42]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,8])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])
# Out:
# 2026-06-10 15:42:15.252000  ->  1781124135.252  ->  speed:0

# %% [markdown]
# MCUDisconnected_NeedToForceUpdateMCU

# %%
warning_4=vf[vf['Unnamed: 4'].str.contains('MCUDisconnected_NeedToForceUpdateMCU')]
#vf_no_seatbelt

vf_date_time=warning_4[warning_4['Unnamed: 5'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,5][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,42]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,8])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])
# Out:
# 2026-06-16 11:59:10.372000  ->  1781629150.372  ->  speed:0

# %% [markdown]
# ## PowerEvent

# %%
warning_5=vf[vf['Unnamed: 5'].str.contains('removed')]
#vf_no_seatbelt

vf_date_time=warning_5[warning_5['Unnamed: 9'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,5][12:25])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,42]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,10])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])
# Out:
# 2026-06-10 15:26:41  ->  1781123201.0  ->  speed:-1
# 2026-06-10 16:00:51  ->  1781125251.0  ->  speed:-1
# 2026-06-10 16:40:09  ->  1781127609.0  ->  speed:-1
# 2026-06-16 12:45:22  ->  1781631922.0  ->  speed:-1

# %% [markdown]
# ## IgnitionStatus

# %%
warning_6=vf[vf['Message'].str.contains('IgnitionStatus')]
#vf_no_seatbelt

vf_date_time=warning_6[warning_6['Unnamed: 8'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,8][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,42]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,10])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])
# Out:
# 2026-06-07 18:52:38  ->  1780876358.0  ->  heading:0
# 2026-06-08 05:24:21  ->  1780914261.0  ->  heading:0
# 2026-06-08 07:01:22  ->  1780920082.0  ->  heading:258.299987
# 2026-06-08 07:19:08  ->  1780921148.0  ->  heading:87.300003
# 2026-06-08 07:24:14  ->  1780921454.0  ->  heading:268
# 2026-06-08 17:55:54  ->  1780959354.0  ->  heading:88.900001
# 2026-06-08 17:55:54  ->  1780959354.0  ->  heading:88.900001
# 2026-06-08 19:56:39  ->  1780966599.0  ->  heading:37.799999
# 2026-06-10 15:25:54  ->  1781123154.0  ->  heading:0
# 2026-06-10 15:26:46  ->  1781123206.0  ->  heading:-1
# 2026-06-10 15:57:00  ->  1781125020.0  ->  heading:0
# 2026-06-10 16:00:47  ->  1781125247.0  ->  heading:-1
# 2026-06-10 16:13:21  ->  1781126001.0  ->  heading:0
# 2026-06-10 16:38:08  ->  1781127488.0  ->  heading:307.799987
# 2026-06-16 11:55:01  ->  1781628901.0  ->  heading:-1
# 2026-06-17 12:27:06  ->  1781717226.0  ->  heading:0
# 2026-06-17 12:37:58  ->  1781717878.0  ->  heading:300.299987
# ...

# %% [markdown]
# ## DataUsage

# %%
warning_7=vf[vf['Message'].str.contains('DataUsage')]
#vf_no_seatbelt

vf_date_time=warning_7[warning_7['Unnamed: 6'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,6][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,42]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,7])
    warning_m.append(vf_date_time.iloc[i,3])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i],' -> ',warning_m[i])
# Out:
# 2026-06-08 12:02:46  ->  1780938166.0  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-10 14:21:41  ->  1781119301.0  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-10 14:22:17  ->  1781119337.0  ->  speed:1.6668  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-10 14:28:14  ->  1781119694.0  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-10 15:34:17  ->  1781123657.0  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-10 15:38:25  ->  1781123905.0  ->  speed:0  ->  warning:"NoTripDataUploaded_CheckRecordingFailure"
# 2026-06-10 15:40:12  ->  1781124012.0  ->  speed:0  ->  dataUsageInKB:0
# 2026-06-10 15:44:44  ->  1781124284.0  ->  speed:0  ->  dataUsageInKB:0

# %% [markdown]
# ## CameraRunningInfo

# %%
warning_8=vf[vf['Message'].str.contains('CameraRunningInfo')]
#vf_no_seatbelt

vf_date_time=warning_8[warning_8['Unnamed: 4'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
oldest_buffered=[]
oldest_marked=[]
buffered_date=[]
marked_date=[]

for i in range(0,vf_date_time.shape[0]):
    oldest_buffered.append(vf_date_time.iloc[i,11])
    oldest_marked.append(vf_date_time.iloc[i,12])
    buffered_date.append(datetime.datetime.fromtimestamp(float(vf_date_time.iloc[i,11][23:36])/1000))
    marked_date.append(datetime.datetime.fromtimestamp(float(vf_date_time.iloc[i,12][21:34])/1000)      )
    #vf_date_time.iloc[i,42]=str(epoch_date[i])    

for i in range(0,len(oldest_buffered)):
    print(oldest_buffered[i],' -> ',buffered_date[i],' -> ',oldest_marked[i],' -> ',marked_date[i])
# Out:
# oldestBufferedClipTime:1777738777000  ->  2026-05-02 11:19:37  ->  oldestMarkedClipTime:1778011382000  ->  2026-05-05 15:03:02
# oldestBufferedClipTime:1777738777000  ->  2026-05-02 11:19:37  ->  oldestMarkedClipTime:1778011382000  ->  2026-05-05 15:03:02
# oldestBufferedClipTime:1777738777000  ->  2026-05-02 11:19:37  ->  oldestMarkedClipTime:1778011382000  ->  2026-05-05 15:03:02
# oldestBufferedClipTime:1777738777000  ->  2026-05-02 11:19:37  ->  oldestMarkedClipTime:1778011382000  ->  2026-05-05 15:03:02
# oldestBufferedClipTime:1777738777000  ->  2026-05-02 11:19:37  ->  oldestMarkedClipTime:1778011382000  ->  2026-05-05 15:03:02
# oldestBufferedClipTime:1777738777000  ->  2026-05-02 11:19:37  ->  oldestMarkedClipTime:1778011382000  ->  2026-05-05 15:03:02
# oldestBufferedClipTime:1777738777000  ->  2026-05-02 11:19:37  ->  oldestMarkedClipTime:1778011382000  ->  2026-05-05 15:03:02
# ...

# %% [markdown]
# HL

# %%
hl=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\sedisa\historicallocations_vck379.xlsx')
hl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4017 entries, 0 to 4016
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Secuencia       4017 non-null   int64
#  1   Unidad          4017 non-null   str
#  2   Eventos         4009 non-null   str
#  3   Fecha           4017 non-null   str
#  4   Pt. Referencia  0 non-null      float64
#  5   Dirección       4017 non-null   str
#  6   Velocidad       4017 non-null   int64
#  7   Temperatura     0 non-null      float64
#  8   Conductor       0 non-null      float64
#  9   Latitud         4017 non-null   float64
#  10  Longitud        4017 non-null   float64
# dtypes: float64(5), int64(2), str(4)
# memory usage: 345.3 KB

# %%
date=input("Type the date: ")
hl[hl['Fecha'].str.contains(date)]
# Out:
#       Secuencia      Unidad             Eventos                 Fecha  \
# 0          4017  VCK-379 VF        AutoSnapshot  Jun 30 2026 08:51 PM
# 1          4016  VCK-379 VF    Ignición Apagada  Jun 30 2026 08:51 PM
# 2          4015  VCK-379 VF  Ignición Encendida  Jun 30 2026 08:51 PM
# 3          4014  VCK-379 VF        AutoSnapshot  Jun 30 2026 08:51 PM
# 4          4013  VCK-379 VF        AutoSnapshot  Jun 30 2026 08:50 PM
# ...         ...         ...                 ...                   ...
# 4012          5  VCK-379 VF  Ignición Encendida  Jun 01 2026 08:00 AM
# 4013          4  VCK-379 VF    Ignición Apagada  Jun 01 2026 07:32 AM
# 4014          3  VCK-379 VF  Ignición Encendida  Jun 01 2026 05:58 AM
# 4015          2  VCK-379 VF    Ignición Apagada  Jun 01 2026 05:55 AM
# 4016          1  VCK-379 VF  Ignición Encendida  Jun 01 2026 05:24 AM
#
#       Pt. Referencia                                          Dirección  \
# ...
