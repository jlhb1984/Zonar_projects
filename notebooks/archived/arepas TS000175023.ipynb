# %%
import pandas as pd 
import numpy as np
import datetime         #Shows in my time zone COL.

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\arepas_raw_data.csv',sep=';')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11278 entries, 0 to 11277
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     11278 non-null  str
#  1   Sequence #                 0 non-null      float64
#  2   Server Time                11278 non-null  str
#  3   Unit Time                  11278 non-null  str
#  4   Last Message Time          11278 non-null  str
#  5   Latitude                   11278 non-null  str
#  6   Longitude                  11278 non-null  str
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 11278 non-null  str
#  9   Raw Event                  11278 non-null  str
#  10  Address                    11278 non-null  str
#  11  GPS Speed                  10506 non-null  str
#  12  ECU Speed                  0 non-null      float64
#  13  Speed Limit                4006 non-null   str
# ...

# %%
#vf=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\sedisa\Export (1).xlsx')
#vf.info()

# %%
vf['Notification Type'].value_counts()
# Out:
# Notification Type
# TripInfo          8701
# IgnitionStatus    1303
# AutoSnapshot      1174
# CameraEvent         96
# PowerEvent           4
# Name: count, dtype: int64

# %%
vf_camera_events=vf[vf['Notification Type'].str.contains('CameraEvent')]
vf_camera_events['Event Name'].value_counts()
# Out:
# Event Name
# No Seatbelt            34
# Hard Brake             18
# Using Phone             9
# Drowsiness              9
# Yawn                    7
# Collision Warning       6
# Stop Sign Violation     4
# Rapid Acceleration      2
# Travel Start            2
# Hard Turn               2
# Manual                  1
# Power Lost              1
# Tailgating              1
# Name: count, dtype: int64

# %%
vf_autosnapshot=vf[vf['Notification Type'].str.contains('AutoSnapshot')]
vf_autosnapshot.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\snapshot.csv')
