# %%
import pandas as pd
import numpy as np

# %%
hl=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\wilber\historicallocations.xlsx')
hl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     279 non-null    int64
#  1   Unit         279 non-null    str
#  2   Events       279 non-null    str
#  3   Date         279 non-null    str
#  4   Landmark     0 non-null      float64
#  5   Address      277 non-null    str
#  6   Speed        279 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     279 non-null    float64
#  10  Longitude    279 non-null    float64
# dtypes: float64(5), int64(2), str(4)
# memory usage: 24.1 KB

# %%
hl['Events'].value_counts()
# Out:
# Events
# Travel Stop         74
# Travel Start        74
# Towing/Drifting?    59
# Parked              30
# POWER UP            17
# Drive               15
# Ignition OFF         4
# Ignition ON          4
# Idle Alert           1
# Idle - Stop          1
# Name: count, dtype: int64

# %%
hl_ignition=hl[hl['Events'].str.contains('Ignition')]
hl_ignition
# Out:
#      Sequence    Unit        Events                  Date  Landmark  \
# 259        20  JG-18T  Ignition OFF  May 17 2026 01:56 PM       NaN
# 261        18  JG-18T   Ignition ON  May 17 2026 01:55 PM       NaN
# 262        17  JG-18T   Ignition ON  May 17 2026 01:55 PM       NaN
# 263        16  JG-18T  Ignition OFF  May 17 2026 01:55 PM       NaN
# 265        14  JG-18T  Ignition OFF  May 06 2026 11:18 AM       NaN
# 268        11  JG-18T   Ignition ON  May 06 2026 11:07 AM       NaN
# 272         7  JG-18T  Ignition OFF  May 03 2026 03:26 PM       NaN
# 273         6  JG-18T   Ignition ON  May 03 2026 03:24 PM       NaN
#
#                                              Address  Speed  Temperature  \
# 259  Av Siberia Cota, Bogota, Cundinamarca, Colombia      0          NaN
# 261  Av Siberia Cota, Bogota, Cundinamarca, Colombia      0          NaN
# 262  Av Siberia Cota, Bogota, Cundinamarca, Colombia      0          NaN
# ...

# %%
hl_drive=hl[hl['Events'].str.contains('Drive')]
hl_drive
# Out:
#      Sequence    Unit Events                  Date  Landmark  \
# 16        263  JG-18T  Drive  May 25 2026 08:11 AM       NaN
# 111       168  JG-18T  Drive  May 21 2026 05:21 PM       NaN
# 145       134  JG-18T  Drive  May 21 2026 04:40 PM       NaN
# 149       130  JG-18T  Drive  May 21 2026 04:36 PM       NaN
# 162       117  JG-18T  Drive  May 21 2026 04:27 PM       NaN
# 163       116  JG-18T  Drive  May 21 2026 04:27 PM       NaN
# 184        95  JG-18T  Drive  May 21 2026 07:41 AM       NaN
# 185        94  JG-18T  Drive  May 21 2026 07:41 AM       NaN
# 198        81  JG-18T  Drive  May 21 2026 07:29 AM       NaN
# 201        78  JG-18T  Drive  May 21 2026 07:25 AM       NaN
# 203        76  JG-18T  Drive  May 21 2026 07:25 AM       NaN
# 204        75  JG-18T  Drive  May 21 2026 07:25 AM       NaN
# 205        74  JG-18T  Drive  May 21 2026 07:24 AM       NaN
# 206        73  JG-18T  Drive  May 21 2026 07:24 AM       NaN
# ...
