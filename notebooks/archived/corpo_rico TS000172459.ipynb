# %%
import pandas as pd
import numpy as np

# %%
df_book_table01_aux=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\Customer-Units.xlsx - Sheet1.csv',sep=',',encoding='latin1')
df_book_table02_aux=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\01-06-2026_Detallada_36B7179B3F06488D2CE351FAF1F736FF.xlsx - Data.csv',sep=',',encoding='latin1')
df_book_table02_aux['phone']='Nan'

df_book_table01_aux.info()
df_book_table02_aux.info()

for i in range(0, df_book_table02_aux.shape[0]):
    df_book_table02_aux.iloc[i,41]=str(df_book_table02_aux.iloc[i,7])[2:12]

df_book_table02_aux['phone']
df_book_table01=df_book_table01_aux[['Unit','Serial Number','Phone Number','Last Contact On']]

df_book_table02=df_book_table02_aux[['Text','Status','phone','Send At']]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       129 non-null    int64
#  1   Owner                    129 non-null    str
#  2   Unit ID                  129 non-null    str
#  3   Unit                     129 non-null    str
#  4   Peripherals              49 non-null     str
#  5   Billing Period           128 non-null    str
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            6 non-null      str
#  9   Last Event Date          129 non-null    str
#  10  Monthly Fee              129 non-null    int64
#  11  Bill To                  0 non-null      float64
#  12  Assigned To              129 non-null    str
#  13  Linked Mode              129 non-null    int64
#  14  Paired GPS               0 non-null      float64
#  15  Paired Camera            0 non-null      float64
#  16  Billable                 129 non-null    str
#  17  RMA                      129 non-null    str
#  18  Unit Type                129 non-null    str
#  19  IMEI                     129 non-null    object
#  20  Serial Number            129 non-null    int64
#  21  Phone Number             114 non-null    str
#  22  Carrier                  124 non-null    str
#  23  SIM #                    129 non-null    str
#  24  VIN                      5 non-null      str
#  25  License Plate            127 non-null    str
#  26  Static IP                0 non-null      float64
#  27  Event                    129 non-null    str
#  28  Last Contact On          129 non-null    str
#  29  Min                      129 non-null    int64
#  30  Server IP                129 non-null    str
#  31  Server Port              129 non-null    int64
#  32  Last Event Address       129 non-null    str
#  33  Modem                    128 non-null    str
#  34  Inv #                    129 non-null    str
#  35  Status                   129 non-null    str
#  36  Last Service Paid Until  129 non-null    str
#  37  Service Paid Until       129 non-null    str
#  38  Assigned to Company      129 non-null    str
#  39  IFTA                     129 non-null    str
#  40  History Months           129 non-null    int64
#  41  Comments                 4 non-null      str
#  42  Warranty Expires         129 non-null    str
#  43  Script                   56 non-null     str
#  44  JBOX Profile             57 non-null     str
#  45  Contract Type            0 non-null      float64
#  46  Subscription             0 non-null      float64
#  47  Firmware                 92 non-null     str
# dtypes: float64(8), int64(7), object(1), str(32)
# memory usage: 48.5+ KB
# <class 'pandas.DataFrame'>
# RangeIndex: 4926 entries, 0 to 4925
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Account Name                 4926 non-null   str
#  1   Traffic Source               4926 non-null   str
#  2   Communication Name           0 non-null      float64
#  3   Communication Scheduled For  0 non-null      float64
#  4   Communication Start Date     0 non-null      float64
#  5   Communication Template       0 non-null      float64
#  6   From                         4926 non-null   str
#  7   To                           4926 non-null   int64
#  8   Message Id                   4926 non-null   object
#  9   Send At                      4926 non-null   str
#  10  Country Prefix               4922 non-null   float64
#  11  Country Name                 4922 non-null   str
#  12  Network Name                 4922 non-null   str
#  13  Original MCC                 4922 non-null   float64
#  14  Original MNC                 4919 non-null   float64
#  15  Original MCC MNC             4922 non-null   float64
#  16  Purchase Price               4926 non-null   int64
#  17  Purchase Currency            4926 non-null   str
#  18  Selling Price                0 non-null      float64
#  19  Selling Currency             0 non-null      float64
#  20  Message Type                 4926 non-null   str
#  21  SMS Type                     4926 non-null   str
#  22  Status                       4926 non-null   str
#  23  Reason                       4926 non-null   str
#  24  Action                       2495 non-null   str
#  25  Error Group                  4926 non-null   str
#  26  Error Name                   4926 non-null   str
#  27  Done At                      4926 non-null   str
#  28  Text                         4926 non-null   str
#  29  Message Length               4926 non-null   int64
#  30  Messages Count               4926 non-null   int64
#  31  Service Name                 4926 non-null   str
#  32  User Name                    4926 non-null   str
#  33  Paired Message Id            0 non-null      float64
#  34  Clicks                       0 non-null      float64
#  35  Verified                     0 non-null      float64
#  36  Data Payload                 0 non-null      float64
#  37  Bulk Id                      0 non-null      float64
#  38  Campaign Reference           0 non-null      float64
#  39  Application ID               4926 non-null   str
#  40  Entity ID                    0 non-null      float64
#  41  phone                        4926 non-null   str
# dtypes: float64(17), int64(4), object(1), str(20)
# memory usage: 1.6+ MB

# %%
df_book_table01.info()
df_book_table02.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit             129 non-null    str
#  1   Serial Number    129 non-null    int64
#  2   Phone Number     114 non-null    str
#  3   Last Contact On  129 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 4.2 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 4926 entries, 0 to 4925
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Text     4926 non-null   str
#  1   Status   4926 non-null   str
#  2   phone    4926 non-null   str
#  3   Send At  4926 non-null   str
# dtypes: str(4)
# memory usage: 154.1 KB

# %%
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]
list_field05=[]   
list_field06=[]
list_field07=[]       
#print("df_book_table01[8,0]: ",df_book_table01.iloc[8,0]) #UnitsByDealer.csv_r.csv
#print("df_book_table02[8,5]: ",df_book_table02.iloc[8,5]) #6MB.        
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='Phone Number'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='phone'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]): 
        if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):                                                                             
            list_field01.append(df_book_table01.iloc[i,0])
            list_field02.append(df_book_table01.iloc[i,1])
            list_field03.append(df_book_table01.iloc[i,2])
            list_field04.append(df_book_table01.iloc[i,3])
            list_field05.append(df_book_table02.iloc[j,0])
            list_field06.append(df_book_table02.iloc[j,1])
            list_field07.append(df_book_table02.iloc[j,3])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['Unit']=list_field01
df_aux['Serial Number']=list_field02
df_aux['Phone']=list_field03
df_aux['Last contact on']=list_field04
df_aux['text']=list_field05
df_aux['status']=list_field06
df_aux['date']=list_field07

print("Cont= ",cont)
print(df_aux.info())
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    df_aux.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\coincidences.csv')                  #Edit
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):
                df_book_table02.iloc[j,3]=np.nan
                print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    #print(df_book_table02)
    df_book_table02.dropna(axis=0,inplace=True)
    print(df_book_table02)
    df_book_table02.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\differences.csv')          #Edit

#lista_combinada=[lista_simcard,lista_linea]
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit             129 non-null    str
#  1   Serial Number    129 non-null    int64
#  2   Phone Number     114 non-null    str
#  3   Last Contact On  129 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 4.2 KB
# None
#
# Tabla 2:
# <class 'pandas.DataFrame'>
# RangeIndex: 4926 entries, 0 to 4925
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Text     4926 non-null   str
#  1   Status   4926 non-null   str
#  2   phone    4926 non-null   str
#  3   Send At  4926 non-null   str
# dtypes: str(4)
# memory usage: 154.1 KB
# None
#
# Atributo de la tabla1:  2
# Atributo de la tabla2:  2
#
# Trabajando...
# df_book_table01[i,position_table01]:  958984392  = df_book_table02[j,position_table02]:  958984392
# df_book_table01[i,position_table01]:  958984392  = df_book_table02[j,position_table02]:  958984392
# df_book_table01[i,position_table01]:  986154879  = df_book_table02[j,position_table02]:  986154879
# df_book_table01[i,position_table01]:  986154879  = df_book_table02[j,position_table02]:  986154879
# df_book_table01[i,position_table01]:  969773925  = df_book_table02[j,position_table02]:  969773925
# df_book_table01[i,position_table01]:  969773925  = df_book_table02[j,position_table02]:  969773925
# df_book_table01[i,position_table01]:  987865324  = df_book_table02[j,position_table02]:  987865324
# df_book_table01[i,position_table01]:  987865324  = df_book_table02[j,position_table02]:  987865324
# df_book_table01[i,position_table01]:  997373161  = df_book_table02[j,position_table02]:  997373161
# df_book_table01[i,position_table01]:  997373161  = df_book_table02[j,position_table02]:  997373161
# df_book_table01[i,position_table01]:  982015608  = df_book_table02[j,position_table02]:  982015608
# df_book_table01[i,position_table01]:  982015608  = df_book_table02[j,position_table02]:  982015608
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  982916737  = df_book_table02[j,position_table02]:  982916737
# df_book_table01[i,position_table01]:  982916737  = df_book_table02[j,position_table02]:  982916737
# df_book_table01[i,position_table01]:  982917864  = df_book_table02[j,position_table02]:  982917864
# df_book_table01[i,position_table01]:  982917864  = df_book_table02[j,position_table02]:  982917864
# df_book_table01[i,position_table01]:  982906102  = df_book_table02[j,position_table02]:  982906102
# df_book_table01[i,position_table01]:  982906102  = df_book_table02[j,position_table02]:  982906102
# df_book_table01[i,position_table01]:  961851749  = df_book_table02[j,position_table02]:  961851749
# df_book_table01[i,position_table01]:  961851749  = df_book_table02[j,position_table02]:  961851749
# df_book_table01[i,position_table01]:  987844693  = df_book_table02[j,position_table02]:  987844693
# df_book_table01[i,position_table01]:  987844693  = df_book_table02[j,position_table02]:  987844693
# df_book_table01[i,position_table01]:  982916535  = df_book_table02[j,position_table02]:  982916535
# df_book_table01[i,position_table01]:  982916535  = df_book_table02[j,position_table02]:  982916535
# df_book_table01[i,position_table01]:  982908928  = df_book_table02[j,position_table02]:  982908928
# df_book_table01[i,position_table01]:  982908928  = df_book_table02[j,position_table02]:  982908928
# df_book_table01[i,position_table01]:  961763573  = df_book_table02[j,position_table02]:  961763573
# df_book_table01[i,position_table01]:  961763573  = df_book_table02[j,position_table02]:  961763573
# df_book_table01[i,position_table01]:  987660823  = df_book_table02[j,position_table02]:  987660823
# df_book_table01[i,position_table01]:  987660823  = df_book_table02[j,position_table02]:  987660823
# df_book_table01[i,position_table01]:  993428410  = df_book_table02[j,position_table02]:  993428410
# df_book_table01[i,position_table01]:  993428410  = df_book_table02[j,position_table02]:  993428410
# df_book_table01[i,position_table01]:  99999999  = df_book_table02[j,position_table02]:  99999999
# df_book_table01[i,position_table01]:  99999999  = df_book_table02[j,position_table02]:  99999999
# df_book_table01[i,position_table01]:  987105326  = df_book_table02[j,position_table02]:  987105326
# df_book_table01[i,position_table01]:  987105326  = df_book_table02[j,position_table02]:  987105326
# df_book_table01[i,position_table01]:  983368003  = df_book_table02[j,position_table02]:  983368003
# df_book_table01[i,position_table01]:  983368003  = df_book_table02[j,position_table02]:  983368003
# df_book_table01[i,position_table01]:  982908448  = df_book_table02[j,position_table02]:  982908448
# df_book_table01[i,position_table01]:  982908448  = df_book_table02[j,position_table02]:  982908448
# df_book_table01[i,position_table01]:  961444436  = df_book_table02[j,position_table02]:  961444436
# df_book_table01[i,position_table01]:  961444436  = df_book_table02[j,position_table02]:  961444436
# df_book_table01[i,position_table01]:  993426614  = df_book_table02[j,position_table02]:  993426614
# df_book_table01[i,position_table01]:  993426614  = df_book_table02[j,position_table02]:  993426614
# df_book_table01[i,position_table01]:  994343125  = df_book_table02[j,position_table02]:  994343125
# df_book_table01[i,position_table01]:  994343125  = df_book_table02[j,position_table02]:  994343125
# df_book_table01[i,position_table01]:  994343125  = df_book_table02[j,position_table02]:  994343125
# df_book_table01[i,position_table01]:  997538749  = df_book_table02[j,position_table02]:  997538749
# df_book_table01[i,position_table01]:  997538749  = df_book_table02[j,position_table02]:  997538749
# df_book_table01[i,position_table01]:  997538749  = df_book_table02[j,position_table02]:  997538749
# df_book_table01[i,position_table01]:  993197837  = df_book_table02[j,position_table02]:  993197837
# df_book_table01[i,position_table01]:  993197837  = df_book_table02[j,position_table02]:  993197837
# df_book_table01[i,position_table01]:  993197837  = df_book_table02[j,position_table02]:  993197837
# df_book_table01[i,position_table01]:  982908578  = df_book_table02[j,position_table02]:  982908578
# df_book_table01[i,position_table01]:  982908578  = df_book_table02[j,position_table02]:  982908578
# df_book_table01[i,position_table01]:  982908578  = df_book_table02[j,position_table02]:  982908578
# df_book_table01[i,position_table01]:  987862116  = df_book_table02[j,position_table02]:  987862116
# df_book_table01[i,position_table01]:  987862116  = df_book_table02[j,position_table02]:  987862116
# df_book_table01[i,position_table01]:  987862116  = df_book_table02[j,position_table02]:  987862116
# df_book_table01[i,position_table01]:  993429278  = df_book_table02[j,position_table02]:  993429278
# df_book_table01[i,position_table01]:  993429278  = df_book_table02[j,position_table02]:  993429278
# df_book_table01[i,position_table01]:  993429278  = df_book_table02[j,position_table02]:  993429278
# df_book_table01[i,position_table01]:  997501638  = df_book_table02[j,position_table02]:  997501638
# df_book_table01[i,position_table01]:  997501638  = df_book_table02[j,position_table02]:  997501638
# df_book_table01[i,position_table01]:  997501638  = df_book_table02[j,position_table02]:  997501638
# df_book_table01[i,position_table01]:  983363227  = df_book_table02[j,position_table02]:  983363227
# df_book_table01[i,position_table01]:  983363227  = df_book_table02[j,position_table02]:  983363227
# df_book_table01[i,position_table01]:  983363227  = df_book_table02[j,position_table02]:  983363227
# df_book_table01[i,position_table01]:  987861495  = df_book_table02[j,position_table02]:  987861495
# df_book_table01[i,position_table01]:  987861495  = df_book_table02[j,position_table02]:  987861495
# df_book_table01[i,position_table01]:  987861495  = df_book_table02[j,position_table02]:  987861495
# Cont=  77
# <class 'pandas.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit             77 non-null     str
#  1   Serial Number    77 non-null     int64
#  2   Phone            77 non-null     str
#  3   Last contact on  77 non-null     str
#  4   text             77 non-null     str
#  5   status           77 non-null     str
#  6   date             77 non-null     str
# dtypes: int64(1), str(6)
# memory usage: 4.3 KB
# None
# Trabajando...
# df_book_table01[i,position_table01]:  958984392  = df_book_table02[j,position_table02]:  958984392
# df_book_table01[i,position_table01]:  958984392  = df_book_table02[j,position_table02]:  958984392
# df_book_table01[i,position_table01]:  986154879  = df_book_table02[j,position_table02]:  986154879
# df_book_table01[i,position_table01]:  986154879  = df_book_table02[j,position_table02]:  986154879
# df_book_table01[i,position_table01]:  969773925  = df_book_table02[j,position_table02]:  969773925
# df_book_table01[i,position_table01]:  969773925  = df_book_table02[j,position_table02]:  969773925
# df_book_table01[i,position_table01]:  987865324  = df_book_table02[j,position_table02]:  987865324
# df_book_table01[i,position_table01]:  987865324  = df_book_table02[j,position_table02]:  987865324
# df_book_table01[i,position_table01]:  997373161  = df_book_table02[j,position_table02]:  997373161
# df_book_table01[i,position_table01]:  997373161  = df_book_table02[j,position_table02]:  997373161
# df_book_table01[i,position_table01]:  982015608  = df_book_table02[j,position_table02]:  982015608
# df_book_table01[i,position_table01]:  982015608  = df_book_table02[j,position_table02]:  982015608
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  9104046614  = df_book_table02[j,position_table02]:  9104046614
# df_book_table01[i,position_table01]:  982916737  = df_book_table02[j,position_table02]:  982916737
# df_book_table01[i,position_table01]:  982916737  = df_book_table02[j,position_table02]:  982916737
# df_book_table01[i,position_table01]:  982917864  = df_book_table02[j,position_table02]:  982917864
# df_book_table01[i,position_table01]:  982917864  = df_book_table02[j,position_table02]:  982917864
# df_book_table01[i,position_table01]:  982906102  = df_book_table02[j,position_table02]:  982906102
# df_book_table01[i,position_table01]:  982906102  = df_book_table02[j,position_table02]:  982906102
# df_book_table01[i,position_table01]:  961851749  = df_book_table02[j,position_table02]:  961851749
# df_book_table01[i,position_table01]:  961851749  = df_book_table02[j,position_table02]:  961851749
# df_book_table01[i,position_table01]:  987844693  = df_book_table02[j,position_table02]:  987844693
# df_book_table01[i,position_table01]:  987844693  = df_book_table02[j,position_table02]:  987844693
# df_book_table01[i,position_table01]:  982916535  = df_book_table02[j,position_table02]:  982916535
# df_book_table01[i,position_table01]:  982916535  = df_book_table02[j,position_table02]:  982916535
# df_book_table01[i,position_table01]:  982908928  = df_book_table02[j,position_table02]:  982908928
# df_book_table01[i,position_table01]:  982908928  = df_book_table02[j,position_table02]:  982908928
# df_book_table01[i,position_table01]:  961763573  = df_book_table02[j,position_table02]:  961763573
# df_book_table01[i,position_table01]:  961763573  = df_book_table02[j,position_table02]:  961763573
# df_book_table01[i,position_table01]:  987660823  = df_book_table02[j,position_table02]:  987660823
# df_book_table01[i,position_table01]:  987660823  = df_book_table02[j,position_table02]:  987660823
# df_book_table01[i,position_table01]:  993428410  = df_book_table02[j,position_table02]:  993428410
# df_book_table01[i,position_table01]:  993428410  = df_book_table02[j,position_table02]:  993428410
# df_book_table01[i,position_table01]:  99999999  = df_book_table02[j,position_table02]:  99999999
# df_book_table01[i,position_table01]:  99999999  = df_book_table02[j,position_table02]:  99999999
# df_book_table01[i,position_table01]:  987105326  = df_book_table02[j,position_table02]:  987105326
# df_book_table01[i,position_table01]:  987105326  = df_book_table02[j,position_table02]:  987105326
# df_book_table01[i,position_table01]:  983368003  = df_book_table02[j,position_table02]:  983368003
# df_book_table01[i,position_table01]:  983368003  = df_book_table02[j,position_table02]:  983368003
# df_book_table01[i,position_table01]:  982908448  = df_book_table02[j,position_table02]:  982908448
# df_book_table01[i,position_table01]:  982908448  = df_book_table02[j,position_table02]:  982908448
# df_book_table01[i,position_table01]:  961444436  = df_book_table02[j,position_table02]:  961444436
# df_book_table01[i,position_table01]:  961444436  = df_book_table02[j,position_table02]:  961444436
# df_book_table01[i,position_table01]:  993426614  = df_book_table02[j,position_table02]:  993426614
# df_book_table01[i,position_table01]:  993426614  = df_book_table02[j,position_table02]:  993426614
# df_book_table01[i,position_table01]:  994343125  = df_book_table02[j,position_table02]:  994343125
# df_book_table01[i,position_table01]:  994343125  = df_book_table02[j,position_table02]:  994343125
# df_book_table01[i,position_table01]:  994343125  = df_book_table02[j,position_table02]:  994343125
# df_book_table01[i,position_table01]:  997538749  = df_book_table02[j,position_table02]:  997538749
# df_book_table01[i,position_table01]:  997538749  = df_book_table02[j,position_table02]:  997538749
# df_book_table01[i,position_table01]:  997538749  = df_book_table02[j,position_table02]:  997538749
# df_book_table01[i,position_table01]:  993197837  = df_book_table02[j,position_table02]:  993197837
# df_book_table01[i,position_table01]:  993197837  = df_book_table02[j,position_table02]:  993197837
# df_book_table01[i,position_table01]:  993197837  = df_book_table02[j,position_table02]:  993197837
# df_book_table01[i,position_table01]:  982908578  = df_book_table02[j,position_table02]:  982908578
# df_book_table01[i,position_table01]:  982908578  = df_book_table02[j,position_table02]:  982908578
# df_book_table01[i,position_table01]:  982908578  = df_book_table02[j,position_table02]:  982908578
# df_book_table01[i,position_table01]:  987862116  = df_book_table02[j,position_table02]:  987862116
# df_book_table01[i,position_table01]:  987862116  = df_book_table02[j,position_table02]:  987862116
# df_book_table01[i,position_table01]:  987862116  = df_book_table02[j,position_table02]:  987862116
# df_book_table01[i,position_table01]:  993429278  = df_book_table02[j,position_table02]:  993429278
# df_book_table01[i,position_table01]:  993429278  = df_book_table02[j,position_table02]:  993429278
# df_book_table01[i,position_table01]:  993429278  = df_book_table02[j,position_table02]:  993429278
# df_book_table01[i,position_table01]:  997501638  = df_book_table02[j,position_table02]:  997501638
# df_book_table01[i,position_table01]:  997501638  = df_book_table02[j,position_table02]:  997501638
# df_book_table01[i,position_table01]:  997501638  = df_book_table02[j,position_table02]:  997501638
# df_book_table01[i,position_table01]:  983363227  = df_book_table02[j,position_table02]:  983363227
# df_book_table01[i,position_table01]:  983363227  = df_book_table02[j,position_table02]:  983363227
# df_book_table01[i,position_table01]:  983363227  = df_book_table02[j,position_table02]:  983363227
# df_book_table01[i,position_table01]:  987861495  = df_book_table02[j,position_table02]:  987861495
# df_book_table01[i,position_table01]:  987861495  = df_book_table02[j,position_table02]:  987861495
# df_book_table01[i,position_table01]:  987861495  = df_book_table02[j,position_table02]:  987861495
#                                         Text     Status       phone  \
# 0                          1707106744_Wakeup  Delivered  3156366413
# 1                           403348892_Wakeup  Delivered  9103682518
# 2                          1064012639_Wakeup  Delivered  9103682518
# 3                          1417932494_Wakeup  Delivered  9103535597
# 4                          1021932604_Wakeup  Delivered  9103682518
# ...                                      ...        ...         ...
# 4921            AT+GTRTO=gv55w,1,,1,,,,FFFF$  Delivered   950185532
# 4922                        158202618_Wakeup  Delivered  3185868201
# 4923                        754317352_Wakeup  Delivered  3185868201
# 4924                       1323352884_Wakeup  Delivered  3185868201
# 4925  1780332541 Wakeup cloud info bubble LS   Rejected   103824977
#
#                   Send At ACTION
# 0     28/05/2026 08:49:57   Keep
# 1     28/05/2026 08:50:37   Keep
# 2     28/05/2026 08:51:48   Keep
# 3     28/05/2026 08:51:53   Keep
# 4     28/05/2026 08:53:00   Keep
# ...                   ...    ...
# 4921  01/06/2026 11:43:40   Keep
# 4922  01/06/2026 11:44:12   Keep
# 4923  01/06/2026 11:47:21   Keep
# 4924  01/06/2026 11:48:37   Keep
# 4925  01/06/2026 11:49:02   Keep
#
# [4849 rows x 5 columns]

# %%
no_duplicated=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\coincidences.csv',sep=',')
no_duplicated['Unit'].drop_duplicates().to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\units_speed_updated.csv')

# %% [markdown]
# Units resting:

# %%
df_book_table01=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\coincidences.csv',sep=',')
df_book_table02=df_book_table01_aux[['Unit','Serial Number','Phone Number','Last Contact On']]

# %%
df_book_table01.info()
df_book_table02.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       40 non-null     int64
#  1   Unit             40 non-null     str
#  2   Serial Number    40 non-null     int64
#  3   Phone            40 non-null     int64
#  4   Last contact on  40 non-null     str
#  5   text             40 non-null     str
#  6   status           40 non-null     str
#  7   date             40 non-null     str
# dtypes: int64(3), str(5)
# memory usage: 2.6 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit             129 non-null    str
#  1   Serial Number    129 non-null    int64
#  2   Phone Number     114 non-null    str
#  3   Last Contact On  129 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 4.2 KB

# %%
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]
list_field05=[]   
list_field06=[]
list_field07=[]       
#print("df_book_table01[8,0]: ",df_book_table01.iloc[8,0]) #UnitsByDealer.csv_r.csv
#print("df_book_table02[8,5]: ",df_book_table02.iloc[8,5]) #6MB.        
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='Phone'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='Phone Number'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]): 
        if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):                                                                             
            list_field01.append(df_book_table01.iloc[i,0])
            list_field02.append(df_book_table01.iloc[i,1])
            list_field03.append(df_book_table01.iloc[i,2])
            list_field04.append(df_book_table01.iloc[i,3])
            list_field05.append(df_book_table01.iloc[i,4])
            list_field06.append(df_book_table01.iloc[i,5])
            list_field07.append(df_book_table01.iloc[i,6])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['Unit']=list_field01
df_aux['Serial Number']=list_field02
df_aux['Phone']=list_field03
df_aux['Last contact on']=list_field04
df_aux['text']=list_field05
df_aux['status']=list_field06
df_aux['date']=list_field07

print("Cont= ",cont)
print(df_aux.info())
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    df_aux.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\coincidences_f.csv')                  #Edit
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):
                df_book_table02.iloc[j,3]=np.nan
                print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    #print(df_book_table02)
    df_book_table02.dropna(axis=0,inplace=True)
    print(df_book_table02)
    df_book_table02.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\corporacion_rico\differences_f.csv')          #Edit

#lista_combinada=[lista_simcard,lista_linea]
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       40 non-null     int64
#  1   Unit             40 non-null     str
#  2   Serial Number    40 non-null     int64
#  3   Phone            40 non-null     int64
#  4   Last contact on  40 non-null     str
#  5   text             40 non-null     str
#  6   status           40 non-null     str
#  7   date             40 non-null     str
# dtypes: int64(3), str(5)
# memory usage: 2.6 KB
# None
#
# Tabla 2:
# <class 'pandas.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit             129 non-null    str
#  1   Serial Number    129 non-null    int64
#  2   Phone Number     114 non-null    str
#  3   Last Contact On  129 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 4.2 KB
# None
#
# Atributo de la tabla1:  3
# Atributo de la tabla2:  2
#
# Trabajando...
# df_book_table01[i,position_table01]:  958984392  = df_book_table02[j,position_table02]:  958984392
# df_book_table01[i,position_table01]:  986154879  = df_book_table02[j,position_table02]:  986154879
# df_book_table01[i,position_table01]:  969773925  = df_book_table02[j,position_table02]:  969773925
# df_book_table01[i,position_table01]:  987865324  = df_book_table02[j,position_table02]:  987865324
# df_book_table01[i,position_table01]:  997373161  = df_book_table02[j,position_table02]:  997373161
# df_book_table01[i,position_table01]:  982015608  = df_book_table02[j,position_table02]:  982015608
# df_book_table01[i,position_table01]:  982916737  = df_book_table02[j,position_table02]:  982916737
# df_book_table01[i,position_table01]:  982917864  = df_book_table02[j,position_table02]:  982917864
# df_book_table01[i,position_table01]:  982906102  = df_book_table02[j,position_table02]:  982906102
# df_book_table01[i,position_table01]:  961851749  = df_book_table02[j,position_table02]:  961851749
# df_book_table01[i,position_table01]:  987844693  = df_book_table02[j,position_table02]:  987844693
# df_book_table01[i,position_table01]:  982916535  = df_book_table02[j,position_table02]:  982916535
# df_book_table01[i,position_table01]:  982908928  = df_book_table02[j,position_table02]:  982908928
# df_book_table01[i,position_table01]:  961763573  = df_book_table02[j,position_table02]:  961763573
# df_book_table01[i,position_table01]:  987660823  = df_book_table02[j,position_table02]:  987660823
# df_book_table01[i,position_table01]:  993428410  = df_book_table02[j,position_table02]:  993428410
# df_book_table01[i,position_table01]:  99999999  = df_book_table02[j,position_table02]:  99999999
# df_book_table01[i,position_table01]:  987105326  = df_book_table02[j,position_table02]:  987105326
# df_book_table01[i,position_table01]:  983368003  = df_book_table02[j,position_table02]:  983368003
# df_book_table01[i,position_table01]:  982908448  = df_book_table02[j,position_table02]:  982908448
# df_book_table01[i,position_table01]:  961444436  = df_book_table02[j,position_table02]:  961444436
# df_book_table01[i,position_table01]:  993426614  = df_book_table02[j,position_table02]:  993426614
# df_book_table01[i,position_table01]:  994343125  = df_book_table02[j,position_table02]:  994343125
# df_book_table01[i,position_table01]:  994343125  = df_book_table02[j,position_table02]:  994343125
# df_book_table01[i,position_table01]:  997538749  = df_book_table02[j,position_table02]:  997538749
# df_book_table01[i,position_table01]:  997538749  = df_book_table02[j,position_table02]:  997538749
# df_book_table01[i,position_table01]:  993197837  = df_book_table02[j,position_table02]:  993197837
# df_book_table01[i,position_table01]:  993197837  = df_book_table02[j,position_table02]:  993197837
# df_book_table01[i,position_table01]:  982908578  = df_book_table02[j,position_table02]:  982908578
# df_book_table01[i,position_table01]:  982908578  = df_book_table02[j,position_table02]:  982908578
# df_book_table01[i,position_table01]:  987862116  = df_book_table02[j,position_table02]:  987862116
# df_book_table01[i,position_table01]:  987862116  = df_book_table02[j,position_table02]:  987862116
# df_book_table01[i,position_table01]:  993429278  = df_book_table02[j,position_table02]:  993429278
# df_book_table01[i,position_table01]:  993429278  = df_book_table02[j,position_table02]:  993429278
# df_book_table01[i,position_table01]:  997501638  = df_book_table02[j,position_table02]:  997501638
# df_book_table01[i,position_table01]:  997501638  = df_book_table02[j,position_table02]:  997501638
# df_book_table01[i,position_table01]:  983363227  = df_book_table02[j,position_table02]:  983363227
# df_book_table01[i,position_table01]:  983363227  = df_book_table02[j,position_table02]:  983363227
# df_book_table01[i,position_table01]:  987861495  = df_book_table02[j,position_table02]:  987861495
# df_book_table01[i,position_table01]:  987861495  = df_book_table02[j,position_table02]:  987861495
# Cont=  40
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unit             40 non-null     int64
#  1   Serial Number    40 non-null     str
#  2   Phone            40 non-null     int64
#  3   Last contact on  40 non-null     int64
#  4   text             40 non-null     str
#  5   status           40 non-null     str
#  6   date             40 non-null     str
# dtypes: int64(3), str(4)
# memory usage: 2.3 KB
# None
