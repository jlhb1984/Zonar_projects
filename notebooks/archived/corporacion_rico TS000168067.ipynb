# %%
import pandas as pd
import numpy as np

# %%
hl_vfw970=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\corporacion_rico\historicallocations.xlsx - Sheet1.csv',sep=',')
hl_vfw970.info()
hl_vfw970['Eventos'].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23739 entries, 0 to 23738
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Secuencia       23739 non-null  int64
#  1   Unidad          23739 non-null  str
#  2   Eventos         23739 non-null  str
#  3   Fecha           23739 non-null  str
#  4   Pt. Referencia  942 non-null    str
#  5   Dirección       23739 non-null  str
#  6   Velocidad       23739 non-null  int64
#  7   Temperatura     0 non-null      float64
#  8   Conductor       0 non-null      float64
#  9   Latitud         23739 non-null  float64
#  10  Longitud        23739 non-null  float64
# dtypes: float64(4), int64(2), str(5)
# memory usage: 2.0 MB
# Eventos
# Estacionado              16635
# Conduciendo               5111
# Inmóvil - Detenido         256
# Inicio de Viaje            246
# Viaje detenido             230
# Ignición Encendida         217
# Ignición Apagada           216
# ...

# %%
for i in range(0,hl_vfw970.shape[0]):
    if hl_vfw970.iloc[i,2]=='Giro Brusco':
        print(hl_vfw970.iloc[i,3],hl_vfw970.iloc[i,1],hl_vfw970.iloc[i,2])
# Out:
# Feb 25 2026 02:10 AM VFW-970 Giro Brusco
# Feb 25 2026 02:05 AM VFW-970 Giro Brusco
# Feb 23 2026 02:24 AM VFW-970 Giro Brusco
# Feb 20 2026 02:01 AM VFW-970 Giro Brusco
# Feb 18 2026 02:09 AM VFW-970 Giro Brusco
# Feb 06 2026 01:09 AM VFW-970 Giro Brusco

# %%
for i in range(0,hl_vfw970.shape[0]):
    if hl_vfw970.iloc[i,2]=='Conduciendo':
        print(hl_vfw970.iloc[i,3],hl_vfw970.iloc[i,1],hl_vfw970.iloc[i,2],hl_vfw970.iloc[i,6])
# Out:
# Mar 03 2026 02:29 AM VFW-970 Conduciendo 35
# Mar 03 2026 02:28 AM VFW-970 Conduciendo 33
# Mar 03 2026 02:28 AM VFW-970 Conduciendo 35
# Mar 03 2026 02:28 AM VFW-970 Conduciendo 33
# Mar 03 2026 02:27 AM VFW-970 Conduciendo 43
# Mar 03 2026 02:27 AM VFW-970 Conduciendo 43
# Mar 03 2026 02:26 AM VFW-970 Conduciendo 41
# Mar 03 2026 02:26 AM VFW-970 Conduciendo 35
# Mar 03 2026 02:26 AM VFW-970 Conduciendo 35
# Mar 03 2026 02:26 AM VFW-970 Conduciendo 43
# Mar 03 2026 02:26 AM VFW-970 Conduciendo 41
# Mar 03 2026 02:26 AM VFW-970 Conduciendo 43
# Mar 03 2026 02:25 AM VFW-970 Conduciendo 38
# Mar 03 2026 02:25 AM VFW-970 Conduciendo 35
# Mar 03 2026 02:25 AM VFW-970 Conduciendo 37
# Mar 03 2026 02:25 AM VFW-970 Conduciendo 38
# Mar 03 2026 02:25 AM VFW-970 Conduciendo 38
# Mar 03 2026 02:25 AM VFW-970 Conduciendo 46
# Mar 03 2026 02:24 AM VFW-970 Conduciendo 41
# Mar 03 2026 02:24 AM VFW-970 Conduciendo 41
# Mar 03 2026 02:23 AM VFW-970 Conduciendo 41
# ...

# %% [markdown]
# Event codes only for No User messages.
# Harsh Turn: 35 on Hex, 53 on Dec

# %%
raw_vfw970=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\corporacion_rico\Export.xlsx - Sheet1.csv',sep=',')
raw_vfw970.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24445 entries, 0 to 24444
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  24445 non-null  str
#  1   Message  24445 non-null  str
#  2   Status   24445 non-null  str
# dtypes: str(3)
# memory usage: 573.1 KB

# %%
event_code=[]

for i in range(0,raw_vfw970.shape[0]):
    event_code.append(raw_vfw970.iloc[i,2][64:66])
        
    if raw_vfw970.iloc[i,2][64:66]=='35':
        print(raw_vfw970.iloc[i,0],' -> ',raw_vfw970.iloc[i,2][64:66])
# Out:
# 2026-02-04 06:07:56.638  ->  35
# 2026-02-06 06:10:59.752  ->  35
# 2026-02-18 07:11:22.615  ->  35
# 2026-02-20 07:01:32.925  ->  35
# 2026-02-23 07:30:54.024  ->  35
# 2026-02-25 07:05:34.217  ->  35
# 2026-02-25 07:10:46.012  ->  35
