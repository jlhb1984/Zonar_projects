# %%
import pandas as pd 
import numpy as np
import datetime

# %% [markdown]
# 8B5221H4

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\8B5221H4_rawdata.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8834 entries, 0 to 8833
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Row Id                     8834 non-null   int64
#  1   Sequence #                 0 non-null      float64
#  2   Server Time                8834 non-null   str
#  3   Unit Time                  8834 non-null   str
#  4   Last Message Time          8834 non-null   str
#  5   Latitude                   8834 non-null   float64
#  6   Longitude                  8834 non-null   float64
#  7   Driver Name                0 non-null      float64
#  8   Event Name                 8834 non-null   str
#  9   Raw Event                  8834 non-null   str
#  10  Address                    8832 non-null   str
#  11  GPS Speed                  7026 non-null   float64
#  12  ECU Speed                  0 non-null      float64
#  13  Speed Limit                1403 non-null   float64
# ...

# %%
battery=vf[vf['Raw Data'].str.contains('Bat')]
battery
# Out:
#             Row Id  Sequence #          Server Time            Unit Time  \
# 7458  177812693717         NaN  2026/05/06 23:08:57  2026/05/06 22:15:59
#
#         Last Message Time  Latitude  Longitude  Driver Name  Event Name  \
# 7458  2026/05/06 23:08:58  6.250899  -75.54848          NaN  Power Lost
#
#                    Raw Event  ... ECU Engine Hours + Off  Engine Odometer  \
# 7458  CameraEvent.POWER_LOST  ...                      0           883.27
#
#       Engine Odometer + Off  ECU Engine Odometer  ECU Engine Odometer + Off  \
# 7458                 883.27                    0                          0
#
#       HDOP VDOP RSSI  Battery Level  \
# 7458  0.69  NaN  NaN            NaN
#
#                                                Raw Data
# 7458  "{\"ingestVersion\":\"1.0.4\",\"linkedMode\":1...
#
# [1 rows x 50 columns]

# %%
vf['Event Name'].value_counts()
# Out:
# Event Name
# AutoSnapshot             2027
# Idle                     1776
# Ignition On              1112
# Ignition Off             1111
# Travel Stop               873
# Travel Start              870
# Drive                     522
# Power Lost                153
# Main Power Disconnect     151
# Main Power Connect        144
# No Seatbelt                78
# Hard Brake                  9
# Stop Sign Violation         6
# Drowsiness                  1
# Rapid Acceleration          1
# Name: count, dtype: int64

# %% [markdown]
# Ignition

# %%
vf_ignition=vf[vf['Event Name'].str.contains('Ignition Off')]
vf_ignition[['Event Name','Server Time','Unit Time','Last Message Time']]#.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\8B5221H4_ignition_off.csv')
# Out:
#         Event Name          Server Time            Unit Time  \
# 0     Ignition Off  2026/05/26 15:28:21  2026/05/26 15:28:10
# 21    Ignition Off  2026/05/26 14:42:29  2026/05/26 14:42:15
# 64    Ignition Off  2026/05/26 14:16:33  2026/05/26 14:16:16
# 80    Ignition Off  2026/05/26 13:43:05  2026/05/26 13:41:40
# 94    Ignition Off  2026/05/26 13:28:08  2026/05/26 13:27:46
# ...            ...                  ...                  ...
# 8785  Ignition Off  2026/05/01 06:08:56  2026/05/01 06:08:37
# 8791  Ignition Off  2026/05/01 06:05:56  2026/05/01 06:05:44
# 8796  Ignition Off  2026/05/01 06:00:58  2026/05/01 06:00:48
# 8814  Ignition Off  2026/05/01 05:37:06  2026/05/01 05:36:46
to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\8B5221H4_Power_Lost.csv')
# Out:
#       Event Name          Server Time            Unit Time  \
# 4760  Power Lost  2026/05/13 16:28:25  2026/05/13 16:27:53
# 4764  Power Lost  2026/05/13 16:24:13  2026/05/13 16:21:57
# 4773  Power Lost  2026/05/13 16:01:13  2026/05/13 16:00:51
# 5026  Power Lost  2026/05/13 09:28:36  2026/05/13 09:24:53
# 5036  Power Lost  2026/05/13 09:15:46  2026/05/13 09:15:01
# ...          ...                  ...                  ...
# 8669  Power Lost  2026/05/01 10:27:49  2026/05/01 10:27:13
# 8678  Power Lost  2026/05/01 10:09:09  2026/05/01 10:08:27
# 8690  Power Lost  2026/05/01 09:13:40  2026/05/01 09:13:11
# 8768  Power Lost  2026/05/01 06:59:19  2026/05/01 06:27:55
# 8813  Power Lost  2026/05/01 05:53:28  2026/05/01 05:53:11
#
#         Last Message Time
# 4760  2026/05/13 16:28:26
# 4764  2026/05/13 16:24:14
# 4773  2026/05/13 16:01:13
# 5026  2026/05/13 09:28:36
# 5036  2026/05/13 09:15:46
# ...                   ...
# 8669  2026/05/01 10:27:50
# 8678  2026/05/01 10:09:09
# ...

# %% [markdown]
# Restore Cable from Troubleshooting + Power Lost

# %%
ts=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\8B5221H4_restore_cable.csv',sep=',')
ts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Camera ESN      220 non-null    str
#  1   Reason          220 non-null    str
#  2   Powered By      219 non-null    str
#  3   Created Time    220 non-null    str
#  4   Power Off Time  111 non-null    str
#  5   Recover Time    105 non-null    str
#  6   Last Gps Data   220 non-null    str
# dtypes: str(7)
# memory usage: 12.2 KB

# %%
ts['Reason'].value_counts()
# Out:
# Reason
# lostWhileParking    110
# restoreCable        109
# lostWhileDriving      1
# Name: count, dtype: int64

# %%
ts[['Power Off Time','Reason','Created Time']]#.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\8B5221H4_restore_cable_events.csv')
# Out:
#              Power Off Time            Reason            Created Time
# 0                       NaN      restoreCable  May 13 2026 4:41:26 pm
# 1    May 13 2026 4:27:56 pm  lostWhileParking  May 13 2026 4:27:58 pm
# 2                       NaN      restoreCable  May 13 2026 4:27:57 pm
# 3    May 13 2026 4:22:00 pm  lostWhileParking  May 13 2026 4:22:02 pm
# 4                       NaN      restoreCable  May 13 2026 4:19:32 pm
# ..                      ...               ...                     ...
# 215  May 06 2026 9:43:25 am  lostWhileParking  May 06 2026 9:43:25 am
# 216                     NaN      restoreCable  May 06 2026 9:43:01 am
# 217  May 06 2026 9:41:29 am  lostWhileParking  May 06 2026 9:41:29 am
# 218                     NaN      restoreCable  May 06 2026 8:07:11 am
# 219  May 06 2026 7:51:03 am  lostWhileParking  May 06 2026 7:51:04 am
#
# [220 rows x 3 columns]
