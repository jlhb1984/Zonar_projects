# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Chart of values: This part of the notebook is for troubleshooting and graphical analysis.

# %%
#raw_fuel_data=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\Export.xlsx - Sheet1.csv',sep=',',encoding='latin1') #csv
raw_fuel_data=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\comciza\Export.xlsx') #excel
raw_fuel_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4607 entries, 0 to 4606
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  4607 non-null   str
#  1   Message  4607 non-null   str
#  2   Status   4607 non-null   str
# dtypes: str(3)
# memory usage: 108.1 KB

# %%
e0x=raw_fuel_data[raw_fuel_data['Status'].str.contains('3E0')]
row_number=e0x.shape[0]
e0x.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\comciza\Export_raw_e0.csv')

# %%
fs01_dec_value=[]
fs02_dec_value=[]
last_index_fs01=[]
last_index_fs02=[]
date_fs01_dec_value=[]
date_fs02_dec_value=[]
values_dates_fs01=pd.DataFrame()
values_dates_fs02=pd.DataFrame()

for i in range(0,row_number):
    e0x_aux=e0x.iloc[i,2]
    aux=e0x_aux.find('3E01')    
    if len(e0x_aux)>0:
        fs01=(e0x_aux[aux:aux+18])
        if len(fs01)>17:
            msb=fs01[10:12]
            lsb=fs01[8:10]
            measure=msb+lsb
            fs01_dec_value.append(int(measure,16))
            date_fs01_dec_value.append(e0x.iloc[i,0])
            #last_index_fs01=i
            msb=fs01[28:30]
            lsb=fs01[26:28]
            fs01_dec_value.append(int(measure,16))
            date_fs01_dec_value.append(e0x.iloc[i,0]) 
            msb=fs01[46:48]
            lsb=fs01[44:46]
            fs01_dec_value.append(int(measure,16))
            date_fs01_dec_value.append(e0x.iloc[i,0])
            msb=fs01[46:48]
            lsb=fs01[44:46]
            fs01_dec_value.append(int(measure,16))
            date_fs01_dec_value.append(e0x.iloc[i,0])
            msb=fs01[64:66]
            lsb=fs01[62:64]        
            
#print(i, raw_fuel_data.iloc[i,0] )

for i in range(0,row_number):
    e0x_aux=e0x.iloc[i,2]
    aux=e0x_aux.find('3E02')
    if len(e0x_aux)>0:
        fs02=e0x_aux[aux:aux+18]
        if len(fs02)>17:
            msb=fs02[10:12]
            lsb=fs02[8:10]
            measure=msb+lsb
            fs02_dec_value.append(int(measure,16))
            date_fs02_dec_value.append(e0x.iloc[i,0])
            #last_index_fs02=i
            msb=fs02[28:30]
            lsb=fs02[26:28]
            fs02_dec_value.append(int(measure,16))
            date_fs02_dec_value.append(e0x.iloc[i,0]) 
            msb=fs02[46:48]
            lsb=fs02[44:46]
            fs02_dec_value.append(int(measure,16))
            date_fs02_dec_value.append(e0x.iloc[i,0])
            msb=fs02[46:48]
            lsb=fs02[44:46]
            fs02_dec_value.append(int(measure,16))
            date_fs02_dec_value.append(e0x.iloc[i,0])
            msb=fs02[64:66]
            lsb=fs02[62:64]        
            
        #print(fs01_cad)   

fs01_count=len(fs01_dec_value)
fs02_count=len(fs02_dec_value)
values_dates_fs01['Value fs01']=fs01_dec_value
values_dates_fs01['Dates fs01']=date_fs01_dec_value
values_dates_fs02['Value fs02']=fs02_dec_value
values_dates_fs02['Dates fs02']=date_fs02_dec_value

#print('El Ncode en decimal es:')
print("Tank 1: ",fs01_dec_value,fs01_count)
print("Tank 2: ",fs02_dec_value,fs02_count)

print("Last fuel report fs01: ",e0x.iloc[last_index_fs01,0],"Last fuel report fs02: ",e0x.iloc[last_index_fs02,0])
# Out:
# Tank 1:  [1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1730, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1729, 1728, 1728, 1728, 1728, 1724, 1724, 1724, 1724, 1709, 1709, 1709, 1709, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1722, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1718, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1719, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1720, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721, 1721,  ...
# Tank 2:  [2566, 2566, 2566, 2566] 4
# Last fuel report fs01:  Series([], Name: Created, dtype: str) Last fuel report fs02:  Series([], Name: Created, dtype: str)

# %%
fs01_x_values=[]
fs02_x_values=[]

for i in range(0,fs01_count):
    fs01_x_values.append(i)
    
for i in range(0,fs02_count):
    fs02_x_values.append(i)

#plt.xlim(1300,1400)
plt.plot(fs01_x_values,fs01_dec_value)
#plt.plot(fs02_x_values,fs02_dec_value)

# %%
plt.plot(fs02_x_values,fs02_dec_value)
#plt.plot(fs02_x_values,fs02_dec_value)

# %%
report_tank1=pd.DataFrame()
report_tank1['Tank1']=fs01_dec_value
report_tank1['Date']=date_fs01_dec_value
report_tank1
# Out:
#       Tank1                     Date
# 0      1730  2026-04-08 00:00:54.776
# 1      1730  2026-04-08 00:00:54.776
# 2      1730  2026-04-08 00:00:54.776
# 3      1730  2026-04-08 00:00:54.776
# 4      1730  2026-04-08 00:04:54.972
# ...     ...                      ...
# 1351   3854  2026-04-22 14:23:53.951
# 1352   3854  2026-04-22 15:52:59.242
# 1353   3854  2026-04-22 15:52:59.242
# 1354   3854  2026-04-22 15:52:59.242
# 1355   3854  2026-04-22 15:52:59.242
#
# [1356 rows x 2 columns]

# %%
report_tank2=pd.DataFrame()
report_tank2['Tank2']=fs01_dec_value
report_tank2['Date']=date_fs01_dec_value
report_tank2
# Out:
#       Tank2                     Date
# 0      1730  2026-04-08 00:00:54.776
# 1      1730  2026-04-08 00:00:54.776
# 2      1730  2026-04-08 00:00:54.776
# 3      1730  2026-04-08 00:00:54.776
# 4      1730  2026-04-08 00:04:54.972
# ...     ...                      ...
# 1351   3854  2026-04-22 14:23:53.951
# 1352   3854  2026-04-22 15:52:59.242
# 1353   3854  2026-04-22 15:52:59.242
# 1354   3854  2026-04-22 15:52:59.242
# 1355   3854  2026-04-22 15:52:59.242
#
# [1356 rows x 2 columns]

# %%
hl=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\comciza\historicallocations.xlsx') #excel
hl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4491 entries, 0 to 4490
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     4491 non-null   int64
#  1   Unit         4491 non-null   str
#  2   Events       4491 non-null   str
#  3   Date         4491 non-null   str
#  4   Landmark     11 non-null     str
#  5   Address      4490 non-null   str
#  6   Speed        4491 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       0 non-null      float64
#  9   Latitude     4491 non-null   float64
#  10  Longitude    4491 non-null   float64
# dtypes: float64(4), int64(2), str(5)
# memory usage: 386.1 KB

# %%
hl['Events'].value_counts()
# Out:
# Events
# Drive               1639
# Travel Start         460
# Travel Stop          459
# Parked               381
# POWER UP             362
# End Speeding         240
# Speed alert          240
# Ignition ON          202
# Idle - Stop          200
# Ignition OFF         182
# Idle Alert           122
# Harsh Turn             1
# Landmark OUT           1
# Landmark IN            1
# Towing/Drifting?       1
# Name: count, dtype: int64
