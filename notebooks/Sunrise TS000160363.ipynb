# %%
import pandas as pd 
import numpy as np
import datetime

# %% [markdown]
# Units

# %%
cu=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\Customer-Units.csv',sep=',')
cu.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       21 non-null     int64
#  1   Owner                    21 non-null     str
#  2   Unit ID                  21 non-null     str
#  3   Unit                     21 non-null     str
#  4   Peripherals              1 non-null      str
#  5   Billing Period           21 non-null     str
#  6   Reporting Status         0 non-null      float64
#  7   Show Until               0 non-null      float64
#  8   Billing Group            0 non-null      float64
#  9   Last Event Date          21 non-null     str
#  10  Monthly Fee              21 non-null     int64
#  11  Bill To                  1 non-null      str
#  12  Assigned To              21 non-null     str
#  13  Linked Mode              21 non-null     int64
# ...

# %%
cu_air2_cameras=cu[cu['Unit'].str.contains('A')]
cu_vf_cameras=cu[cu['Unit'].str.contains('VF')]
cu_total=pd.concat([cu_air2_cameras,cu_vf_cameras])
cu_total.drop_duplicates(inplace=True)
cu_cameras=cu_total[~cu_total['Unit'].str.contains('PRZ506 B BRAUN SURGI')]
print(cu_cameras['Unit'])
# Out:
# 0        QJX106 AIR2
# 2        QJL983 AIR2
# 4      PRZ507 VF-AR2
# 6     PRZ506 VF-AIR2
# 9        PRZ505 AIR2
# 19       OJX103 AIR2
# 11         PRZ061 VF
# 13         PRZ060 VF
# 15         PRZ047 VF
# 17         PMX778 VF
# Name: Unit, dtype: str

# %% [markdown]
# qjx106

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\qjx106.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3958 entries, 0 to 3957
# Columns: 104 entries, Message to Unnamed: 103
# dtypes: float64(4), str(100)
# memory usage: 3.1 MB

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"DROWSINESS"                      71
# event:"USING_PHONE"                     25
# event:"STOP_SIGN_VIOLATION"              5
# event:"SHARP_TURN"                       3
# event:"YAWN"                             3
# event:"HARD_BRAKE"                       2
# event:"NO_SEATBELT"                      1
# event:"HEADWAY_MONITORING_EMERGENCY"     1
# event:"POTENTIAL_INCIDENT_LOW"           1
# Name: count, dtype: int64

# %%
vf_drowsiness=vf[vf['Unnamed: 4'].str.contains('DROWSINESS')]

for i in range(0,vf_drowsiness.shape[0]):
    aux=float(vf_drowsiness.iloc[i,9][5:18])/1000
    #print(datetime.datetime.utcfromtimestamp(aux))

# %% [markdown]
# qjl983

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\qjl983.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 57 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      134 non-null    str
#  1   Unnamed: 1   134 non-null    str
#  2   Unnamed: 2   134 non-null    str
#  3   Unnamed: 3   134 non-null    str
#  4   Unnamed: 4   134 non-null    str
#  5   Unnamed: 5   134 non-null    str
#  6   Unnamed: 6   134 non-null    str
#  7   Unnamed: 7   134 non-null    str
#  8   Unnamed: 8   134 non-null    str
#  9   Unnamed: 9   134 non-null    str
#  10  Unnamed: 10  134 non-null    str
#  11  Unnamed: 11  134 non-null    str
#  12  Unnamed: 12  134 non-null    str
#  13  Unnamed: 13  134 non-null    str
#  14  Unnamed: 14  134 non-null    str
#  15  Unnamed: 15  134 non-null    str
#  16  Unnamed: 16  134 non-null    str
#  17  Unnamed: 17  131 non-null    str
#  18  Unnamed: 18  123 non-null    str
#  19  Unnamed: 19  122 non-null    str
# ...

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"DROWSINESS"                      71
# event:"USING_PHONE"                     25
# event:"STOP_SIGN_VIOLATION"              5
# event:"SHARP_TURN"                       3
# event:"YAWN"                             3
# event:"HARD_BRAKE"                       2
# event:"NO_SEATBELT"                      1
# event:"HEADWAY_MONITORING_EMERGENCY"     1
# event:"POTENTIAL_INCIDENT_LOW"           1
# Name: count, dtype: int64

# %% [markdown]
# PRZ507 VF-AR2 possibel aux cam

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\prz507.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2479 entries, 0 to 2478
# Columns: 104 entries, Message to Unnamed: 103
# dtypes: float64(4), str(100)
# memory usage: 2.0 MB

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_LOW"    1
# event:"HARD_BRAKE"                1
# Name: count, dtype: int64

# %% [markdown]
# PRZ506 VF-AIR2

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\prz506.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5028 entries, 0 to 5027
# Columns: 152 entries, Message to Unnamed: 151
# dtypes: float64(8), str(144)
# memory usage: 5.8 MB
# ...

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"HARD_BRAKE"                      4
# event:"HEADWAY_MONITORING_EMERGENCY"    4
# event:"POTENTIAL_INCIDENT_LOW"          2
# Name: count, dtype: int64

# %% [markdown]
#  PRZ505 AIR2

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\prz505.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5192 entries, 0 to 5191
# Columns: 116 entries, Message to Unnamed: 115
# dtypes: float64(5), str(111)
# memory usage: 4.6 MB

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"HARD_BRAKE"    2
# event:"SHARP_TURN"    2
# Name: count, dtype: int64

# %% [markdown]
# OJX103 AIR2

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\ojx103.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3951 entries, 0 to 3950
# Columns: 104 entries, Message to Unnamed: 103
# dtypes: float64(4), str(100)
# memory usage: 3.1 MB

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"HARD_BRAKE"                      3
# event:"HEADWAY_MONITORING_EMERGENCY"    1
# event:"FORWARD_COLLISION_WARNING"       1
# event:"SHARP_TURN"                      1
# Name: count, dtype: int64

# %% [markdown]
# PRZ061 VF

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\prz061.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3729 entries, 0 to 3728
# Columns: 104 entries, Message to Unnamed: 103
# dtypes: float64(4), str(100)
# memory usage: 3.0 MB

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"    18
# event:"POTENTIAL_INCIDENT_MEDIUM"    16
# event:"POTENTIAL_INCIDENT_LOW"       10
# event:"HARD_BRAKE"                    2
# event:"SHARP_TURN"                    1
# Name: count, dtype: int64

# %% [markdown]
# prz060

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\prz060.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 152 entries, Message to Unnamed: 151
# dtypes: float64(8), str(144)
# memory usage: 3.6 MB

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"FORWARD_COLLISION_WARNING"       54
# event:"POTENTIAL_INCIDENT_MEDIUM"       14
# event:"POTENTIAL_INCIDENT_LOW"          11
# event:"HARD_ACCEL"                       1
# event:"HARD_BRAKE"                       1
# event:"HEADWAY_MONITORING_EMERGENCY"     1
# Name: count, dtype: int64

# %% [markdown]
# prz047

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\prz047.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2860 entries, 0 to 2859
# Data columns (total 92 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Message      2860 non-null   str
#  1   Unnamed: 1   2860 non-null   str
#  2   Unnamed: 2   2860 non-null   str
#  3   Unnamed: 3   2860 non-null   str
#  4   Unnamed: 4   2860 non-null   str
#  5   Unnamed: 5   2860 non-null   str
#  6   Unnamed: 6   2860 non-null   str
#  7   Unnamed: 7   2860 non-null   str
#  8   Unnamed: 8   2860 non-null   str
#  9   Unnamed: 9   2860 non-null   str
#  10  Unnamed: 10  2860 non-null   str
#  11  Unnamed: 11  2860 non-null   str
#  12  Unnamed: 12  2860 non-null   str
#  13  Unnamed: 13  2860 non-null   str
#  14  Unnamed: 14  2860 non-null   str
#  15  Unnamed: 15  2860 non-null   str
#  16  Unnamed: 16  2743 non-null   str
#  17  Unnamed: 17  2741 non-null   str
#  18  Unnamed: 18  2733 non-null   str
#  19  Unnamed: 19  2733 non-null   str
# ...

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"HARD_BRAKE"                1
# event:"POTENTIAL_INCIDENT_LOW"    1
# Name: count, dtype: int64

# %% [markdown]
# pmx778

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\pmx778.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7884 entries, 0 to 7883
# Columns: 128 entries, Message to Unnamed: 127
# dtypes: float64(6), str(122)
# memory usage: 7.7 MB
# C:\Users\Jose.Hurtado\AppData\Local\Temp\ipykernel_23240\2793430683.py:1: DtypeWarning: Columns (0: Unnamed: 104, 1: Unnamed: 105, 2: Unnamed: 107, 3: Unnamed: 108, 4: Unnamed: 109, 5: Unnamed: 110, 6: Unnamed: 111, 7: Unnamed: 112, 8: Unnamed: 113, 9: Unnamed: 114, 10: Unnamed: 115, 11: Unnamed: 116, 12: Unnamed: 117, 13: Unnamed: 119, 14: Unnamed: 120, 15: Unnamed: 121, 16: Unnamed: 122, 17: Unnamed: 123, 18: Unnamed: 124, 19: Unnamed: 125, 20: Unnamed: 126, 21: Unnamed: 127) have mixed types. Specify dtype option on import or set low_memory=False.
#   vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\sunrise\pmx778.csv',sep=',')

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"POTENTIAL_INCIDENT_LOW"       16
# event:"HARD_BRAKE"                   12
# event:"FORWARD_COLLISION_WARNING"     9
# event:"POTENTIAL_INCIDENT_MEDIUM"     1
# Name: count, dtype: int64
