# %%
import pandas as pd
import numpy as np

# %% [markdown]
# TSO report

# %%
idle_report_tso=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\invertrans\Idles Report_tso.csv',sep=',')
idle_report_tso.info()
idle_report_tso.head(2)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2928 entries, 0 to 2927
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   textbox12    2928 non-null   str
#  1   textbox16    2928 non-null   str
#  2   EventTime    2928 non-null   str
#  3   Address      2928 non-null   str
#  4   EndLandmark  1278 non-null   str
#  5   textbox25    2928 non-null   str
#  6   Driver       2928 non-null   str
#  7   textbox20    2928 non-null   str
# dtypes: str(8)
# memory usage: 183.1 KB
#   textbox12                     textbox16                 EventTime  \
# 0  CASTILLA  Unidad: KBY321 CASTIL CAMION  16/02/2026 12:35:00 a.m.
# 1  CASTILLA  Unidad: KBY321 CASTIL CAMION   16/02/2026 1:26:53 a.m.
#
#                    Address   EndLandmark textbox25 Driver  \
# 0  Vía Palmira-Candelaría   BOMBA TERPEL  00:00:15
# 1  Vía Palmira-Candelaría   BOMBA TERPEL  00:01:09
#
#                                            textbox20
# ...

# %% [markdown]
# Ignition report

# %%
idle_report_ignition=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\invertrans\idleReport_2026-02-17_ignition.csv',sep=',')
idle_report_ignition.info()
print('Mínimum: ',idle_report_ignition['Idle Time (minutes)'].min(),'Maximum: ',idle_report_ignition['Idle Time (minutes)'].max())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unit                 409 non-null    str
#  1   Time & Date (COT)    409 non-null    str
#  2   Driver               0 non-null      float64
#  3   Address              409 non-null    str
#  4   Event                409 non-null    str
#  5   Idle Time (minutes)  409 non-null    float64
# dtypes: float64(2), str(4)
# memory usage: 19.3 KB
# Mínimum:  1.03 Maximum:  241.13

# %% [markdown]
# Units reported by Jahidine:
# sn	report
# spl056	no
# wdl101	si
# wdm183	si
# wpk640	si
# wpk661	no
# znm975	si

# %% [markdown]
# SPL056

# %%
raw_data_spl056=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\invertrans\spl056.csv',sep=';',encoding='latin1')
raw_datam_spl056=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\invertrans\spl056_columns.csv',sep=';',encoding='latin1')
raw_datam_spl056.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_datam_spl056.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           12 non-null     str
#  1   Message Type      12 non-null     str
#  2   Protocole         12 non-null     str
#  3   IMEI              12 non-null     str
#  4   Serial            12 non-null     str
#  5   Mileage           12 non-null     str
#  6   Date              12 non-null     str
#  7   Ignition          12 non-null     str
#  8   Latitude          12 non-null     str
#  9   Longitude         12 non-null     str
#  10  Altitude          12 non-null     str
#  11  External Power    12 non-null     str
#  12  RPM               12 non-null     str
#  13  Speed             12 non-null     str
#  14  Satellite Number  12 non-null     str
#  15  Azimuth           12 non-null     str
#  16  Bettery level     12 non-null     str
# dtypes: str(17)
# memory usage: 1.7 KB

# %%
print("TSO report: ")
value_to_look=input('Type the value to look: ')
idle_report_tso_filtered=idle_report_tso[idle_report_tso['textbox16'].str.contains(value_to_look)]
idle_report_tso_filtered
# Out:
# TSO report:
#      textbox12                textbox16                 EventTime  \
# 2810  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 12:00:51 a.m.
# 2811  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 12:29:59 a.m.
# 2812  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 12:43:00 a.m.
# 2813  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 12:44:19 a.m.
# 2814  RIOPAILA  Unidad: ZNM975 RIOPAILA   16/02/2026 2:00:24 a.m.
# ...        ...                      ...                       ...
# 2878  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 10:06:56 p.m.
# 2879  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 10:12:47 p.m.
# 2880  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 10:39:43 p.m.
# 2881  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 11:19:48 p.m.
# 2882  RIOPAILA  Unidad: ZNM975 RIOPAILA  16/02/2026 11:22:30 p.m.
#
#                                                 Address         EndLandmark  \
# 2810      FV4J+M3 Roldanillo, Valle del Cauca, Colombia                 NaN
# ...

# %%
print("Ignition report: ")
idle_report_ignition_filtered=idle_report_ignition[idle_report_ignition['Unit'].str.contains(value_to_look)]
idle_report_ignition_filtered
# Out:
# Ignition report:
#                 Unit    Time & Date (COT)  Driver  \
# 366  ZNM975 RIOPAILA  02/16/2026 00:00 AM     NaN
# 367  ZNM975 RIOPAILA  02/16/2026 00:29 AM     NaN
# 368  ZNM975 RIOPAILA  02/16/2026 02:00 AM     NaN
# 369  ZNM975 RIOPAILA  02/16/2026 03:06 AM     NaN
# 370  ZNM975 RIOPAILA  02/16/2026 03:36 AM     NaN
# 371  ZNM975 RIOPAILA  02/16/2026 06:02 AM     NaN
# 372  ZNM975 RIOPAILA  02/16/2026 06:26 AM     NaN
# 373  ZNM975 RIOPAILA  02/16/2026 06:57 AM     NaN
# 374  ZNM975 RIOPAILA  02/16/2026 07:05 AM     NaN
# 375  ZNM975 RIOPAILA  02/16/2026 08:09 AM     NaN
# 376  ZNM975 RIOPAILA  02/16/2026 09:20 AM     NaN
# 377  ZNM975 RIOPAILA  02/16/2026 09:54 AM     NaN
# 378  ZNM975 RIOPAILA  02/16/2026 11:04 AM     NaN
# 379  ZNM975 RIOPAILA  02/16/2026 13:41 PM     NaN
# 380  ZNM975 RIOPAILA  02/16/2026 16:16 PM     NaN
# 381  ZNM975 RIOPAILA  02/16/2026 18:17 PM     NaN
# 382  ZNM975 RIOPAILA  02/16/2026 18:40 PM     NaN
# ...

# %%
#print('Mínimum value in TSO is ',idle_report_tso_filtered.min(),' and the maximum value in TSO is ',idle_report_tso_filtered.max())
print('Mínimum value in Ignition is ',idle_report_ignition_filtered['Idle Time (minutes)'].min(),' and the maximum value in Ignition is ',idle_report_ignition_filtered['Idle Time (minutes)'].max())
# Out:
# Mínimum value in Ignition is  2.02  and the maximum value in Ignition is  72.85
