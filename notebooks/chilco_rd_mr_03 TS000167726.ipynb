# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# eqy796

# %%
raw_data=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\eqy796_march.csv',sep=',')
raw_data_columns=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\chilco\eqy796_march_columns.csv',sep=',')
raw_data_columns['Date']='NaN'
raw_data_columns['Message_Type']='NaN'
aux_m=[]

#raw_data_columns['Message'].value_counts()

# %%
value_to_look=input('Type the date to searh (2026-03-01 00:40:00.074): ')
raw_events=raw_data[raw_data['Created'].str.contains(value_to_look)]
raw_events
# Out:
# Empty DataFrame
# Columns: [Created, Message, Status]
# Index: []

# %%
for i in range(0,raw_data_columns.shape[0]):
    aux_m.append(raw_data_columns.iloc[i,0][6:11])
raw_data_columns['Message_Type']=aux_m

gtfri_raw_data=raw_data_columns[raw_data_columns['Message'].str.contains('GTFRI')]

date_gtfri=[]

km_gtfri=[]

for i in range(0, gtfri_raw_data.shape[0]):
    date_gtfri.append(str(gtfri_raw_data.iloc[i,13]))    
    km_gtfri.append((float(gtfri_raw_data.iloc[i,20]))*0.621371)
gtfri_raw_data['Date']=date_gtfri
#gtfri_raw_data_eqz329_28_jan2026.info()
gtfri_raw_data['Km in miles']=km_gtfri

#202601021739
value_to_look=input('Type the date to searh: ')
gtfri_raw_data_wanted=gtfri_raw_data[gtfri_raw_data['Date'].str.contains(value_to_look)]
print(gtfri_raw_data_wanted[['Message','Date','Unnamed: 20','Km in miles']])
# Out:
#            Message            Date Unnamed: 20   Km in miles
# 25537  +RESP:GTFRI  20260329000610    121763.5  75660.307758

# %%
#GTPDP no tiene odómetro.
gtpdp_raw_data=raw_data_columns[raw_data_columns['Message'].str.contains('GTPDP')]

date_gtpdp=[]

km_gtpdp=[]

for i in range(0, gtpdp_raw_data.shape[0]):
    date_gtpdp.append(str(gtpdp_raw_data.iloc[i,13]))    
    km_gtpdp.append((float(gtpdp_raw_data.iloc[i,20]))*0.621371)
gtpdp_raw_data['Date']=date_gtpdp
#gtfri_raw_data_eqz329_28_jan2026.info()
gtpdp_raw_data['Km in miles']=km_gtpdp

#202601021739
value_to_look=input('Type the date to searh: ')
gtpdp_raw_data_wanted=gtpdp_raw_data[gtpdp_raw_data['Date'].str.contains(value_to_look)]
print(gtpdp_raw_data_wanted[['Message','Date','Unnamed: 20','Km in miles']])
# Out:
# Empty DataFrame
# Columns: [Message, Date, Unnamed: 20, Km in miles]
# Index: []
