# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
esp840=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zona_logistica\esp840_1824_022026.csv',sep=',')
esp840.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16385 entries, 0 to 16384
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  16385 non-null  str
#  1   Message  16385 non-null  str
#  2   Status   16385 non-null  str
# dtypes: str(3)
# memory usage: 384.2 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
esp840_odometer=pd.DataFrame()
cont=0

for i in range (0, esp840.shape[0]):
    l=len(esp840.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(esp840.iloc[i,2][68:76],16))
        aux_miles.append((int(esp840.iloc[i,2][68:76],16))*0.621371)
        cont=cont+1 

esp840_odometer['Odometer in']=aux
esp840_odometer['Odometer en miles']=aux_miles

for i in range(0,cont):
    x_axis.append(i)

esp840_odometer
plt.plot(x_axis,aux)

# %% [markdown]
# Data analysis since 16-02-2026 to 20-02-2026.

# %%
esp840=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zona_logistica\esp840_1620_02_2026.csv',sep=',')
esp840.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12896 entries, 0 to 12895
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  12896 non-null  str
#  1   Message  12896 non-null  str
#  2   Status   12896 non-null  str
# dtypes: str(3)
# memory usage: 302.4 KB

# %%
aux=[]
aux_miles=[]
x_axis=[]
date=[]
esp840_odometer=pd.DataFrame()
cont=0

for i in range (0, esp840.shape[0]):
    l=len(esp840.iloc[i,2])
    #print('Len=',l)
    if l<180:
        aux.append(int(esp840.iloc[i,2][68:76],16))
        aux_miles.append((int(esp840.iloc[i,2][68:76],16))*0.000621371)
        date.append(esp840.iloc[i,0])
        cont=cont+1 

for i in range(0,cont):
    x_axis.append(i)

esp840_odometer['Odometer in meters']=aux
esp840_odometer['Odometer en miles']=aux_miles
esp840_odometer['Date']=date
esp840_odometer['x']=x_axis

esp840_odometer.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zona_logistica\esp840_1620_02_2026_data.csv')

esp840_odometer
plt.plot(x_axis,aux)

# %%
ar_esp840=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\zona_logistica\ar_esp840_19022026.csv',sep=',')
ar_esp840.info()

ar_esp840['Distancia Conducida'].sort_values(ascending=False)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Hora de Inicio       103 non-null    str
#  1   Unnamed: 1           0 non-null      float64
#  2   Tiempo Viajado       103 non-null    str
#  3   Distancia Conducida  103 non-null    float64
#  4   Vel. Máxima          103 non-null    float64
#  5   Hora de Parada       103 non-null    str
#  6   Evento de Parada     101 non-null    str
#  7   Unnamed: 7           0 non-null      float64
#  8   Unnamed: 8           0 non-null      float64
#  9   Unnamed: 9           0 non-null      float64
#  10  Tiempo Detenido      103 non-null    str
#  11  Dirección            101 non-null    str
# dtypes: float64(6), str(6)
# memory usage: 9.9 KB
# 103    204.26
# 101    204.26
# 77      79.76
# 69      15.87
# 44      11.56
#         ...
# 84       0.00
# 80       0.00
# 76       0.00
# ...

# %%
for i in range(0,ar_esp840.shape[0]):
    if ar_esp840.iloc[i,3]>5:
        print(ar_esp840.iloc[i,0]," -> ",ar_esp840.iloc[i,5],"   ",ar_esp840.iloc[i,2],"   ",ar_esp840.iloc[i,3])
