# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Export Alerts Report from TSO.
#
# 4764429210	33333333		    85f	55,182
#
# 4764429242	972564107	BHI-774	85f	55,182
#
# 4764429241	972573025	BHA-863	85f	55,182
#
# 4764429268	987457988	BCZ-718	85f	55,182
#
# 4764428940	972565498	BCY-928	85f	55,182

# %%
alerts=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\don_pollo\Alerts Report.csv',sep=',')
alerts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3501 entries, 0 to 3500
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GroupName    3431 non-null   str
#  1   UnitName     3501 non-null   str
#  2   textbox4     3501 non-null   str
#  3   StartTime    3501 non-null   str
#  4   ContactName  3463 non-null   str
#  5   DriverName   3501 non-null   str
#  6   textbox11    3501 non-null   str
# dtypes: str(7)
# memory usage: 191.6 KB

# %%
alerts['textbox4'].value_counts()
# Out:
# textbox4
# Geofence Alert    2473
# Idle Alert         757
# Speeding Alert     271
# Name: count, dtype: int64

# %%
idle_alert=alerts[alerts['textbox4'].str.contains('Idle')]
idle_alert['UnitName'].to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\don_pollo\Units.csv')

# %%
plate=input('Type the number plate: ')
idle_alert_1=idle_alert[idle_alert['UnitName'].str.contains(plate)]
idle_alert_1
# Out:
#         GroupName       UnitName    textbox4             StartTime  \
# 115       Calzada  Unit: BCY-866  Idle Alert   7/05/2026 8:53 a.m.
# 116       Calzada  Unit: BCY-866  Idle Alert   7/05/2026 7:40 a.m.
# 117       Calzada  Unit: BCY-866  Idle Alert   7/05/2026 7:09 p.m.
# 2291  SEGUIMIENTO  Unit: BCZ-714  Idle Alert   7/05/2026 2:50 p.m.
# 2292  SEGUIMIENTO  Unit: BCZ-714  Idle Alert   8/05/2026 3:41 p.m.
# 2293  SEGUIMIENTO  Unit: BCZ-714  Idle Alert   7/05/2026 7:58 a.m.
# 2294  SEGUIMIENTO  Unit: BCZ-714  Idle Alert  7/05/2026 12:36 a.m.
# 2295  SEGUIMIENTO  Unit: BCZ-714  Idle Alert   7/05/2026 7:22 a.m.
# 2296  SEGUIMIENTO  Unit: BCZ-714  Idle Alert   7/05/2026 4:40 p.m.
#
#                                             ContactName  \
# 115                             XW4Q+3C Moyobamba, Peru
# 116   Av Pe-08b Km 482, Calzada, Moyobamba, San Mart...
# 117            Pe-5n-65, Rioja, Rioja, San Martín, Perú
# 2291                               4MC5+G3 Picota, Peru
# 2292                                                NaN
# 2293  Pe-5n Km 673, Buenos Aires, Picota, San Martín...
# 2294                               4MC5+R7 Picota, Peru
# 2295                               4MC5+G2 Picota, Peru
# 2296                             4JPP+JQ Pucacaca, Peru
#
#                      DriverName      textbox11
# 115   WALTER AGUILAR FERNANDEZ   00h:31m14s
# 116   WALTER AGUILAR FERNANDEZ   00h:31m55s
# 117   WALTER AGUILAR FERNANDEZ   00h:30m44s
# 2291        GEMMER TELLO SALAS   00h:30m21s
# 2292        GEMMER TELLO SALAS   00h:32m48s
# 2293        GEMMER TELLO SALAS   00h:48m44s
# 2294        GEMMER TELLO SALAS   00h:31m29s
# 2295        GEMMER TELLO SALAS   00h:55m29s
# 2296        GEMMER TELLO SALAS   00h:33m44s
