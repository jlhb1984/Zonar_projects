# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
speed_report=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\speedReport_2026-04-13_1776108306095_1xopqhaee.csv',sep=',')
speed_report.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5062 entries, 0 to 5061
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unit               5062 non-null   str
#  1   Driver             0 non-null      float64
#  2   Time/Date (UTC-5)  5062 non-null   str
#  3   Address            5062 non-null   str
#  4   Speed (kph)        5062 non-null   int64
#  5   Posted Speed       5062 non-null   str
#  6   Signal             5062 non-null   int64
# dtypes: float64(1), int64(2), str(4)
# memory usage: 277.0 KB

# %%
speed_report['Unit'].value_counts().to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\speedReport_units.csv')
speed_report_units_imported=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\arepas\speedReport_units.csv',sep=',')

# %%
cont=0
units=[]
unit_aux=[]
cont_aux=[]

for i in range(0,speed_report_units_imported.shape[0]):
    units.append(speed_report_units_imported.iloc[i,0])

print("Units: ",units," ","Quantity: ",len(units))

for i in range(0,len(units)):
    for j in range(0,speed_report.shape[0]):
        if units[i]==speed_report.iloc[j,0]:
            unit_aux.append(int(speed_report.iloc[j,4]))
            cont=cont+1
            cont_aux.append(cont)
    print(units[i])
    plt.plot(cont_aux,unit_aux)
    plt.show()
    unit_aux=[]
    cont_aux=[]    
#print(unit_aux)
# Out:
# Units:  ['GDX550', 'PXK574', 'PXK571', 'JYN930', 'LGU446', 'JYW714', 'LTL615', 'NLW978', 'GDX086', 'LGU417', 'WPX590', 'LKK378', 'ESP290', 'GTX996', 'WMR448', 'NLX863', 'GDY165', 'NLX865', 'JYM943', 'WLX372', 'GDY884', 'GDZ176', 'ESR610', 'NLX864']   Quantity:  24
# GDX550
# PXK574
# PXK571
# JYN930
# LGU446
# JYW714
# LTL615
# NLW978
# GDX086
# LGU417
# WPX590
# LKK378
# ESP290
# GTX996
# WMR448
# NLX863
# GDY165
# NLX865
# JYM943
# WLX372
# GDY884
# GDZ176
# ESR610
# NLX864
