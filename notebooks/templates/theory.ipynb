# %%
import pandas as pd

# %%
#~
increment=lambda x:x+1
print(increment(1))
# Out:
# 2

# %%
ars=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\brahman\Activity Report Summarized_2703_2903.csv',sep=',')
ars['MilesDriven_in_Miles']=0.0
cad_str_to_float=[]
for i in range(0,ars.shape[0]):
    aux=ars.iloc[i,4].replace('.','')
    ars.iloc[i,4]=aux
    aux=ars.iloc[i,4].replace(',','.')
    cad_str_to_float.append(aux)

# %%
#Working on get a column form an excel file and turn it into a csv file
xls_file=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\Export_queclink.xlsx')
xls_file_message=xls_file['Message']
xls_file_message.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\Export_queclink.csv')
csv_file_message=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\Export_queclink.csv',sep=',')
csv_file_message.head(1)
# Out:
#    Unnamed: 0                                            Message
# 0           0  +RESP:GTFRI,500700,868574042784996,,,10,1,1,0....
