# %%
import pandas as pd
import numpy as np

# %%
ubd=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\CRMUnitsDealersReports_15724_20260818230020.xlsx')
ubd.info()

#If you want to filter the data based on a specific date, you can use the following line of code. This will create a new DataFrame called 'ubd_reported' that only includes rows where the 'Last Contact On' date is on or after January 1, 2026.
#ubd_reported=ubd[ubd['Last Contact On']>=pd.to_datetime('2026-01-01')]#
#ubd_reported.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30382 entries, 0 to 30381
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   30382 non-null  str
#  1   Company                  30382 non-null  str
#  2   VIP                      30382 non-null  str
#  3   FEIN                     27969 non-null  str
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      8120 non-null   str
#  6   Peripherals              30382 non-null  str
#  7   Service                  24999 non-null  str
#  8   Owner                    30382 non-null  str
#  9   Unit ID                  30382 non-null  str
#  10  Unit                     30382 non-null  str
#  11  Unit Type                30382 non-null  str
#  12  Carrier                  27738 non-null  str
#  13  Unnamed: 13              0 non-null      float64
#  14  Monthly Fee              30382 non-null  float64
#  15  Billing Group            3835 non-null   str
#  16  Billing Period           30264 non-null  str
#  17  Last Service Paid Until  30382 non-null  datetime64[us]
#  18  Service Paid Until       30382 non-null  datetime64[us]
#  19  Serial Number            28129 non-null  str
#  20  Phone Number             23364 non-null  str
#  21  IMEI                     28117 non-null  str
#  22  Bill To                  859 non-null    str
#  23  Status                   30382 non-null  str
#  24  Event                    26940 non-null  str
#  25  Assigned To Company On   30382 non-null  datetime64[us]
#  26  Last Event Date          30382 non-null  datetime64[us]
#  27  Last Contact On          30382 non-null  datetime64[us]
#  28  Last Event Address       27590 non-null  str
# dtypes: datetime64[us](5), float64(3), str(21)
# memory usage: 6.7 MB
# <class 'pandas.DataFrame'>
# Index: 15244 entries, 0 to 30381
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Dealer                   15244 non-null  str
#  1   Company                  15244 non-null  str
#  2   VIP                      15244 non-null  str
#  3   FEIN                     14910 non-null  str
#  4   Unnamed: 4               0 non-null      float64
#  5   DNI                      6805 non-null   str
#  6   Peripherals              15244 non-null  str
#  7   Service                  14791 non-null  str
#  8   Owner                    15244 non-null  str
#  9   Unit ID                  15244 non-null  str
#  10  Unit                     15244 non-null  str
#  11  Unit Type                15244 non-null  str
#  12  Carrier                  15094 non-null  str
#  13  Unnamed: 13              0 non-null      float64
#  14  Monthly Fee              15244 non-null  float64
#  15  Billing Group            643 non-null    str
#  16  Billing Period           15176 non-null  str
#  17  Last Service Paid Until  15244 non-null  datetime64[us]
#  18  Service Paid Until       15244 non-null  datetime64[us]
#  19  Serial Number            15243 non-null  str
#  20  Phone Number             15084 non-null  str
#  21  IMEI                     15243 non-null  str
#  22  Bill To                  724 non-null    str
#  23  Status                   15244 non-null  str
#  24  Event                    15020 non-null  str
#  25  Assigned To Company On   15244 non-null  datetime64[us]
#  26  Last Event Date          15244 non-null  datetime64[us]
#  27  Last Contact On          15244 non-null  datetime64[us]
#  28  Last Event Address       15244 non-null  str
# dtypes: datetime64[us](5), float64(3), str(21)
# memory usage: 3.5 MB

# %%
ubd['Dealer'].value_counts()
# Out:
# Dealer
# TSO Mobile - Colombia             11896
# TSO Mobile Peru                    8898
# UTS Sistemas Kalo MX               5544
# TSO Colombia - IBO IDCOM           2417
# TSO Colombia - IBO SEGTEC          1544
# Jorge Garcia                         81
# TSO Peru -   FG SATELITAL EIRL        1
# MYM GLOBAL SEGURITY SAS               1
# Name: count, dtype: int64

# %%
tso_mobile_colombia=ubd[ubd['Dealer'].str.contains('TSO Mobile - Colombia')]
tso_mobile_peru=ubd[ubd['Dealer'].str.contains('TSO Mobile Peru')]
uts_sistemas_kalo=ubd[ubd['Dealer'].str.contains('UTS Sistemas Kalo MX')]
tso_mobile_colombia_ibo_idcom=ubd[ubd['Dealer'].str.contains('TSO Colombia - IBO IDCOM')]
tso_mobile_colombia_ibo_segtec=ubd[ubd['Dealer'].str.contains('TSO Colombia - IBO SEGTEC')]
jorge_garcia=ubd[ubd['Dealer'].str.contains('Jorge Garcia')]
tso_peru_fg_satelital_eirl=ubd[ubd['Dealer'].str.contains('TSO Peru -   FG SATELITAL EIRL')]
mym_global_security=ubd[ubd['Dealer'].str.contains('MYM GLOBAL SEGURITY SAS')]

# %%
col=pd.concat([tso_mobile_colombia,tso_mobile_colombia_ibo_idcom,tso_mobile_colombia_ibo_segtec])
per=pd.concat([tso_mobile_peru,tso_peru_fg_satelital_eirl])
mex=uts_sistemas_kalo

# %%
cop_mrr=col['Monthly Fee'].sum()
conversion=float(input("Enter dollar rate: "))
cop_usd=cop_mrr/conversion
mex_mrr=mex['Monthly Fee'].sum()
per_mrr=per['Monthly Fee'].sum()
print(f"Total MRR for Colombia: {cop_mrr} COP, {cop_usd} USD")
print(f"Total MRR for Mexico:  {mex_mrr} USD")
print(f"Total MRR for Peru: {per_mrr} USD") 
print(f"Total MRR for all countries: {cop_usd+mex_mrr+per_mrr} USD")
# Out:
# Total MRR for Colombia: 13180986986.93 COP, 4119058.4334156252 USD
# Total MRR for Mexico:  133322.67 USD
# Total MRR for Peru: 164060.49 USD
# Total MRR for all countries: 4416441.593415625 USD
