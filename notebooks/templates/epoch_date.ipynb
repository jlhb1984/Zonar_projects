# %%
import pandas as pd
import numpy as np
import datetime

# %%
aux=input("Type date: ")
aux=float(aux)/1000
print(datetime.datetime.utcfromtimestamp(aux))
# Out:
# 2026-08-22 17:39:49.713000
# C:\Users\Jose.Hurtado\AppData\Local\Temp\ipykernel_14504\2270880292.py:3: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   print(datetime.datetime.utcfromtimestamp(aux))

# %%
aux=input("Type date: ")
aux=float(aux)/1000
print(datetime.datetime.fromtimestamp(aux))
# Out:
# 2026-08-22 06:56:01.258000
