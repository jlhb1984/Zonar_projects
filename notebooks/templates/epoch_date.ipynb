# %%
import pandas as pd
import numpy as np
import datetime

# %%
epoch_time=int(input('Type the epoch time: '))  # example epoch in seconds
date=datetime.datetime.fromtimestamp(epoch_time)
print(date)
# Out:
# 1973-12-24 21:09:23
