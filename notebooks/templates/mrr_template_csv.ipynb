# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Units by dealer report has been showing mistakes, do not use this module until Units by dealer report in .csv format be repaired.

# %%
#ubd=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\CRMUnitsDealersReports_15724_20260818230020.xlsx')
#ubd.info()
ubd=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\CRMUnitsDealersReports_15724_20260819153549.csv',sep=',')
ubd.info()

#If you want to filter the data based on a specific date, you can use the following line of code. This will create a new DataFrame called 'ubd_reported' that only includes rows where the 'Last Contact On' date is on or after January 1, 2026.
#ubd_reported=ubd[ubd['Last Contact On']>=pd.to_datetime('2026-01-01')]#
#ubd_reported.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3144 entries, 0 to 3143
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Dealer                3144 non-null   str
#  1   Company1              3144 non-null   str
#  2   VIP                   3144 non-null   str
#  3   FEIN                  2898 non-null   str
#  4   DNI                   1154 non-null   str
#  5   Peripherals           3144 non-null   str
#  6   ServiceName           3031 non-null   str
#  7   IsRenting             3144 non-null   str
#  8   UnitID1               3144 non-null   str
#  9   ShortName             3144 non-null   str
#  10  UnitType              3144 non-null   str
#  11  Carrier               1569 non-null   str
#  12  MonthlyFee            3144 non-null   float64
#  13  BillingGroup          91 non-null     str
#  14  BillingPeriod         3144 non-null   str
#  15  LastServicePaidUntil  3144 non-null   str
#  16  ServicePaidUntil      3144 non-null   str
#  17  SerialNumber          1582 non-null   str
#  18  PhoneNumber           1571 non-null   str
#  19  IMEI                  1581 non-null   str
#  20  BillTo                24 non-null     str
#  21  Suspended             3144 non-null   str
#  22  EventName             1086 non-null   str
#  23  AssignedToCompanyOn   3144 non-null   str
#  24  LastEventDate         3144 non-null   str
#  25  LastContactOn         3144 non-null   str
#  26  LastEventAddress      1116 non-null   str
# dtypes: float64(1), str(26)
# memory usage: 663.3 KB

# %%
ubd['Dealer'].value_counts()
# Out:
# Dealer
# TSO Mobile - Colombia        1590
# TSO Mobile Peru              1091
# UTS Sistemas Kalo MX          277
# TSO Colombia - IBO IDCOM      137
# TSO Colombia - IBO SEGTEC      42
# Jorge Garcia                    7
# Name: count, dtype: int64

# %%
tso_mobile_colombia=ubd[ubd['Dealer'].str.contains('TSO Mobile - Colombia')]
tso_mobile_peru=ubd[ubd['Dealer'].str.contains('TSO Mobile Peru')]
uts_sistemas_kalo=ubd[ubd['Dealer'].str.contains('UTS Sistemas Kalo MX')]
tso_mobile_colombia_ibo_idcom=ubd[ubd['Dealer'].str.contains('TSO Colombia - IBO IDCOM')]
tso_mobile_colombia_ibo_segtec=ubd[ubd['Dealer'].str.contains('TSO Colombia - IBO SEGTEC')]
jorge_garcia=ubd[ubd['Dealer'].str.contains('Jorge Garcia')]
tso_peru_fg_satelital_eirl=ubd[ubd['Dealer'].str.contains('TSO Peru -   FG SATELITAL EIRL')]
mym_global_security=ubd[ubd['Dealer'].str.contains('MYM GLOBAL SEGURITY SAS')]

# %%
col=pd.concat([tso_mobile_colombia,tso_mobile_colombia_ibo_idcom,tso_mobile_colombia_ibo_segtec])
per=pd.concat([tso_mobile_peru,tso_peru_fg_satelital_eirl])
mex=uts_sistemas_kalo

# %%
cop_mrr=col['MonthlyFee'].sum()
conversion=float(input("Enter TRM: "))
cop_usd=cop_mrr/conversion
mex_mrr=mex['MonthlyFee'].sum()
per_mrr=per['MonthlyFee'].sum()
print(f"Total MRR for Colombia: {cop_mrr} COP, {cop_usd} USD")
print(f"Total MRR for Mexico:  {mex_mrr} USD")
print(f"Total MRR for Peru: {per_mrr} USD") 
print(f"Total MRR for LATAM: {cop_usd+mex_mrr+per_mrr} USD")
# Out:
# Total MRR for Colombia: 762169494.0400001 COP, 246258.31794507272 USD
# Total MRR for Mexico:  1049.6999999999998 USD
# Total MRR for Peru: 5880.530000000001 USD
# Total MRR for LATAM: 253188.54794507273 USD
