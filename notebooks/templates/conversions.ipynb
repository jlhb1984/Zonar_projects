# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# API

# %%
import csv
import random
from urllib import request
import json
import datetime
import requests

def get_api_information():
    
    try:
        url=f'https://api.tsomobile.com/rest/Authentication/ValidateUser'
        payload={
        "login": "jhurtado",
        "password": "Azul1984"
        }
        response=requests.post(url,json=payload)
        
    except Exception as e:
        print("Trouble while try to connect!")   

    return response.json();

if __name__== '__main__':
    cad=get_api_information()
    print(cad)
# Out:
# {'Code': 1, 'Message': '', 'Data': {'companyId': 15724, 'userId': 45645, 'token': '76356310-40B0-4336-B9A7-31B45561F222', 'lang': 'en', 'FullName': 'José Hurtado', 'mileskms': 'M', 'gasunit': 'L', 'temperatureunit': 'F', 'tokenExpiresOn': '0001-01-01T00:00:00'}}

# %% [markdown]
# Dollar

# %% [markdown]
# Speed

# %%
v=float(input("Type the value in km/h: "))
w=(v*100000)/3600
print(v,'km/h',' -> ',w,'cm/s')
# Out:
# 9.0 km/h  ->  250.0 cm/s

# %%
w=float(input("Type the value in cm/s: "))
v=(w*3600)/100000
x=v*0.62137119
print(w,'cm/s',' -> ',v,'km/h',' -> ',x,'mph')
# Out:
# 9.0 cm/s  ->  0.324 km/h  ->  0.20132426556 mph

# %%
y=float(input("Type the value in mph: "))
z=y*1.609344
print(y,'mph',' -> ',z,'km/h')
# Out:
# 9.0 mph  ->  14.484096000000001 km/h

# %% [markdown]
# El sistema reportará alertas a 80Km/h si se establece a 82Km/h porque la variable es entera y aproxima al entero menor.

# %% [markdown]
# Volume

# %%
t=float(input("Type the value in gallons: "))
u=t*3.785412
print(t,'galons',' -> ',u,'liters')
# Out:
# 9.0 galons  ->  34.068708 liters

# %%
u=float(input("Type the value in liters: "))
t=u/3.785412
print(u,'liters',' -> ',t,'galons')
# Out:
# 9.0 liters  ->  2.377548335557662 galons

# %% [markdown]
# Temperature

# %%
c=float(input("Type the Celsius value: "))
f=(9/5)*c+32
print(c,'Celsius',' -> ',f,'Farenheit')
# Out:
# 9.0 Celsius  ->  48.2 Farenheit

# %%
f=float(input("Type the Farenheit value: "))
c=(f-32)*(5/9)
print(f,'Farenheit',' -> ',c,'celsius')
# Out:
# 9.0 Farenheit  ->  -12.777777777777779 celsius

# %% [markdown]
# Fuel

# %%
n=float(input("Type the N number of the OBD: "))
l=n*0.17
print(n,'n value',' -> ',l,'l')
# Out:
# 9.0 n value  ->  1.53 l

# %% [markdown]
# Date

# %%
aux=input("Type date: ")
aux=float(aux)# It is possible use float(aux)/1000
print(datetime.datetime.fromtimestamp(aux))
# Out:
# 2026-07-31 19:00:43
