# %%
import pandas as pd
import numpy as np
import math
import requests
import datetime

# %% [markdown]
# API

# %%
import csv
import random
from urllib import request
import json
import datetime
import requests

def get_api_information():
    
    try:
        url=f'https://api.tsomobile.com/rest/Authentication/ValidateUser'
        payload={
        "login": "jhurtado",
        "password": "Azul1984"
        }
        response=requests.post(url,json=payload)
        
    except Exception as e:
        print("Trouble while try to connect!")   

    return response.json();

if __name__== '__main__':
    cad=get_api_information()
    print(cad)
# Out:
# {'Code': 1000, 'Message': 'The user credentials are not valid', 'Data': None}

# %% [markdown]
# Dollar

# %%
cop=float(input("Enter the amount in COP: "))
url = "https://www.datos.gov.co/resource/ceyp-9c7c.json?$limit=1&$order=vigenciadesde DESC"
response = requests.get(url)

data = response.json()
trm = float(data[0]["valor"])
cop_dollars = cop/trm
print(f"Current TRM: {trm} COP/USD, {cop}$ -> {cop_dollars}USD")
# Out:
# Current TRM: 3208.66 COP/USD, 200.0$ -> 0.06233131587640947USD

# %% [markdown]
# Speed

# %%
v=float(input("Type the value in km/h: "))
w=(v*100000)/3600
print(v,'km/h',' -> ',w,'cm/s')
# Out:
# 82.0 km/h  ->  2277.777777777778 cm/s

# %%
w=float(input("Type the value in cm/s: "))
v=(w*3600)/100000
x=v*0.62137119
print(w,'cm/s',' -> ',v,'km/h',' -> ',x,'mph')
# Out:
# 2277.0 cm/s  ->  81.972 km/h  ->  50.935039186679994 mph

# %%
y=float(input("Type the value in mph: "))
z=y*1.609344
print(y,'mph',' -> ',z,'km/h')
# Out:
# 45.0 mph  ->  72.42048 km/h

# %% [markdown]
# El sistema reportará alertas a 80Km/h si se establece a 82Km/h porque la variable es entera y aproxima al entero menor.

# %% [markdown]
# Volume

# %%
t=float(input("Type the value in gallons: "))
u=t*3.785412
print(t,'galons',' -> ',u,'liters')
# Out:
# 1000.0 galons  ->  3785.412 liters

# %%
u=float(input("Type the value in liters: "))
t=u/3.785412
print(u,'liters',' -> ',t,'galons')
# Out:
# 1000.0 liters  ->  264.1720372841847 galons

# %% [markdown]
# Temperature

# %%
c=float(input("Type the Celsius value: "))
f=(9/5)*c+32
print(c,'Celsius',' -> ',f,'Farenheit')
# Out:
# 32.0 Celsius  ->  89.6 Farenheit

# %%
f=float(input("Type the Farenheit value: "))
c=(f-32)*(5/9)
print(f,'Farenheit',' -> ',c,'celsius')
# Out:
# 233.0 Farenheit  ->  111.66666666666667 celsius

# %% [markdown]
# Fuel

# %%
n=float(input("Type the N number of the OBD: "))
l=n*0.17
print(n,'n value',' -> ',l,'l')
# Out:
# 102.0 n value  ->  17.34 l

# %% [markdown]
# Date

# %%
aux=input("Type date: ")
aux=float(aux)# It is possible use float(aux)/1000
print(aux,"->",datetime.datetime.fromtimestamp(aux))
# Out:
# 2026.0 -> 1969-12-31 19:33:46
