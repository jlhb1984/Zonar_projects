# %%
import pandas as pd 
import numpy as np
import datetime         #Shows in my time zone COL.

# %%
vf=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\bus_service\8B5141Z2_columns.csv',sep=',')
vf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Columns: 284 entries, Message to Unnamed: 283
# dtypes: float64(17), str(267)
# memory usage: 825.5 KB

# %%
vf['Message'].value_counts()
# Out:
# Message
# {"notificationType":"TripInfo"             199
# {"notificationType":"AutoSnapshot"          58
# {"notificationType":"CameraRunningInfo"     56
# {"notificationType":"IgnitionStatus"        52
# {"notificationType":"CameraEvent"            5
# {"notificationType":"ParkingHeartbeat"       2
# Name: count, dtype: int64

# %%
vf_camera_events=vf[vf['Message'].str.contains('CameraEvent')]
vf_camera_events['Unnamed: 4'].value_counts()
# Out:
# Unnamed: 4
# event:"NO_SEATBELT"    3
# event:"USING_PHONE"    2
# Name: count, dtype: int64

# %%
vf_camera_events['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# eventCategory:"DMS"    5
# Name: count, dtype: int64

# %%
vf_autosnapshot=vf[vf['Unnamed: 5'].str.contains('http')]
vf_autosnapshot['Unnamed: 5']
# Out:
# 1      url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 14     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 16     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 28     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 33     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 36     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 40     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 45     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 60     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 62     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 67     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 69     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 84     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 87     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 95     url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 100    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 111    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 114    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 118    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 119    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 123    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 125    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 128    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 130    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 133    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 135    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 138    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 140    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 146    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 149    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 164    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 166    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 174    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 179    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 184    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 201    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 213    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 219    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 221    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 233    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 256    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 259    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 260    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 266    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 267    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 280    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 285    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 287    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 288    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 301    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 314    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 326    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 330    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 334    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 337    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 339    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 351    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# 370    url:"https://cdn.vidfleet-api.gpstrackit.com/c...
# Name: Unnamed: 5, dtype: str

# %%
vf_date_time=vf[vf['Unnamed: 3'].str.contains('time')]
vf_date_time['Unnamed: 3']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
print(vf_date_time.iloc[0,103])

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,3][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))
    vf_date_time.iloc[i,103]=str(epoch_date[i])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i])
# Out:
# nan
# 2026-06-25 21:18:06  ->  1782440286.0
# 2026-06-25 21:25:59  ->  1782440759.0
# 2026-06-25 21:26:55  ->  1782440815.0
# 2026-06-25 21:36:55  ->  1782441415.0
# 2026-06-25 21:38:35  ->  1782441515.0
# 2026-06-25 21:39:50  ->  1782441590.0
# 2026-06-25 22:02:56  ->  1782442976.0
# 2026-06-25 22:05:22  ->  1782443122.0
# 2026-06-25 22:13:16  ->  1782443596.0
# 2026-06-25 22:14:33  ->  1782443673.0
# 2026-06-25 22:17:59  ->  1782443879.0
# 2026-06-25 22:40:12  ->  1782445212.0
# 2026-06-25 22:48:18  ->  1782445698.0
# 2026-06-25 22:48:50  ->  1782445730.0
# 2026-06-25 22:59:16  ->  1782446356.0
# 2026-06-25 23:01:15  ->  1782446475.0
# 2026-06-25 23:16:48  ->  1782447408.0
# 2026-06-25 23:17:17  ->  1782447437.0
# 2026-06-25 23:17:29  ->  1782447449.0
# 2026-06-25 23:17:38  ->  1782447458.0
# 2026-06-25 23:18:08  ->  1782447488.0
# 2026-06-25 23:18:13  ->  1782447493.0
# 2026-06-25 23:18:27  ->  1782447507.0
# 2026-06-25 23:18:36  ->  1782447516.0
# 2026-06-25 23:18:57  ->  1782447537.0
# 2026-06-25 23:19:07  ->  1782447547.0
# 2026-06-25 23:19:25  ->  1782447565.0
# 2026-06-25 23:19:34  ->  1782447574.0
# 2026-06-25 23:26:57  ->  1782448017.0
# 2026-06-25 23:28:20  ->  1782448100.0
# 2026-06-25 23:40:45  ->  1782448845.0
# 2026-06-26 03:04:21  ->  1782461061.0
# 2026-06-26 03:08:50  ->  1782461330.0
# 2026-06-26 08:00:56  ->  1782478856.0
# 2026-06-26 08:33:06  ->  1782480786.0
# 2026-06-26 08:43:06  ->  1782481386.0
# 2026-06-26 08:53:06  ->  1782481986.0
# 2026-06-26 08:54:58  ->  1782482098.0
# 2026-06-26 09:35:40  ->  1782484540.0
# 2026-06-26 09:45:39  ->  1782485139.0
# 2026-06-26 10:04:37  ->  1782486277.0
# 2026-06-26 10:13:09  ->  1782486789.0
# 2026-06-26 10:36:50  ->  1782488210.0
# 2026-06-26 10:38:25  ->  1782488305.0
# 2026-06-26 10:38:29  ->  1782488309.0
# 2026-06-26 10:48:29  ->  1782488909.0
# 2026-06-26 10:49:56  ->  1782488996.0
# 2026-06-26 10:58:55  ->  1782489535.0
# 2026-06-26 11:04:42  ->  1782489882.0
# 2026-06-26 11:14:42  ->  1782490482.0
# 2026-06-26 11:24:42  ->  1782491082.0
# 2026-06-26 11:34:42  ->  1782491682.0
# 2026-06-26 11:35:14  ->  1782491714.0
# 2026-06-26 11:38:45  ->  1782491925.0
# 2026-06-26 11:39:12  ->  1782491952.0
# 2026-06-26 11:50:53  ->  1782492653.0
# 2026-06-26 12:00:53  ->  1782493253.0
# 2026-06-26 12:12:55  ->  1782493975.0

# %%
vf_autosnapshot=vf[vf['Unnamed: 5'].str.contains('http')]
vf_autosnapshot_date=[]
aux_date_time_as=[]
epoch_date_as=[]
vf_autosnapshot['Date']='NaN'

for i in range(0,vf_autosnapshot.shape[0]):
    aux_date_time_as.append(float(vf_date_time.iloc[i,3][5:18])/1000)
    epoch_date_as.append(datetime.datetime.fromtimestamp(aux_date_time[i]))
    vf_autosnapshot.iloc[i,104]=str(epoch_date_as[i])

vf_autosnapshot[['Unnamed: 5','Unnamed: 3','Date']].to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\bus_service\report.csv')       #Edit.

# %% [markdown]
# NO_SEATBELT

# %%
vf_no_seatbelt=vf[vf['Unnamed: 4'].str.contains('NO_SEATBELT')]
#vf_no_seatbelt

vf_date_time=vf_no_seatbelt[vf_no_seatbelt['Unnamed: 9'].str.contains('time')]
#vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,9][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))    
    vf_date_time.iloc[i,103]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,19])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])
# Out:
# 2026-06-25 22:05:04  ->  1782443104.0  ->  speed:8.487715
# 2026-06-25 22:45:45  ->  1782445545.0  ->  speed:17.66808
# 2026-06-26 09:57:14  ->  1782485834.0  ->  speed:19.920113

# %% [markdown]
# USING_PHONE

# %%
vf_no_seatbelt=vf[vf['Unnamed: 4'].str.contains('USING_PHONE')]
#vf_no_seatbelt

vf_date_time=vf_no_seatbelt[vf_no_seatbelt['Unnamed: 9'].str.contains('time')]
vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,9][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))
    vf_date_time.iloc[i,103]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,19])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])
# Out:
# 2026-06-26 09:45:55  ->  1782485155.0  ->  speed:21.948051
# 2026-06-26 12:09:09  ->  1782493749.0  ->  speed:4.013284

# %% [markdown]
# DROWSINESS

# %%
vf_no_seatbelt=vf[vf['Unnamed: 4'].str.contains('DROWSINESS')]
#vf_no_seatbelt

vf_date_time=vf_no_seatbelt[vf_no_seatbelt['Unnamed: 9'].str.contains('time')]
vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,9][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))
    vf_date_time.iloc[i,103]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,19])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ',speed[i])

# %% [markdown]
# YAWN

# %%
vf_no_seatbelt=vf[vf['Unnamed: 4'].str.contains('YAWN')]
#vf_no_seatbelt

vf_date_time=vf_no_seatbelt[vf_no_seatbelt['Unnamed: 9'].str.contains('time')]
vf_date_time['Unnamed: 9']
aux_date_time=[]
epoch_date=[]
vf_date_time['Date']='NaN'
speed=[]

for i in range(0,vf_date_time.shape[0]):
    aux_date_time.append(float(vf_date_time.iloc[i,9][5:18])/1000)
    epoch_date.append(datetime.datetime.fromtimestamp(aux_date_time[i]))
    vf_date_time.iloc[i,103]=str(epoch_date[i])
    speed.append(vf_date_time.iloc[i,19])

for i in range(0,len(epoch_date)):
    print(epoch_date[i],' -> ',aux_date_time[i],' -> ','speed[i]')
