# %%
import pandas as pd

# %%
x=input('Type the message: ')
print(x)
decoder={'Prefix':x[0:2],'Sender network address':x[2:4],'Command code':x[4:6],'Temperature':x[6:8],'User value of fuel level':x[8:12],'Technological value of fuel level':x[12:16],'CRC':x[16:18]}
msb=x[10:12]
lsb=x[8:10]
measure=msb+lsb
dec_measure=int(measure,16)
decoder
# Out:
#  3E0107165E04E945F0
# {'Prefix': ' 3',
#  'Sender network address': 'E0',
#  'Command code': '10',
#  'Temperature': '71',
#  'User value of fuel level': '65E0',
#  'Technological value of fuel level': '4E94',
#  'CRC': '5F'}

# %%
print(dec_measure)
# Out:
# 886
