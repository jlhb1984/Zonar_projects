# %%
import pandas as pd

x=input('Type the message: ')
print(x)
decoder={'Prefix':x[0:2],'Sender network address':x[2:4],'Command code':x[4:6],'Temperature':x[6:8],'User value of fuel level':x[8:12],'Technological value of fuel level':x[12:16],'CRC':x[16:18]}
msb=x[10:12]
lsb=x[8:10]
measure=msb+lsb
dec_measure=int(measure,16)
print("N code: ",dec_measure)
decoder
# Out:
# 3E01421A0210A9BE03015518
# N code:  4098
# {'Prefix': '3E',
#  'Sender network address': '01',
#  'Command code': '42',
#  'Temperature': '1A',
#  'User value of fuel level': '0210',
#  'Technological value of fuel level': 'A9BE',
#  'CRC': '03'}
