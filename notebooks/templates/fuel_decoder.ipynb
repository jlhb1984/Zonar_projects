# %%
import pandas as pd

# %%
x=input('Digita la trama: ')
print(x)
decoder={'Prefix':x[0:2],'Sender network address':x[2:4],'Command code':x[4:6],'Temperature':x[6:8],'User value of fuel level':x[8:12],'Technological value of fuel level':x[12:16],'CRC':x[16:18]}
msb=x[10:12]
lsb=x[8:10]
measure=msb+lsb
dec_measure=int(measure,16)
decoder
# Out:
# 3E01072255085B851D
# {'Prefix': '3E',
#  'Sender network address': '01',
#  'Command code': '07',
#  'Temperature': '22',
#  'User value of fuel level': '5508',
#  'Technological value of fuel level': '5B85',
#  'CRC': '1D'}

# %%
print(dec_measure)
# Out:
# 2176
