# %%
import pandas as pd
import numpy as np

# %%
palomino_devices=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\palomino\devices.csv',sep=',')
palomino_devices['Warning']='NaN'
palomino_devices.info()
palomino_devices[['Label','IMEI','Serial','Paired Unit','Last Event','Last Message Time']]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     15 non-null     int64
#  1   Label                  15 non-null     str
#  2   Status                 15 non-null     str
#  3   Reference              15 non-null     int64
#  4   Manufacturer           15 non-null     str
#  5   Model                  15 non-null     str
#  6   Group                  0 non-null      float64
#  7   Serial                 15 non-null     str
#  8   IMEI                   15 non-null     int64
#  9   Paired Unit            0 non-null      float64
#  10  GPS Unit ESN           0 non-null      float64
#  11  Camera ESN             0 non-null      float64
#  12  SIM #                  15 non-null     str
#  13  SIM Phone              0 non-null      float64
#  14  Network                0 non-null      float64
# ...

# %%
option=int(input('Look for: 1, exit: 0'))
while option!=0:
    if option==1:
        value_to_look=input('Type the number plate: ')
        for i in range(0,palomino_devices.shape[0]):
            aux=palomino_devices.iloc[i,1]
            if aux==value_to_look:
                #print("Founded")
                palomino_devices.iloc[i,37]=input('Type the warning!')
    option=int(input('Look for: 1, exit: 0'))
print(palomino_devices['Label','IMEI','Serial','Paired Unit','Last Event','Last Message Time','Warning'])
# Out:
# Founded
# Founded
# 0     It never reported.
# 1      It never reported
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# Name: Warning, dtype: str
