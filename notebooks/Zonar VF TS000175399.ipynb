# %%
import pandas as pd
import numpy as np

# %%
df_book_table01=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\Waylens_r_and_ap.xlsx')
df_book_table02=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\VF 1 y 2.xlsx')

# %%
df_book_table01.info()
df_book_table02.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Serial   75 non-null     str
#  1   Status   75 non-null     str
#  2   Process  75 non-null     int64
# dtypes: int64(1), str(2)
# memory usage: 1.9 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Serial          154 non-null    str
#  1   Reportadas por  154 non-null    str
#  2   Caso            154 non-null    str
#  3   Característica  154 non-null    str
# dtypes: str(4)
# memory usage: 4.9 KB

# %%
num_filas_table01=int(df_book_table01.shape[0])
num_filas_table02=int(df_book_table02.shape[0])       
cont=0
df_aux=pd.DataFrame()        
list_field00=[]
list_field01=[]
list_field02=[]
list_field03=[]
list_field04=[]
list_field05=[]
list_field06=[]               
print("\nInformación de las tablas: ")
print("\nTabla 1:")
print(df_book_table01.info())
print("\nTabla 2:")
print(df_book_table02.info())
attribute_name_table01='Serial'#Digitar el índice de la tabla 1.#input("\nDigita el atributo a comparar de la tabla 1: ")
attribute_name_table02='Serial'#Digitar el índice de la tabla 2.#input("Digita el atribito a comparar de la tabla 2: ")
position_table01=int(df_book_table01.columns.get_loc(attribute_name_table01))
position_table02=int(df_book_table02.columns.get_loc(attribute_name_table02))
print("\nAtributo de la tabla1: ",position_table01)
print("Atributo de la tabla2: ",position_table02,"\n")
print("Trabajando...")                          
for i in range(0,num_filas_table01):
    for j in range(0,num_filas_table02):
        #if str(df_book_table01.iloc[i,5])==str(df_book_table02.iloc[j,3]): 
        if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):                                                                             
            list_field00.append(df_book_table01.iloc[i,0])
            list_field01.append(df_book_table01.iloc[i,1])
            list_field02.append(df_book_table01.iloc[i,2])
            list_field03.append(df_book_table02.iloc[j,1])
            list_field04.append(df_book_table02.iloc[j,2])
            list_field05.append(df_book_table02.iloc[j,3])
            print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
            print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
            cont=cont+1
df_aux['Serial']=list_field00
df_aux['Status']=list_field01
df_aux['Process']=list_field02
df_aux['Reported_by']=list_field03
df_aux['Case number']=list_field04
df_aux['Característica']=list_field05

#df_aux['Last Contact On']=list_field04
print("Cont= ",cont)
print(df_aux.info())
option_exp=input("\n¿Desea generar un reporte de coincidencias en formato csv S/N?\n")
if option_exp=="S":
    df_aux.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\Waylens_coincidences.csv')                  #Edit
cont=0
option_exp=input("¿Desea generar un reporte de diferencias en formato csv S/N?\n")        
df_book_table02['ACTION']="Keep"
if option_exp=="S":
    print("Trabajando...")
    for i in range(0,num_filas_table01):
        for j in range(0,num_filas_table02):
            if str(df_book_table01.iloc[i,position_table01])==str(df_book_table02.iloc[j,position_table02]):
                df_book_table02.iloc[j,3]=np.nan
                print("df_book_table01[i,position_table01]: ",df_book_table01.iloc[i,position_table01]," = ",end="")
                print("df_book_table02[j,position_table02]: ",df_book_table02.iloc[j,position_table02])               
    #print(df_book_table02)
    df_book_table02.dropna(axis=0,inplace=True)
    print(df_book_table02)
    df_book_table02.to_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\Waylens_differences.csv')          #Edit

#lista_combinada=[lista_simcard,lista_linea]
# Out:
# Información de las tablas:
#
# Tabla 1:
# <class 'pandas.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Serial   75 non-null     str
#  1   Status   75 non-null     str
#  2   Process  75 non-null     int64
# dtypes: int64(1), str(2)
# memory usage: 1.9 KB
# None
#
# Tabla 2:
# <class 'pandas.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Serial          154 non-null    str
#  1   Reportadas por  154 non-null    str
#  2   Caso            154 non-null    str
#  3   Característica  154 non-null    str
# dtypes: str(4)
# memory usage: 4.9 KB
# None
#
# Atributo de la tabla1:  0
# Atributo de la tabla2:  0
#
# Trabajando...
# df_book_table01[i,position_table01]:  6B301AJS  = df_book_table02[j,position_table02]:  6B301AJS
# df_book_table01[i,position_table01]:  6B301KF2  = df_book_table02[j,position_table02]:  6B301KF2
# df_book_table01[i,position_table01]:  6B301A8A  = df_book_table02[j,position_table02]:  6B301A8A
# df_book_table01[i,position_table01]:  6B301AGW  = df_book_table02[j,position_table02]:  6B301AGW
# df_book_table01[i,position_table01]:  6B301A9Z  = df_book_table02[j,position_table02]:  6B301A9Z
# df_book_table01[i,position_table01]:  6B301AMB  = df_book_table02[j,position_table02]:  6B301AMB
# df_book_table01[i,position_table01]:  6B301AV9  = df_book_table02[j,position_table02]:  6B301AV9
# df_book_table01[i,position_table01]:  6B301AYN  = df_book_table02[j,position_table02]:  6B301AYN
# df_book_table01[i,position_table01]:  6B301AXM  = df_book_table02[j,position_table02]:  6B301AXM
# df_book_table01[i,position_table01]:  6B301A6R  = df_book_table02[j,position_table02]:  6B301A6R
# df_book_table01[i,position_table01]:  6B301BLZ  = df_book_table02[j,position_table02]:  6B301BLZ
# df_book_table01[i,position_table01]:  6B301ALL  = df_book_table02[j,position_table02]:  6B301ALL
# df_book_table01[i,position_table01]:  6B301A7W  = df_book_table02[j,position_table02]:  6B301A7W
# df_book_table01[i,position_table01]:  6B301AKJ  = df_book_table02[j,position_table02]:  6B301AKJ
# df_book_table01[i,position_table01]:  6B301BN9  = df_book_table02[j,position_table02]:  6B301BN9
# df_book_table01[i,position_table01]:  6B301AJT  = df_book_table02[j,position_table02]:  6B301AJT
# df_book_table01[i,position_table01]:  6B301AC1  = df_book_table02[j,position_table02]:  6B301AC1
# df_book_table01[i,position_table01]:  6B301AYB  = df_book_table02[j,position_table02]:  6B301AYB
# df_book_table01[i,position_table01]:  6B301ABE  = df_book_table02[j,position_table02]:  6B301ABE
# df_book_table01[i,position_table01]:  6B301AM5  = df_book_table02[j,position_table02]:  6B301AM5
# df_book_table01[i,position_table01]:  6B301B7A  = df_book_table02[j,position_table02]:  6B301B7A
# df_book_table01[i,position_table01]:  6B301BH7  = df_book_table02[j,position_table02]:  6B301BH7
# df_book_table01[i,position_table01]:  6B301AG3  = df_book_table02[j,position_table02]:  6B301AG3
# df_book_table01[i,position_table01]:  6B301AWP  = df_book_table02[j,position_table02]:  6B301AWP
# df_book_table01[i,position_table01]:  6B301AHQ  = df_book_table02[j,position_table02]:  6B301AHQ
# df_book_table01[i,position_table01]:  6B301AJV  = df_book_table02[j,position_table02]:  6B301AJV
# df_book_table01[i,position_table01]:  6B301AZW  = df_book_table02[j,position_table02]:  6B301AZW
# df_book_table01[i,position_table01]:  6B301AVA  = df_book_table02[j,position_table02]:  6B301AVA
# df_book_table01[i,position_table01]:  6B301ALM  = df_book_table02[j,position_table02]:  6B301ALM
# df_book_table01[i,position_table01]:  6B301GSN  = df_book_table02[j,position_table02]:  6B301GSN
# df_book_table01[i,position_table01]:  6B301GPA  = df_book_table02[j,position_table02]:  6B301GPA
# df_book_table01[i,position_table01]:  6B301GKZ  = df_book_table02[j,position_table02]:  6B301GKZ
# df_book_table01[i,position_table01]:  6B301GN9  = df_book_table02[j,position_table02]:  6B301GN9
# df_book_table01[i,position_table01]:  6B301GRV  = df_book_table02[j,position_table02]:  6B301GRV
# df_book_table01[i,position_table01]:  6B301GRD  = df_book_table02[j,position_table02]:  6B301GRD
# df_book_table01[i,position_table01]:  6B301GRU  = df_book_table02[j,position_table02]:  6B301GRU
# df_book_table01[i,position_table01]:  6B301GSH  = df_book_table02[j,position_table02]:  6B301GSH
# df_book_table01[i,position_table01]:  6B301GQY  = df_book_table02[j,position_table02]:  6B301GQY
# df_book_table01[i,position_table01]:  6B301KF0  = df_book_table02[j,position_table02]:  6B301KF0
# df_book_table01[i,position_table01]:  6B301AWV  = df_book_table02[j,position_table02]:  6B301AWV
# df_book_table01[i,position_table01]:  6B301AJF  = df_book_table02[j,position_table02]:  6B301AJF
# df_book_table01[i,position_table01]:  6B301ALE  = df_book_table02[j,position_table02]:  6B301ALE
# df_book_table01[i,position_table01]:  6B301ANS  = df_book_table02[j,position_table02]:  6B301ANS
# df_book_table01[i,position_table01]:  6B301ASB  = df_book_table02[j,position_table02]:  6B301ASB
# Cont=  44
# <class 'pandas.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Serial          44 non-null     str
#  1   Status          44 non-null     str
#  2   Process         44 non-null     int64
#  3   Reported_by     44 non-null     str
#  4   Case number     44 non-null     str
#  5   Característica  44 non-null     str
# dtypes: int64(1), str(5)
# memory usage: 2.2 KB
# None
# Trabajando...
# df_book_table01[i,position_table01]:  6B301AJS  = df_book_table02[j,position_table02]:  6B301AJS
# df_book_table01[i,position_table01]:  6B301KF2  = df_book_table02[j,position_table02]:  6B301KF2
# df_book_table01[i,position_table01]:  6B301A8A  = df_book_table02[j,position_table02]:  6B301A8A
# df_book_table01[i,position_table01]:  6B301AGW  = df_book_table02[j,position_table02]:  6B301AGW
# df_book_table01[i,position_table01]:  6B301A9Z  = df_book_table02[j,position_table02]:  6B301A9Z
# df_book_table01[i,position_table01]:  6B301AMB  = df_book_table02[j,position_table02]:  6B301AMB
# df_book_table01[i,position_table01]:  6B301AV9  = df_book_table02[j,position_table02]:  6B301AV9
# df_book_table01[i,position_table01]:  6B301AYN  = df_book_table02[j,position_table02]:  6B301AYN
# df_book_table01[i,position_table01]:  6B301AXM  = df_book_table02[j,position_table02]:  6B301AXM
# df_book_table01[i,position_table01]:  6B301A6R  = df_book_table02[j,position_table02]:  6B301A6R
# df_book_table01[i,position_table01]:  6B301BLZ  = df_book_table02[j,position_table02]:  6B301BLZ
# df_book_table01[i,position_table01]:  6B301ALL  = df_book_table02[j,position_table02]:  6B301ALL
# df_book_table01[i,position_table01]:  6B301A7W  = df_book_table02[j,position_table02]:  6B301A7W
# df_book_table01[i,position_table01]:  6B301AKJ  = df_book_table02[j,position_table02]:  6B301AKJ
# df_book_table01[i,position_table01]:  6B301BN9  = df_book_table02[j,position_table02]:  6B301BN9
# df_book_table01[i,position_table01]:  6B301AJT  = df_book_table02[j,position_table02]:  6B301AJT
# df_book_table01[i,position_table01]:  6B301AC1  = df_book_table02[j,position_table02]:  6B301AC1
# df_book_table01[i,position_table01]:  6B301AYB  = df_book_table02[j,position_table02]:  6B301AYB
# df_book_table01[i,position_table01]:  6B301ABE  = df_book_table02[j,position_table02]:  6B301ABE
# df_book_table01[i,position_table01]:  6B301AM5  = df_book_table02[j,position_table02]:  6B301AM5
# df_book_table01[i,position_table01]:  6B301B7A  = df_book_table02[j,position_table02]:  6B301B7A
# df_book_table01[i,position_table01]:  6B301BH7  = df_book_table02[j,position_table02]:  6B301BH7
# df_book_table01[i,position_table01]:  6B301AG3  = df_book_table02[j,position_table02]:  6B301AG3
# df_book_table01[i,position_table01]:  6B301AWP  = df_book_table02[j,position_table02]:  6B301AWP
# df_book_table01[i,position_table01]:  6B301AHQ  = df_book_table02[j,position_table02]:  6B301AHQ
# df_book_table01[i,position_table01]:  6B301AJV  = df_book_table02[j,position_table02]:  6B301AJV
# df_book_table01[i,position_table01]:  6B301AZW  = df_book_table02[j,position_table02]:  6B301AZW
# df_book_table01[i,position_table01]:  6B301AVA  = df_book_table02[j,position_table02]:  6B301AVA
# df_book_table01[i,position_table01]:  6B301ALM  = df_book_table02[j,position_table02]:  6B301ALM
# df_book_table01[i,position_table01]:  6B301GSN  = df_book_table02[j,position_table02]:  6B301GSN
# df_book_table01[i,position_table01]:  6B301GPA  = df_book_table02[j,position_table02]:  6B301GPA
# df_book_table01[i,position_table01]:  6B301GKZ  = df_book_table02[j,position_table02]:  6B301GKZ
# df_book_table01[i,position_table01]:  6B301GN9  = df_book_table02[j,position_table02]:  6B301GN9
# df_book_table01[i,position_table01]:  6B301GRV  = df_book_table02[j,position_table02]:  6B301GRV
# df_book_table01[i,position_table01]:  6B301GRD  = df_book_table02[j,position_table02]:  6B301GRD
# df_book_table01[i,position_table01]:  6B301GRU  = df_book_table02[j,position_table02]:  6B301GRU
# df_book_table01[i,position_table01]:  6B301GSH  = df_book_table02[j,position_table02]:  6B301GSH
# df_book_table01[i,position_table01]:  6B301GQY  = df_book_table02[j,position_table02]:  6B301GQY
# df_book_table01[i,position_table01]:  6B301KF0  = df_book_table02[j,position_table02]:  6B301KF0
# df_book_table01[i,position_table01]:  6B301AWV  = df_book_table02[j,position_table02]:  6B301AWV
# df_book_table01[i,position_table01]:  6B301AJF  = df_book_table02[j,position_table02]:  6B301AJF
# df_book_table01[i,position_table01]:  6B301ALE  = df_book_table02[j,position_table02]:  6B301ALE
# df_book_table01[i,position_table01]:  6B301ANS  = df_book_table02[j,position_table02]:  6B301ANS
# df_book_table01[i,position_table01]:  6B301ASB  = df_book_table02[j,position_table02]:  6B301ASB
#        Serial Reportadas por         Caso Característica ACTION
# 4    6B301GS4       Thaylers  TS000176903          Usada   Keep
# 6    6B301GQR       Thaylers  TS000176903          Usada   Keep
# 7    6B301AYR       Thaylers  TS000176903          Usada   Keep
# 18   6B301B7P       Thaylers  TS000176903          Usada   Keep
# 19   6B301GRS       Thaylers  TS000176903          Usada   Keep
# ..        ...            ...          ...            ...    ...
# 149  8B51424A         Daniel  TS000175399          Usada   Keep
# 150  8B51426K         Daniel  TS000175399          Usada   Keep
# 151  8B51422H         Daniel  TS000175399          Usada   Keep
# 152  8B5251WZ         Daniel  TS000175399          Usada   Keep
# 153  8B52523C         Daniel  TS000175399          Usada   Keep
#
# [110 rows x 5 columns]
