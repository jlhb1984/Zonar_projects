# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# FOL917 - 4764385770.
#
# * Abastecimiento de combustible, no concuerda con sensor del tanque de combustible, placa FOL917, abastecimiento 60 galones mas 61.55 galones, fecha 13-06-26
#
# * Abastecimiento de 55.491 galones de petróleo, placa F0L917, fecha 14-06-26, no concuerda con el sensor de combustible

# %% [markdown]
# Chart of values: This part of the notebook is for troubleshooting and graphical analysis.

# %%
#raw_fuel_data=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\zonar\Export.xlsx - Sheet1.csv',sep=',',encoding='latin1')
raw_fuel_data=pd.read_excel(r'C:\Users\Jose.Hurtado\Documents\Zonar_projects\data\t_pesqueros\Export_f0l917.xlsx') #excel
raw_fuel_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3228 entries, 0 to 3227
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  3228 non-null   str
#  1   Message  3228 non-null   str
#  2   Status   3228 non-null   str
# dtypes: str(3)
# memory usage: 75.8 KB

# %%
e0x=raw_fuel_data[raw_fuel_data['Status'].str.contains('3E0')]
row_number=e0x.shape[0]
#e0x.to_csv('/home/jlhb1984/py-projects/data/veepo/wcr728_.csv')

# %%
fs01_dec_value=[]
fs02_dec_value=[]
last_index_fs01=[]
last_index_fs02=[]
date_fs01_dec_value=[]
date_fs02_dec_value=[]
values_dates_fs01=pd.DataFrame()
values_dates_fs02=pd.DataFrame()

for i in range(0,row_number):
    e0x_aux=e0x.iloc[i,2]
    aux=e0x_aux.find('3E01')    
    if len(e0x_aux)>0:
        fs01=(e0x_aux[aux:aux+18])
        if len(fs01)>17:
            msb=fs01[10:12]
            lsb=fs01[8:10]
            measure=msb+lsb
            fs01_dec_value.append(int(measure,16))
            date_fs01_dec_value.append(e0x.iloc[i,0])            
            msb=fs01[28:30]
            lsb=fs01[26:28]
            fs01_dec_value.append(int(measure,16))
            date_fs01_dec_value.append(e0x.iloc[i,0]) 
            msb=fs01[46:48]
            lsb=fs01[44:46]
            fs01_dec_value.append(int(measure,16))
            date_fs01_dec_value.append(e0x.iloc[i,0])
            msb=fs01[46:48]
            lsb=fs01[44:46]
            fs01_dec_value.append(int(measure,16))
            date_fs01_dec_value.append(e0x.iloc[i,0])
            msb=fs01[64:66]
            lsb=fs01[62:64]
            last_index_fs01=i        
            
#print(i, raw_fuel_data.iloc[i,0] )

for i in range(0,row_number):
    e0x_aux=e0x.iloc[i,2]
    aux=e0x_aux.find('3E02')
    if len(e0x_aux)>0:
        fs02=e0x_aux[aux:aux+18]
        if len(fs02)>17:
            msb=fs02[10:12]
            lsb=fs02[8:10]
            measure=msb+lsb
            fs02_dec_value.append(int(measure,16))
            date_fs02_dec_value.append(e0x.iloc[i,0])            
            msb=fs02[28:30]
            lsb=fs02[26:28]
            fs02_dec_value.append(int(measure,16))
            date_fs02_dec_value.append(e0x.iloc[i,0]) 
            msb=fs02[46:48]
            lsb=fs02[44:46]
            fs02_dec_value.append(int(measure,16))
            date_fs02_dec_value.append(e0x.iloc[i,0])
            msb=fs02[46:48]
            lsb=fs02[44:46]
            fs02_dec_value.append(int(measure,16))
            date_fs02_dec_value.append(e0x.iloc[i,0])
            msb=fs02[64:66]
            lsb=fs02[62:64]
            last_index_fs02=i        
            
        #print(fs01_cad)   

fs01_count=len(fs01_dec_value)
fs02_count=len(fs02_dec_value)
values_dates_fs01['Value fs01']=fs01_dec_value
values_dates_fs01['Dates fs01']=date_fs01_dec_value
values_dates_fs02['Value fs02']=fs02_dec_value
values_dates_fs02['Dates fs02']=date_fs02_dec_value

#print('El Ncode en decimal es:')
print(fs01_dec_value,fs01_count)
print("Last fuel report fs01: ",e0x.iloc[last_index_fs01,0],"Last fuel report fs02: ",e0x.iloc[last_index_fs02,0])
# Out:
# [1516, 1516, 1516, 1516, 1516, 1516, 1516, 1516, 1516, 1516, 1516, 1516, 1479, 1479, 1479, 1479, 1483, 1483, 1483, 1483, 1483, 1483, 1483, 1483, 1483, 1483, 1483, 1483, 1506, 1506, 1506, 1506, 1506, 1506, 1506, 1506, 1506, 1506, 1506, 1506, 1540, 1540, 1540, 1540, 1546, 1546, 1546, 1546, 1546, 1546, 1546, 1546, 1546, 1546, 1546, 1546, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1557, 1557, 1557, 1557, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1555, 1554, 1554, 1554, 1554, 1552, 1552, 1552, 1552, 1553, 1553, 1553, 1553, 1552, 1552, 1552, 1552, 1552, 1552, 1552, 1552, 1537, 1537, 1537, 1537, 1544, 1544, 1544, 1544, 1544, 1544, 1544, 1544, 1544, 1544, 1544, 1544, 1551, 1551, 1551, 1551, 1557, 1557, 1557, 1557, 1561, 1561, 1561, 1561, 1563, 1563, 1563, 1563, 1566, 1566, 1566, 1566, 1567, 1567, 1567, 1567, 1567, 1567, 1567, 1567, 1567, 1567, 1567, 1567, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1568, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1568, 1568, 1568, 1568, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1569, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1570, 1576, 1576, 1576, 1576, 1559, 1559, 1559, 1559, 1558, 1558, 1558, 1558, 1581, 1581, 1581, 1581, 1524, 1524, 1524, 1524, 1497, 1497, 1497, 1497, 1497, 1497, 1497, 1497, 1497, 1497, 1497, 1497, 1503, 1503, 1503, 1503, 1533, 1533, 1533, 1533, 1575, 1575, 1575, 1575, 1752, 1752, 1752, 1752, 1772, 1772, 1772, 1772, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1908, 1908, 1908, 1908, 2019, 2019, 2019, 2019, 2072, 2072, 2072, 2072, 2117, 2117, 2117, 2117, 2104, 2104, 2104, 2104, 2156, 2156, 2156, 2156, 2189, 2189, 2189, 2189, 2233, 2233, 2233, 2233, 2274, 2274, 2274, 2274, 2319, 2319, 2319, 2319, 2361, 2361, 2361, 2361, 2319, 2319, 2319, 2319, 2299, 2299, 2299, 2299, 2255, 2255, 2255, 2255, 2231, 2231, 2231, 2231, 2211, 2211, 2211, 2211, 2176, 2176, 2176, 2176, 2181, 2181, 2181, 2181, 2156, 2156, 2156, 2156, 2167, 2167, 2167, 2167, 2147, 2147, 2147, 2147, 2111, 2111, 2111, 2111, 2104, 2104, 2104, 2104, 2102, 2102, 2102, 2102, 2140, 2140, 2140, 2140, 2130, 2130, 2130, 2130, 2130, 2130, 2130, 2130, 2104, 2104, 2104, 2104, 2072, 2072, 2072, 2072, 2030, 2030, 2030, 2030, 2021, 2021, 2021, 2021, 2016, 2016, 2016, 2016, 1942, 1942, 1942, 1942, 1962, 1962, 1962, 1962, 2051, 2051, 2051, 2051, 2053, 2053, 2053, 2053, 2027, 2027, 2027, 2027, 2014, 2014, 2014, 2014, 2028, 2028, 2028, 2028, 2070, 2070, 2070, 2070, 2068, 2068, 2068, 2068, 2093, 2093, 2093, 2093, 2099, 2099, 2099, 2099, 2106, 2106, 2106, 2106, 2111, 2111, 2111, 2111, 2114, 2114, 2114, 2114, 2116, 2116, 2116, 2116, 2117, 2117, 2117, 2117, 2117, 2117, 2117, 2117, 2117, 2117, 2117, 2117, 2119, 2119, 2119, 2119, 2118, 2118, 2118, 2118, 2119, 2119, 2119, 2119, 2120, 2120, 2120, 2120, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2121, 2122, 2122, 2122, 2122, 2122, 2122, 2122, 2122, 2125, 2125, 212 ...
# Last fuel report fs01:  2026-06-19 17:51:10.798 Last fuel report fs02:  2026-06-18 00:00:32.217

# %%
fs01_x_values=[]
fs02_x_values=[]

for i in range(0,fs01_count):
    fs01_x_values.append(i)
    
for i in range(0,fs02_count):
    fs02_x_values.append(i)

plt.plot(fs01_x_values,fs01_dec_value)
#plt.plot(fs02_x_values,fs02_dec_value)

# %%
int_value=int(input('Type the Ncode to look for: '))
for i in range(0,values_dates_fs01.shape[0]):
    if values_dates_fs01.iloc[i,0]>int_value:
        print(values_dates_fs01.loc[i])
# Out:
# Value fs01                       4028
# Dates fs01    2026-06-13 18:56:08.393
# Name: 1316, dtype: object
# Value fs01                       4028
# Dates fs01    2026-06-13 18:56:08.393
# Name: 1317, dtype: object
# Value fs01                       4028
# Dates fs01    2026-06-13 18:56:08.393
# Name: 1318, dtype: object
# Value fs01                       4028
# Dates fs01    2026-06-13 18:56:08.393
# Name: 1319, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:07:50.204
# Name: 1324, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:07:50.204
# Name: 1325, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:07:50.204
# Name: 1326, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:07:50.204
# Name: 1327, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:13:50.386
# Name: 1328, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:13:50.386
# Name: 1329, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:13:50.386
# Name: 1330, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:13:50.386
# Name: 1331, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:19:50.359
# Name: 1332, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:19:50.359
# Name: 1333, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:19:50.359
# Name: 1334, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:19:50.359
# Name: 1335, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:25:50.634
# Name: 1336, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:25:50.634
# Name: 1337, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:25:50.634
# Name: 1338, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:25:50.634
# Name: 1339, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:31:50.572
# Name: 1340, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:31:50.572
# Name: 1341, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:31:50.572
# Name: 1342, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:31:50.572
# Name: 1343, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:37:50.472
# Name: 1344, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:37:50.472
# Name: 1345, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:37:50.472
# Name: 1346, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:37:50.472
# Name: 1347, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:43:50.600
# Name: 1348, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:43:50.600
# Name: 1349, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:43:50.600
# Name: 1350, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:43:50.600
# Name: 1351, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:43:58.886
# Name: 1352, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:43:58.886
# Name: 1353, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:43:58.886
# Name: 1354, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:43:58.886
# Name: 1355, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:49:50.708
# Name: 1356, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:49:50.708
# Name: 1357, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:49:50.708
# Name: 1358, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:49:50.708
# Name: 1359, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:55:50.765
# Name: 1360, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:55:50.765
# Name: 1361, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:55:50.765
# Name: 1362, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-13 19:55:50.765
# Name: 1363, dtype: object
# Value fs01                       4081
# Dates fs01    2026-06-13 20:02:49.114
# Name: 1364, dtype: object
# Value fs01                       4081
# Dates fs01    2026-06-13 20:02:49.114
# Name: 1365, dtype: object
# Value fs01                       4081
# Dates fs01    2026-06-13 20:02:49.114
# Name: 1366, dtype: object
# Value fs01                       4081
# Dates fs01    2026-06-13 20:02:49.114
# Name: 1367, dtype: object
# Value fs01                       4068
# Dates fs01    2026-06-13 20:08:50.453
# Name: 1368, dtype: object
# Value fs01                       4068
# Dates fs01    2026-06-13 20:08:50.453
# Name: 1369, dtype: object
# Value fs01                       4068
# Dates fs01    2026-06-13 20:08:50.453
# Name: 1370, dtype: object
# Value fs01                       4068
# Dates fs01    2026-06-13 20:08:50.453
# Name: 1371, dtype: object
# Value fs01                       4060
# Dates fs01    2026-06-13 20:14:49.350
# Name: 1372, dtype: object
# Value fs01                       4060
# Dates fs01    2026-06-13 20:14:49.350
# Name: 1373, dtype: object
# Value fs01                       4060
# Dates fs01    2026-06-13 20:14:49.350
# Name: 1374, dtype: object
# Value fs01                       4060
# Dates fs01    2026-06-13 20:14:49.350
# Name: 1375, dtype: object
# Value fs01                       4058
# Dates fs01    2026-06-13 20:21:01.451
# Name: 1376, dtype: object
# Value fs01                       4058
# Dates fs01    2026-06-13 20:21:01.451
# Name: 1377, dtype: object
# Value fs01                       4058
# Dates fs01    2026-06-13 20:21:01.451
# Name: 1378, dtype: object
# Value fs01                       4058
# Dates fs01    2026-06-13 20:21:01.451
# Name: 1379, dtype: object
# Value fs01                       4065
# Dates fs01    2026-06-13 20:27:01.804
# Name: 1384, dtype: object
# Value fs01                       4065
# Dates fs01    2026-06-13 20:27:01.804
# Name: 1385, dtype: object
# Value fs01                       4065
# Dates fs01    2026-06-13 20:27:01.804
# Name: 1386, dtype: object
# Value fs01                       4065
# Dates fs01    2026-06-13 20:27:01.804
# Name: 1387, dtype: object
# Value fs01                       4048
# Dates fs01    2026-06-13 20:33:15.122
# Name: 1388, dtype: object
# Value fs01                       4048
# Dates fs01    2026-06-13 20:33:15.122
# Name: 1389, dtype: object
# Value fs01                       4048
# Dates fs01    2026-06-13 20:33:15.122
# Name: 1390, dtype: object
# Value fs01                       4048
# Dates fs01    2026-06-13 20:33:15.122
# Name: 1391, dtype: object
# Value fs01                       4048
# Dates fs01    2026-06-13 20:33:15.900
# Name: 1392, dtype: object
# Value fs01                       4048
# Dates fs01    2026-06-13 20:33:15.900
# Name: 1393, dtype: object
# Value fs01                       4048
# Dates fs01    2026-06-13 20:33:15.900
# Name: 1394, dtype: object
# Value fs01                       4048
# Dates fs01    2026-06-13 20:33:15.900
# Name: 1395, dtype: object
# Value fs01                       4016
# Dates fs01    2026-06-13 20:39:01.493
# Name: 1396, dtype: object
# Value fs01                       4016
# Dates fs01    2026-06-13 20:39:01.493
# Name: 1397, dtype: object
# Value fs01                       4016
# Dates fs01    2026-06-13 20:39:01.493
# Name: 1398, dtype: object
# Value fs01                       4016
# Dates fs01    2026-06-13 20:39:01.493
# Name: 1399, dtype: object
# Value fs01                       4005
# Dates fs01    2026-06-13 20:45:01.441
# Name: 1400, dtype: object
# Value fs01                       4005
# Dates fs01    2026-06-13 20:45:01.441
# Name: 1401, dtype: object
# Value fs01                       4005
# Dates fs01    2026-06-13 20:45:01.441
# Name: 1402, dtype: object
# Value fs01                       4005
# Dates fs01    2026-06-13 20:45:01.441
# Name: 1403, dtype: object
# Value fs01                       4088
# Dates fs01    2026-06-14 19:35:17.997
# Name: 2324, dtype: object
# Value fs01                       4088
# Dates fs01    2026-06-14 19:35:17.997
# Name: 2325, dtype: object
# Value fs01                       4088
# Dates fs01    2026-06-14 19:35:17.997
# Name: 2326, dtype: object
# Value fs01                       4088
# Dates fs01    2026-06-14 19:35:17.997
# Name: 2327, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:41:35.041
# Name: 2328, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:41:35.041
# Name: 2329, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:41:35.041
# Name: 2330, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:41:35.041
# Name: 2331, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:47:34.983
# Name: 2332, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:47:34.983
# Name: 2333, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:47:34.983
# Name: 2334, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:47:34.983
# Name: 2335, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:53:35.301
# Name: 2336, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:53:35.301
# Name: 2337, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:53:35.301
# Name: 2338, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:53:35.301
# Name: 2339, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:59:35.231
# Name: 2340, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:59:35.231
# Name: 2341, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:59:35.231
# Name: 2342, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 19:59:35.231
# Name: 2343, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 20:05:35.199
# Name: 2344, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 20:05:35.199
# Name: 2345, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 20:05:35.199
# Name: 2346, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 20:05:35.199
# Name: 2347, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 20:11:35.069
# Name: 2348, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 20:11:35.069
# Name: 2349, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 20:11:35.069
# Name: 2350, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-14 20:11:35.069
# Name: 2351, dtype: object
# Value fs01                       4056
# Dates fs01    2026-06-14 20:17:35.245
# Name: 2352, dtype: object
# Value fs01                       4056
# Dates fs01    2026-06-14 20:17:35.245
# Name: 2353, dtype: object
# Value fs01                       4056
# Dates fs01    2026-06-14 20:17:35.245
# Name: 2354, dtype: object
# Value fs01                       4056
# Dates fs01    2026-06-14 20:17:35.245
# Name: 2355, dtype: object
# Value fs01                       4017
# Dates fs01    2026-06-14 20:26:05.172
# Name: 2356, dtype: object
# Value fs01                       4017
# Dates fs01    2026-06-14 20:26:05.172
# Name: 2357, dtype: object
# Value fs01                       4017
# Dates fs01    2026-06-14 20:26:05.172
# Name: 2358, dtype: object
# Value fs01                       4017
# Dates fs01    2026-06-14 20:26:05.172
# Name: 2359, dtype: object
# Value fs01                       4041
# Dates fs01    2026-06-18 13:47:26.542
# Name: 4284, dtype: object
# Value fs01                       4041
# Dates fs01    2026-06-18 13:47:26.542
# Name: 4285, dtype: object
# Value fs01                       4041
# Dates fs01    2026-06-18 13:47:26.542
# Name: 4286, dtype: object
# Value fs01                       4041
# Dates fs01    2026-06-18 13:47:26.542
# Name: 4287, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 13:53:02.636
# Name: 4288, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 13:53:02.636
# Name: 4289, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 13:53:02.636
# Name: 4290, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 13:53:02.636
# Name: 4291, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 13:59:32.747
# Name: 4292, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 13:59:32.747
# Name: 4293, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 13:59:32.747
# Name: 4294, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 13:59:32.747
# Name: 4295, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:05:31.987
# Name: 4296, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:05:31.987
# Name: 4297, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:05:31.987
# Name: 4298, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:05:31.987
# Name: 4299, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:11:32.795
# Name: 4300, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:11:32.795
# Name: 4301, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:11:32.795
# Name: 4302, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:11:32.795
# Name: 4303, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:17:32.819
# Name: 4304, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:17:32.819
# Name: 4305, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:17:32.819
# Name: 4306, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:17:32.819
# Name: 4307, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:23:32.950
# Name: 4308, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:23:32.950
# Name: 4309, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:23:32.950
# Name: 4310, dtype: object
# Value fs01                       4095
# Dates fs01    2026-06-18 14:23:32.950
# Name: 4311, dtype: object

# %%
for i in range(0,values_dates_fs02.shape[0]):
    if values_dates_fs01.iloc[i,0]>int_value:
        print(values_dates_fs01.loc[i])
