# %%
import pandas as pd
import numpy as np

# %%
raw_data_luw348=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\estarter\luw348_0203_0303_2026.csv',sep=',',encoding='latin1')
raw_data_luw348.info()
raw_data_luw348_m=pd.read_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\estarter\luw348_0203_0303_2026m.csv',sep=',',encoding='latin1')
raw_data_luw348_m.rename(columns={'Unnamed: 1':'Message Type',
                                 'Unnamed: 2':'Protocole',
                                 'Unnamed: 3':'IMEI',
                                 'Unnamed: 4':'Serial',
                                 'Unnamed: 5':'Mileage',
                                 'Unnamed: 6':'Date',
                                 'Unnamed: 7':'Ignition',
                                 'Unnamed: 8':'Latitude',
                                 'Unnamed: 9':'Longitude',
                                 'Unnamed: 10':'Altitude',
                                 'Unnamed: 11':'External Power',
                                 'Unnamed: 12':'RPM',
                                 'Unnamed: 13':'Speed',
                                 'Unnamed: 14':'Satellite Number',
                                 'Unnamed: 15':'Azimuth',
                                 'Unnamed: 16':'Bettery level',
                                 },inplace=True)
raw_data_luw348_m.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2292 entries, 0 to 2291
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Created  2292 non-null   str
#  1   Message  2292 non-null   str
#  2   Status   2292 non-null   str
# dtypes: str(3)
# memory usage: 53.8 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 2292 entries, 0 to 2291
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Message           2292 non-null   str
#  1   Message Type      2292 non-null   str
#  2   Protocole         2292 non-null   str
#  3   IMEI              2292 non-null   str
#  4   Serial            2292 non-null   str
#  5   Mileage           2292 non-null   str
#  6   Date              2292 non-null   str
#  7   Ignition          2292 non-null   str
#  8   Latitude          2292 non-null   str
#  9   Longitude         2292 non-null   str
# ...

# %%
raw_data_luw348_020320262300_030320260100=pd.concat([raw_data_luw348_m[raw_data_luw348_m['Date'].str.contains('2026-03-03T04')],raw_data_luw348_m[raw_data_luw348_m['Date'].str.contains('2026-03-03T05')]])
raw_data_luw348_020320262300_030320260100[['Mileage','Latitude','Longitude','Speed','Satellite Number']]
raw_data_luw348_020320262300_030320260100.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\estarter\luw348_0203_0303_2026_.csv')

# %%
value_to_look=input("Type the date to look for (2026-03-03T04): ")
print(raw_data_luw348_020320262300_030320260100[raw_data_luw348_020320262300_030320260100['Date'].str.contains(value_to_look)])
# Out:
#                     Message                        Message Type  \
# 1257  [{"Protocol":"0x2525"  MessageType:"LocationAlarmMessage"
# 1258  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
# 1259  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
# 1260  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
# 1261  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
# ...                     ...                                 ...
# 1346  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
# 1347  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
# 1348  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
# 1349  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
# 1350  [{"Protocol":"0x2525"   MessageType:"LocationInfoMessage"
#
#                 Protocole                    IMEI         Serial  \
# 1257  ProtocolHeadType:20  Imei:"869487064468670"   SerialNo:143
# ...

# %%
value_to_look=input("Type the date to look for (2026-03-03T04): ")
raw_data_luw348_dates=raw_data_luw348[raw_data_luw348['Message'].str.contains(value_to_look)]
raw_data_luw348_dates.to_csv(r'C:\Users\Jose.Hurtado\Documents\projects\data\estarter\luw348_0203_0303_2026_dates.csv')
